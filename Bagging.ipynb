# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from evolutionary_search import EvolutionaryAlgorithmSearchCV
from hyperopt import fmin, tpe, hp, STATUS_OK
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from sklearn.ensemble import BaggingRegressor

# %% [markdown]
# ## Step I. Load data

# %%
train = pd.read_csv('train.csv')
X_test = pd.read_csv('X_test.csv')

X_train = train.iloc[:, :-1]
y_train = train.iloc[:, -1]

# %% [markdown]
# ## Build the model and perform parameter tuning

# %%
def modelfit(clf, train, target, performCV=True, cv=10):
    clf.fit(train, target)
    pred = clf.predict(train)
    train_r2_score = r2_score(target, pred)
    
    print('\nModel Report')
    print('Train_coef_of_det: %0.6f' %(train_r2_score))
    
    if performCV:
        cv_r2_score = cross_val_score(clf, train, target, cv=cv, scoring='r2', n_jobs=-1)
        print('CV_coef_of_det: Mean-%0.6f | Std-%0.6f | Min-%0.6f | Max-%0.6f' %(np.mean(cv_r2_score),
            np.std(cv_r2_score), np.min(cv_r2_score), np.max(cv_r2_score)))

# %% [markdown]
# ### Baseline model

# %%
params = {}
grid = GridSearchCV(estimator=BaggingRegressor(), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.85706230754

# %%
params = {}
grid = GridSearchCV(estimator=BaggingRegressor(base_estimator=None, n_estimators=10, max_samples=1.0,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, warm_start=False,
        n_jobs=1, random_state=10, verbose=0), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.850850639252

# %% [markdown]
# ### Grid search

# %%
params = {}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=10, max_samples=1.0,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=-1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# {}
# 0.850850639252

# %%
params = {'n_estimators': range(10,210,10)}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=10, max_samples=1.0,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=-1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# {'n_estimators': 70}
# 0.867074503041

# %%
params = {'n_estimators': range(70,700,50)}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=10, max_samples=1.0,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'n_estimators': 70}
# 0.867074503041

# %%
params = {'max_samples': [i/10.0 for i in range(1,11)]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=1.0,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_samples': 0.9}
# 0.867136741441

# %%
params = {'max_samples': [i/100.0 for i in range(84,96)]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=1.0,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_samples': 0.9}
# 0.867136741441

# %%
params = {'max_samples': [i/1000.0 for i in range(894,906)]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=1.0,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_samples': 0.896}
# 0.868980362984

# %%
params = {'max_samples': [i/10000.0 for i in range(8954,8966)]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=1.0,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_samples': 0.8958}
# 0.868980362984

# %%
params = {'max_features': [i/10.0 for i in range(1,11)]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=0.896,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_features': 0.5}
# 0.87535570631

# %%
params = {'max_features': [i/100.0 for i in range(44,56)]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=0.896,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_features': 0.53}
# 0.876106932589

# %%
params = {'max_features': [i/1000.0 for i in range(524,536)]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=0.896,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_features': 0.529}
# 0.876106932589

# %%
params = {'max_features': [i/10000.0 for i in range(5284,5296)]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=0.896,
        max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_features': 0.529}
# 0.876106932589

# %%
params = {'bootstrap': [True,False]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=0.896,
        max_features=0.529, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'bootstrap': True}
# 0.876106932589

# %%
params = {'bootstrap_features': [True,False]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=0.896,
        max_features=0.529, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'bootstrap_features': False}
# 0.876106932589

# %%
params = {'oob_score': [True,False]}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=0.896,
        max_features=0.529, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'oob_score': True}
# 0.876106932589

# %% [markdown]
# ### Final model

# %%
params = {}
grid = GridSearchCV(estimator=BaggingRegressor(n_estimators=70, max_samples=0.896,
        max_features=0.529, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.876106932589

# %%
reg1 = BaggingRegressor(n_estimators=70, max_samples=0.896,
        max_features=0.529, bootstrap=True, bootstrap_features=False, oob_score=False, base_estimator=None,
        verbose=0, warm_start=False, n_jobs=1, random_state=10)
modelfit(reg1, X_train, y_train)
# Out:
# Model Report
# Train_coef_of_det: 0.976409
# CV_coef_of_det: Mean-0.876107 | Std-0.035142 | Min-0.792982 | Max-0.909830

# %% [markdown]
# ### Grid search + Random search

# %%
params = {
          'n_estimators': range(10,150,10),
          'max_samples': [i/100.0 for i in range(85,94)],
          'max_features': [i/100.0 for i in range(49,58)],
          'bootstrap': [True,False],
          'bootstrap_features': [True,False],
          'oob_score': [False],
          'base_estimator': [None],
          'warm_start': [True],
          'verbose': [0],
          'n_jobs': [1],
          'random_state': [10]
         }
rand = RandomizedSearchCV(estimator=BaggingRegressor(), param_distributions=params, cv=10, scoring='r2',
         n_iter=1000, random_state=10, n_jobs=-1)
rand.fit(X_train, y_train)
print 'Best parameters: \n', rand.best_params_
print '\tBest score: ', rand.best_score_
# Out:
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Best parameters:
# {'warm_start': True, 'max_samples': 0.9, 'oob_score': False, 'n_jobs': -1, 'verbose': 0, 'bootstrap': False, 'base_estimator': None, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.48, 'bootstrap_features': False}
# 	Best score:  0.878835856234

# %%
params = {}
reg1 = BaggingRegressor(
                        n_estimators = params['n_estimators'],
                        max_samples = params['max_samples'],
                        max_features = params['max_features'],
                        bootstrap = params['bootstrap'],
                        bootstrap_features = params['bootstrap_features'],
                        oob_score = params['oob_score'],
                        base_estimator = params['base_estimator'],
                        warm_start = params['warm_start'],
                        verbose = params['verbose'],
                        n_jobs = params['n_jobs'],
                        random_state = params['random_state']  
                        )
modelfit(reg1, X_train, y_train)

# %% [markdown]
# ### Grid search + Bayesian optimization ( 'hyperopt' package )

# %%
min_score = float('inf')
best_params = ''
c = 0

def score(params):
    global c, min_score, best_params
    c += 1
    print "Interation no.: ", c
    print "Training with params : "
    print params
    reg = BaggingRegressor(
                            n_estimators = params['n_estimators'],
                            max_samples = params['max_samples'],
                            max_features = params['max_features'],
                            bootstrap = params['bootstrap'],
                            bootstrap_features = params['bootstrap_features'],
                            oob_score = params['oob_score'],
                            base_estimator = params['base_estimator'],
                            warm_start = params['warm_start'],
                            verbose = params['verbose'],
                            n_jobs = params['n_jobs'],
                            random_state = params['random_state']        
                            )
    cv_r2_score = cross_val_score(reg, X_train, y_train, cv=10, scoring='r2', n_jobs=-1)
    score = 1 - np.mean(cv_r2_score) 
    if score < min_score:
        min_score = score
        best_params = params     
    print "\tScore: {0}".format(1-score)
    print "\tBest score: {0}\n".format(1-min_score)
    return {'loss': score, 'status': STATUS_OK}

def optimize():
    space = {
              'n_estimators': hp.choice('n_estimators', range(10,150,10)),
              'max_samples': hp.uniform('max_samples', 0.85, 0.94),
              'max_features': hp.uniform('max_features', 0.49, 0.58),
              'bootstrap': hp.choice('bootstrap', [True,False]),
              'bootstrap_features': hp.choice('bootstrap_features', [True,False]),
              'oob_score': hp.choice('oob_score', [False]),
              'base_estimator': hp.choice('base_estimator', [None]),
              'warm_start': hp.choice('warm_start', [True]),
              'verbose': hp.choice('verbose', [0]),
              'n_jobs': hp.choice('n_jobs', [1]),
              'random_state': hp.choice('random_state', [10])        
             }
    best = fmin(score, space, algo=tpe.suggest, max_evals=1000)    
  
optimize()
print 'Best parameters:'
print best_params
print "\tScore {0}".format(1-min_score)
# Out:
# Interation no.:  1
# Training with params :
# {'warm_start': True, 'max_samples': 0.9177721030539293, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.5419723659990853, 'bootstrap_features': True}
# 	Score: 0.876591206057
# 	Best score: 0.876591206057
#
# Interation no.:  2
# Training with params :
# {'warm_start': True, 'max_samples': 0.911932804200888, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5423947088349592, 'bootstrap_features': True}
# 	Score: 0.877033499488
# 	Best score: 0.877033499488
#
# Interation no.:  3
# Training with params :
# {'warm_start': True, 'max_samples': 0.8929581495632761, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.5283738286578658, 'bootstrap_features': True}
# 	Score: 0.845468256558
# 	Best score: 0.877033499488
#
# Interation no.:  4
# Training with params :
# {'warm_start': True, 'max_samples': 0.9268611389294632, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5600207750175599, 'bootstrap_features': True}
# 	Score: 0.870960277007
# 	Best score: 0.877033499488
#
# Interation no.:  5
# Training with params :
# {'warm_start': True, 'max_samples': 0.8606944202385209, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.5094300910059706, 'bootstrap_features': True}
# 	Score: 0.875593785539
# 	Best score: 0.877033499488
#
# Interation no.:  6
# Training with params :
# {'warm_start': True, 'max_samples': 0.8726687783161448, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.4978871249685127, 'bootstrap_features': True}
# 	Score: 0.859388181619
# 	Best score: 0.877033499488
#
# Interation no.:  7
# Training with params :
# {'warm_start': True, 'max_samples': 0.9227900582213924, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5307301004566859, 'bootstrap_features': True}
# 	Score: 0.878484704116
# 	Best score: 0.878484704116
#
# Interation no.:  8
# Training with params :
# {'warm_start': True, 'max_samples': 0.8679408367427568, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.523793179918451, 'bootstrap_features': True}
# 	Score: 0.863992593353
# 	Best score: 0.878484704116
#
# Interation no.:  9
# Training with params :
# {'warm_start': True, 'max_samples': 0.9272817157990395, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5408862337221388, 'bootstrap_features': False}
# 	Score: 0.877247048982
# 	Best score: 0.878484704116
#
# Interation no.:  10
# Training with params :
# {'warm_start': True, 'max_samples': 0.8724052245967155, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.5726548450866394, 'bootstrap_features': True}
# 	Score: 0.868763134461
# 	Best score: 0.878484704116
#
# Interation no.:  11
# Training with params :
# {'warm_start': True, 'max_samples': 0.8865881794456568, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5474268398776615, 'bootstrap_features': True}
# 	Score: 0.880418673857
# 	Best score: 0.880418673857
#
# Interation no.:  12
# Training with params :
# {'warm_start': True, 'max_samples': 0.9379557438757581, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.5228036682883707, 'bootstrap_features': True}
# 	Score: 0.876927138023
# 	Best score: 0.880418673857
#
# Interation no.:  13
# Training with params :
# {'warm_start': True, 'max_samples': 0.8888592405557152, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5658301340167295, 'bootstrap_features': True}
# 	Score: 0.868294956075
# 	Best score: 0.880418673857
#
# Interation no.:  14
# Training with params :
# {'warm_start': True, 'max_samples': 0.8530672756068435, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.490867681639532, 'bootstrap_features': True}
# 	Score: 0.87712359336
# 	Best score: 0.880418673857
#
# Interation no.:  15
# Training with params :
# {'warm_start': True, 'max_samples': 0.9010932095147417, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5168373908396899, 'bootstrap_features': True}
# 	Score: 0.863467765462
# 	Best score: 0.880418673857
#
# Interation no.:  16
# Training with params :
# {'warm_start': True, 'max_samples': 0.8909505355765408, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.4977048891627092, 'bootstrap_features': True}
# 	Score: 0.877972761038
# 	Best score: 0.880418673857
#
# Interation no.:  17
# Training with params :
# {'warm_start': True, 'max_samples': 0.9218608538726145, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.5345132458089644, 'bootstrap_features': False}
# 	Score: 0.847788620552
# 	Best score: 0.880418673857
#
# Interation no.:  18
# Training with params :
# {'warm_start': True, 'max_samples': 0.9128731456363158, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.5315973015943798, 'bootstrap_features': False}
# 	Score: 0.870696949898
# 	Best score: 0.880418673857
#
# Interation no.:  19
# Training with params :
# {'warm_start': True, 'max_samples': 0.8954396468785712, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.5219226293542065, 'bootstrap_features': True}
# 	Score: 0.867793345877
# 	Best score: 0.880418673857
#
# Interation no.:  20
# Training with params :
# {'warm_start': True, 'max_samples': 0.8797939505261256, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.5522609016948598, 'bootstrap_features': False}
# 	Score: 0.850379414433
# 	Best score: 0.880418673857
#
# Interation no.:  21
# Training with params :
# {'warm_start': True, 'max_samples': 0.9391227676582081, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5523530878682181, 'bootstrap_features': True}
# 	Score: 0.876873454317
# 	Best score: 0.880418673857
#
# Interation no.:  22
# Training with params :
# {'warm_start': True, 'max_samples': 0.906223691021933, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.551929372836589, 'bootstrap_features': False}
# 	Score: 0.880878272999
# 	Best score: 0.880878272999
#
# Interation no.:  23
# Training with params :
# {'warm_start': True, 'max_samples': 0.9035599991941231, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5796622210005055, 'bootstrap_features': False}
# 	Score: 0.877611571243
# 	Best score: 0.880878272999
#
# Interation no.:  24
# Training with params :
# {'warm_start': True, 'max_samples': 0.8837216172042904, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5495628880326954, 'bootstrap_features': False}
# 	Score: 0.879276055748
# 	Best score: 0.880878272999
#
# Interation no.:  25
# Training with params :
# {'warm_start': True, 'max_samples': 0.9044925351003538, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5613558894920427, 'bootstrap_features': False}
# 	Score: 0.87702907435
# 	Best score: 0.880878272999
#
# Interation no.:  26
# Training with params :
# {'warm_start': True, 'max_samples': 0.8783784379631108, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5770137005889496, 'bootstrap_features': False}
# 	Score: 0.877940833138
# 	Best score: 0.880878272999
#
# Interation no.:  27
# Training with params :
# {'warm_start': True, 'max_samples': 0.8987123080409456, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5671812137762889, 'bootstrap_features': False}
# 	Score: 0.875129297788
# 	Best score: 0.880878272999
#
# Interation no.:  28
# Training with params :
# {'warm_start': True, 'max_samples': 0.9088775150872802, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5477840815524505, 'bootstrap_features': False}
# 	Score: 0.877184981036
# 	Best score: 0.880878272999
#
# Interation no.:  29
# Training with params :
# {'warm_start': True, 'max_samples': 0.8859190273592885, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5404546608090366, 'bootstrap_features': False}
# 	Score: 0.878547259105
# 	Best score: 0.880878272999
#
# Interation no.:  30
# Training with params :
# {'warm_start': True, 'max_samples': 0.8503795556044113, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5597254556969491, 'bootstrap_features': False}
# 	Score: 0.876396568035
# 	Best score: 0.880878272999
#
# Interation no.:  31
# Training with params :
# {'warm_start': True, 'max_samples': 0.9152078054854579, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.54395147199771, 'bootstrap_features': False}
# 	Score: 0.873311872712
# 	Best score: 0.880878272999
#
# Interation no.:  32
# Training with params :
# {'warm_start': True, 'max_samples': 0.9078430348601847, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5378152469128812, 'bootstrap_features': False}
# 	Score: 0.880366414598
# 	Best score: 0.880878272999
#
# Interation no.:  33
# Training with params :
# {'warm_start': True, 'max_samples': 0.8600231418824126, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.5567323850722985, 'bootstrap_features': True}
# 	Score: 0.863645883961
# 	Best score: 0.880878272999
#
# Interation no.:  34
# Training with params :
# {'warm_start': True, 'max_samples': 0.9335984788568255, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.570351007299493, 'bootstrap_features': False}
# 	Score: 0.872609056685
# 	Best score: 0.880878272999
#
# Interation no.:  35
# Training with params :
# {'warm_start': True, 'max_samples': 0.8949809305889044, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5145229962253856, 'bootstrap_features': True}
# 	Score: 0.876244709613
# 	Best score: 0.880878272999
#
# Interation no.:  36
# Training with params :
# {'warm_start': True, 'max_samples': 0.8637527665009637, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.5558214000009615, 'bootstrap_features': True}
# 	Score: 0.876699845614
# 	Best score: 0.880878272999
#
# Interation no.:  37
# Training with params :
# {'warm_start': True, 'max_samples': 0.9178999138263285, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.5450117933811903, 'bootstrap_features': True}
# 	Score: 0.877544369218
# 	Best score: 0.880878272999
#
# Interation no.:  38
# Training with params :
# {'warm_start': True, 'max_samples': 0.8778341587214387, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5353760377924083, 'bootstrap_features': False}
# 	Score: 0.879487248839
# 	Best score: 0.880878272999
#
# Interation no.:  39
# Training with params :
# {'warm_start': True, 'max_samples': 0.9315561813310757, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5273243512864106, 'bootstrap_features': True}
# 	Score: 0.871860069759
# 	Best score: 0.880878272999
#
# Interation no.:  40
# Training with params :
# {'warm_start': True, 'max_samples': 0.8690538521469114, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.507923046531708, 'bootstrap_features': True}
# 	Score: 0.876480899551
# 	Best score: 0.880878272999
#
# Interation no.:  41
# Training with params :
# {'warm_start': True, 'max_samples': 0.8837513952410925, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.5611894414195788, 'bootstrap_features': False}
# 	Score: 0.877326441458
# 	Best score: 0.880878272999
#
# Interation no.:  42
# Training with params :
# {'warm_start': True, 'max_samples': 0.9091954559252006, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5728816217808768, 'bootstrap_features': True}
# 	Score: 0.875452303007
# 	Best score: 0.880878272999
#
# Interation no.:  43
# Training with params :
# {'warm_start': True, 'max_samples': 0.9192673458063965, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.5653286446116885, 'bootstrap_features': True}
# 	Score: 0.871385404741
# 	Best score: 0.880878272999
#
# Interation no.:  44
# Training with params :
# {'warm_start': True, 'max_samples': 0.8993298484726737, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5476612118550762, 'bootstrap_features': False}
# 	Score: 0.876190463779
# 	Best score: 0.880878272999
#
# Interation no.:  45
# Training with params :
# {'warm_start': True, 'max_samples': 0.9251445878098835, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.5544883084313666, 'bootstrap_features': True}
# 	Score: 0.869604930108
# 	Best score: 0.880878272999
#
# Interation no.:  46
# Training with params :
# {'warm_start': True, 'max_samples': 0.8891067485370165, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5272905485425532, 'bootstrap_features': True}
# 	Score: 0.867205518081
# 	Best score: 0.880878272999
#
# Interation no.:  47
# Training with params :
# {'warm_start': True, 'max_samples': 0.8738529584282471, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.507263759600403, 'bootstrap_features': False}
# 	Score: 0.877202838512
# 	Best score: 0.880878272999
#
# Interation no.:  48
# Training with params :
# {'warm_start': True, 'max_samples': 0.8551316753644207, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.5401217091339764, 'bootstrap_features': True}
# 	Score: 0.869018656128
# 	Best score: 0.880878272999
#
# Interation no.:  49
# Training with params :
# {'warm_start': True, 'max_samples': 0.8924909418665552, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5319794404449708, 'bootstrap_features': True}
# 	Score: 0.876697482633
# 	Best score: 0.880878272999
#
# Interation no.:  50
# Training with params :
# {'warm_start': True, 'max_samples': 0.8968185250189314, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.516416461754857, 'bootstrap_features': False}
# 	Score: 0.849117372572
# 	Best score: 0.880878272999
#
# Interation no.:  51
# Training with params :
# {'warm_start': True, 'max_samples': 0.904663437031485, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.5010144580351559, 'bootstrap_features': True}
# 	Score: 0.87541706685
# 	Best score: 0.880878272999
#
# Interation no.:  52
# Training with params :
# {'warm_start': True, 'max_samples': 0.914787897226012, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5759148556462902, 'bootstrap_features': False}
# 	Score: 0.876473121125
# 	Best score: 0.880878272999
#
# Interation no.:  53
# Training with params :
# {'warm_start': True, 'max_samples': 0.8748052895727128, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5194461496418447, 'bootstrap_features': True}
# 	Score: 0.86716820549
# 	Best score: 0.880878272999
#
# Interation no.:  54
# Training with params :
# {'warm_start': True, 'max_samples': 0.9293774518376375, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5642202097566011, 'bootstrap_features': False}
# 	Score: 0.876626359897
# 	Best score: 0.880878272999
#
# Interation no.:  55
# Training with params :
# {'warm_start': True, 'max_samples': 0.8680983845278886, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5365649662156168, 'bootstrap_features': True}
# 	Score: 0.876652651117
# 	Best score: 0.880878272999
#
# Interation no.:  56
# Training with params :
# {'warm_start': True, 'max_samples': 0.8861849631776418, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5513882922809368, 'bootstrap_features': False}
# 	Score: 0.879490277301
# 	Best score: 0.880878272999
#
# Interation no.:  57
# Training with params :
# {'warm_start': True, 'max_samples': 0.9218708771899335, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5696840845844001, 'bootstrap_features': False}
# 	Score: 0.874127413069
# 	Best score: 0.880878272999
#
# Interation no.:  58
# Training with params :
# {'warm_start': True, 'max_samples': 0.9356847823872285, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5462148335529609, 'bootstrap_features': True}
# 	Score: 0.877326828191
# 	Best score: 0.880878272999
#
# Interation no.:  59
# Training with params :
# {'warm_start': True, 'max_samples': 0.8812042279566167, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.557938256156634, 'bootstrap_features': False}
# 	Score: 0.877228319086
# 	Best score: 0.880878272999
#
# Interation no.:  60
# Training with params :
# {'warm_start': True, 'max_samples': 0.9015420047736201, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5240108354132887, 'bootstrap_features': True}
# 	Score: 0.870186063441
# 	Best score: 0.880878272999
#
# Interation no.:  61
# Training with params :
# {'warm_start': True, 'max_samples': 0.9112340997491646, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.530247798097601, 'bootstrap_features': False}
# 	Score: 0.87518903761
# 	Best score: 0.880878272999
#
# Interation no.:  62
# Training with params :
# {'warm_start': True, 'max_samples': 0.8636479056695061, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.4909284239507951, 'bootstrap_features': True}
# 	Score: 0.850899555792
# 	Best score: 0.880878272999
#
# Interation no.:  63
# Training with params :
# {'warm_start': True, 'max_samples': 0.8906751657119217, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.57861432804811, 'bootstrap_features': False}
# 	Score: 0.877093823219
# 	Best score: 0.880878272999
#
# Interation no.:  64
# Training with params :
# {'warm_start': True, 'max_samples': 0.8709184653619281, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5436826981548416, 'bootstrap_features': False}
# 	Score: 0.87615229868
# 	Best score: 0.880878272999
#
# Interation no.:  65
# Training with params :
# {'warm_start': True, 'max_samples': 0.9054749596806457, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.5392824705247551, 'bootstrap_features': True}
# 	Score: 0.870331469508
# 	Best score: 0.880878272999
#
# Interation no.:  66
# Training with params :
# {'warm_start': True, 'max_samples': 0.9075422082771747, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5501433927320222, 'bootstrap_features': False}
# 	Score: 0.877666176383
# 	Best score: 0.880878272999
#
# Interation no.:  67
# Training with params :
# {'warm_start': True, 'max_samples': 0.901074003415466, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5337768908348994, 'bootstrap_features': False}
# 	Score: 0.876752001338
# 	Best score: 0.880878272999
#
# Interation no.:  68
# Training with params :
# {'warm_start': True, 'max_samples': 0.8940210429642709, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5374411365646125, 'bootstrap_features': False}
# 	Score: 0.876815391788
# 	Best score: 0.880878272999
#
# Interation no.:  69
# Training with params :
# {'warm_start': True, 'max_samples': 0.8973515075459167, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5546694005894872, 'bootstrap_features': False}
# 	Score: 0.876367112837
# 	Best score: 0.880878272999
#
# Interation no.:  70
# Training with params :
# {'warm_start': True, 'max_samples': 0.9241630793531027, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.5423841111710965, 'bootstrap_features': False}
# 	Score: 0.871439087367
# 	Best score: 0.880878272999
#
# Interation no.:  71
# Training with params :
# {'warm_start': True, 'max_samples': 0.914412908904387, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5251789267236054, 'bootstrap_features': False}
# 	Score: 0.876553085379
# 	Best score: 0.880878272999
#
# Interation no.:  72
# Training with params :
# {'warm_start': True, 'max_samples': 0.9191415642751488, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5594277188168999, 'bootstrap_features': False}
# 	Score: 0.875898953904
# 	Best score: 0.880878272999
#
# Interation no.:  73
# Training with params :
# {'warm_start': True, 'max_samples': 0.9111812321754694, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5119297471077846, 'bootstrap_features': False}
# 	Score: 0.878086363484
# 	Best score: 0.880878272999
#
# Interation no.:  74
# Training with params :
# {'warm_start': True, 'max_samples': 0.8871854152210703, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5630954176411809, 'bootstrap_features': False}
# 	Score: 0.878022602846
# 	Best score: 0.880878272999
#
# Interation no.:  75
# Training with params :
# {'warm_start': True, 'max_samples': 0.882180931223793, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.5465058413852744, 'bootstrap_features': False}
# 	Score: 0.878985493739
# 	Best score: 0.880878272999
#
# Interation no.:  76
# Training with params :
# {'warm_start': True, 'max_samples': 0.8760254437287908, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5526659655825706, 'bootstrap_features': False}
# 	Score: 0.876451773279
# 	Best score: 0.880878272999
#
# Interation no.:  77
# Training with params :
# {'warm_start': True, 'max_samples': 0.9018963585004082, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5380558962068182, 'bootstrap_features': True}
# 	Score: 0.870880434348
# 	Best score: 0.880878272999
#
# Interation no.:  78
# Training with params :
# {'warm_start': True, 'max_samples': 0.9068791641611788, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5678640599031661, 'bootstrap_features': False}
# 	Score: 0.874172671353
# 	Best score: 0.880878272999
#
# Interation no.:  79
# Training with params :
# {'warm_start': True, 'max_samples': 0.927458659795706, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.5201377188570018, 'bootstrap_features': False}
# 	Score: 0.872801937029
# 	Best score: 0.880878272999
#
# Interation no.:  80
# Training with params :
# {'warm_start': True, 'max_samples': 0.8918391445618924, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5295475093993146, 'bootstrap_features': True}
# 	Score: 0.879398259242
# 	Best score: 0.880878272999
#
# Interation no.:  81
# Training with params :
# {'warm_start': True, 'max_samples': 0.9166422571708721, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.5339568224763225, 'bootstrap_features': False}
# 	Score: 0.868891720305
# 	Best score: 0.880878272999
#
# Interation no.:  82
# Training with params :
# {'warm_start': True, 'max_samples': 0.8895072365908205, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.5419968562911736, 'bootstrap_features': True}
# 	Score: 0.873459748751
# 	Best score: 0.880878272999
#
# Interation no.:  83
# Training with params :
# {'warm_start': True, 'max_samples': 0.9100607268862569, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.5490818225754679, 'bootstrap_features': False}
# 	Score: 0.857038689593
# 	Best score: 0.880878272999
#
# Interation no.:  84
# Training with params :
# {'warm_start': True, 'max_samples': 0.8965675735746058, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.5738050207587659, 'bootstrap_features': True}
# 	Score: 0.878867525354
# 	Best score: 0.880878272999
#
# Interation no.:  85
# Training with params :
# {'warm_start': True, 'max_samples': 0.8847022557766128, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.5569985909813469, 'bootstrap_features': False}
# 	Score: 0.877641760464
# 	Best score: 0.880878272999
#
# Interation no.:  86
# Training with params :
# {'warm_start': True, 'max_samples': 0.898726380836005, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5538241967077392, 'bootstrap_features': True}
# 	Score: 0.868980217425
# 	Best score: 0.880878272999
#
# Interation no.:  87
# Training with params :
# {'warm_start': True, 'max_samples': 0.8788439439382262, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5632360105921597, 'bootstrap_features': False}
# 	Score: 0.87831161709
# 	Best score: 0.880878272999
#
# Interation no.:  88
# Training with params :
# {'warm_start': True, 'max_samples': 0.9398479363992291, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5315568308977296, 'bootstrap_features': True}
# 	Score: 0.87386439878
# 	Best score: 0.880878272999
#
# Interation no.:  89
# Training with params :
# {'warm_start': True, 'max_samples': 0.9134692391083111, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5042297148492934, 'bootstrap_features': False}
# 	Score: 0.876177174962
# 	Best score: 0.880878272999
#
# Interation no.:  90
# Training with params :
# {'warm_start': True, 'max_samples': 0.9201014993427011, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5447501314760465, 'bootstrap_features': True}
# 	Score: 0.872457147701
# 	Best score: 0.880878272999
#
# Interation no.:  91
# Training with params :
# {'warm_start': True, 'max_samples': 0.9032494519319276, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.5484496561734589, 'bootstrap_features': False}
# 	Score: 0.877242758842
# 	Best score: 0.880878272999
#
# Interation no.:  92
# Training with params :
# {'warm_start': True, 'max_samples': 0.8946000237599974, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5510022804212459, 'bootstrap_features': False}
# 	Score: 0.877538766338
# 	Best score: 0.880878272999
#
# Interation no.:  93
# Training with params :
# {'warm_start': True, 'max_samples': 0.8877584888330761, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5261242605738604, 'bootstrap_features': True}
# 	Score: 0.878982205369
# 	Best score: 0.880878272999
#
# Interation no.:  94
# Training with params :
# {'warm_start': True, 'max_samples': 0.9077594076630023, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5707139499631554, 'bootstrap_features': False}
# 	Score: 0.877730691797
# 	Best score: 0.880878272999
#
# Interation no.:  95
# Training with params :
# {'warm_start': True, 'max_samples': 0.8578748999628085, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.5589775845921762, 'bootstrap_features': True}
# 	Score: 0.865004275203
# 	Best score: 0.880878272999
#
# Interation no.:  96
# Training with params :
# {'warm_start': True, 'max_samples': 0.9324408367980439, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5360250725461059, 'bootstrap_features': False}
# 	Score: 0.873920612005
# 	Best score: 0.880878272999
#
# Interation no.:  97
# Training with params :
# {'warm_start': True, 'max_samples': 0.8644975930668525, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.561614988908188, 'bootstrap_features': True}
# 	Score: 0.877280995873
# 	Best score: 0.880878272999
#
# Interation no.:  98
# Training with params :
# {'warm_start': True, 'max_samples': 0.9169433370108905, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.5218079668545419, 'bootstrap_features': False}
# 	Score: 0.866229177316
# 	Best score: 0.880878272999
#
# Interation no.:  99
# Training with params :
# {'warm_start': True, 'max_samples': 0.935873472790976, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.5328651834115912, 'bootstrap_features': False}
# 	Score: 0.871209104118
# 	Best score: 0.880878272999
#
# Interation no.:  100
# Training with params :
# {'warm_start': True, 'max_samples': 0.8656382976284587, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.5282438544993904, 'bootstrap_features': True}
# 	Score: 0.865731209681
# 	Best score: 0.880878272999
#
# Interation no.:  101
# Training with params :
# {'warm_start': True, 'max_samples': 0.8717034580448977, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5390095076963358, 'bootstrap_features': False}
# 	Score: 0.877861561323
# 	Best score: 0.880878272999
#
# Interation no.:  102
# Training with params :
# {'warm_start': True, 'max_samples': 0.9001933935519422, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.4930053808816007, 'bootstrap_features': True}
# 	Score: 0.879148629372
# 	Best score: 0.880878272999
#
# Interation no.:  103
# Training with params :
# {'warm_start': True, 'max_samples': 0.9056441583105836, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.54125175804468, 'bootstrap_features': False}
# 	Score: 0.871684496514
# 	Best score: 0.880878272999
#
# Interation no.:  104
# Training with params :
# {'warm_start': True, 'max_samples': 0.882074754441835, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5462674615802964, 'bootstrap_features': False}
# 	Score: 0.874372411403
# 	Best score: 0.880878272999
#
# Interation no.:  105
# Training with params :
# {'warm_start': True, 'max_samples': 0.8767685913006972, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5167008207052121, 'bootstrap_features': True}
# 	Score: 0.877417839333
# 	Best score: 0.880878272999
#
# Interation no.:  106
# Training with params :
# {'warm_start': True, 'max_samples': 0.91246711937135, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.567106726274037, 'bootstrap_features': False}
# 	Score: 0.876698911698
# 	Best score: 0.880878272999
#
# Interation no.:  107
# Training with params :
# {'warm_start': True, 'max_samples': 0.9255197741419259, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5563804014838247, 'bootstrap_features': True}
# 	Score: 0.875935332137
# 	Best score: 0.880878272999
#
# Interation no.:  108
# Training with params :
# {'warm_start': True, 'max_samples': 0.8801772855813612, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.5527799234096854, 'bootstrap_features': False}
# 	Score: 0.876766331786
# 	Best score: 0.880878272999
#
# Interation no.:  109
# Training with params :
# {'warm_start': True, 'max_samples': 0.9032889450572942, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5436899026440948, 'bootstrap_features': False}
# 	Score: 0.873829209484
# 	Best score: 0.880878272999
#
# Interation no.:  110
# Training with params :
# {'warm_start': True, 'max_samples': 0.8843100558589474, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5614214390103495, 'bootstrap_features': True}
# 	Score: 0.878615137401
# 	Best score: 0.880878272999
#
# Interation no.:  111
# Training with params :
# {'warm_start': True, 'max_samples': 0.9296858573707831, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5144450404497256, 'bootstrap_features': False}
# 	Score: 0.873878001211
# 	Best score: 0.880878272999
#
# Interation no.:  112
# Training with params :
# {'warm_start': True, 'max_samples': 0.8903871458221604, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5355699198347593, 'bootstrap_features': False}
# 	Score: 0.874348249352
# 	Best score: 0.880878272999
#
# Interation no.:  113
# Training with params :
# {'warm_start': True, 'max_samples': 0.9233624628886077, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5185164439190991, 'bootstrap_features': True}
# 	Score: 0.877782711241
# 	Best score: 0.880878272999
#
# Interation no.:  114
# Training with params :
# {'warm_start': True, 'max_samples': 0.9096709906881784, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.529496366760378, 'bootstrap_features': False}
# 	Score: 0.879961220655
# 	Best score: 0.880878272999
#
# Interation no.:  115
# Training with params :
# {'warm_start': True, 'max_samples': 0.8928332694019198, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.5551544624732716, 'bootstrap_features': True}
# 	Score: 0.86329368347
# 	Best score: 0.880878272999
#
# Interation no.:  116
# Training with params :
# {'warm_start': True, 'max_samples': 0.9158182160505132, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.5232864589151857, 'bootstrap_features': False}
# 	Score: 0.872145108871
# 	Best score: 0.880878272999
#
# Interation no.:  117
# Training with params :
# {'warm_start': True, 'max_samples': 0.8518617019667304, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.5651392251545685, 'bootstrap_features': False}
# 	Score: 0.869653055418
# 	Best score: 0.880878272999
#
# Interation no.:  118
# Training with params :
# {'warm_start': True, 'max_samples': 0.8977746448997739, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.5473097916496208, 'bootstrap_features': True}
# 	Score: 0.877067928051
# 	Best score: 0.880878272999
#
# Interation no.:  119
# Training with params :
# {'warm_start': True, 'max_samples': 0.9211738285547635, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5780842291027951, 'bootstrap_features': False}
# 	Score: 0.876906746727
# 	Best score: 0.880878272999
#
# Interation no.:  120
# Training with params :
# {'warm_start': True, 'max_samples': 0.9276171665624591, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.5104853544059144, 'bootstrap_features': True}
# 	Score: 0.871486464941
# 	Best score: 0.880878272999
#
# Interation no.:  121
# Training with params :
# {'warm_start': True, 'max_samples': 0.8959720849330675, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5493708521693236, 'bootstrap_features': False}
# 	Score: 0.876387475899
# 	Best score: 0.880878272999
#
# Interation no.:  122
# Training with params :
# {'warm_start': True, 'max_samples': 0.860814956496356, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5752191697470336, 'bootstrap_features': False}
# 	Score: 0.877210744754
# 	Best score: 0.880878272999
#
# Interation no.:  123
# Training with params :
# {'warm_start': True, 'max_samples': 0.8943097481450017, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5407700104503603, 'bootstrap_features': True}
# 	Score: 0.877150479634
# 	Best score: 0.880878272999
#
# Interation no.:  124
# Training with params :
# {'warm_start': True, 'max_samples': 0.8878479554175551, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5372437484425119, 'bootstrap_features': False}
# 	Score: 0.8785702831
# 	Best score: 0.880878272999
#
# Interation no.:  125
# Training with params :
# {'warm_start': True, 'max_samples': 0.8736925759020744, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.5710037205212163, 'bootstrap_features': True}
# 	Score: 0.869394962522
# 	Best score: 0.880878272999
#
# Interation no.:  126
# Training with params :
# {'warm_start': True, 'max_samples': 0.9186908677526902, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5685061632513838, 'bootstrap_features': False}
# 	Score: 0.874985094509
# 	Best score: 0.880878272999
#
# Interation no.:  127
# Training with params :
# {'warm_start': True, 'max_samples': 0.9076063298080114, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5432626515285769, 'bootstrap_features': False}
# 	Score: 0.877453233127
# 	Best score: 0.880878272999
#
# Interation no.:  128
# Training with params :
# {'warm_start': True, 'max_samples': 0.905538855595856, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.525830548964595, 'bootstrap_features': True}
# 	Score: 0.87623149442
# 	Best score: 0.880878272999
#
# Interation no.:  129
# Training with params :
# {'warm_start': True, 'max_samples': 0.8704238729449846, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5209670413980098, 'bootstrap_features': False}
# 	Score: 0.875142002244
# 	Best score: 0.880878272999
#
# Interation no.:  130
# Training with params :
# {'warm_start': True, 'max_samples': 0.9022660958670525, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 130, 'random_state': 10, 'max_features': 0.5581075159954537, 'bootstrap_features': True}
# 	Score: 0.872442630425
# 	Best score: 0.880878272999
#
# Interation no.:  131
# Training with params :
# {'warm_start': True, 'max_samples': 0.9108970897736433, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.5394437286062516, 'bootstrap_features': False}
# 	Score: 0.876608969848
# 	Best score: 0.880878272999
#
# Interation no.:  132
# Training with params :
# {'warm_start': True, 'max_samples': 0.8996452165132811, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.5510571068063723, 'bootstrap_features': False}
# 	Score: 0.869912553751
# 	Best score: 0.880878272999
#
# Interation no.:  133
# Training with params :
# {'warm_start': True, 'max_samples': 0.9371327443699342, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.5314298428298061, 'bootstrap_features': True}
# 	Score: 0.853564483503
# 	Best score: 0.880878272999
#
# Interation no.:  134
# Training with params :
# {'warm_start': True, 'max_samples': 0.9136176725789659, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.5344384591493017, 'bootstrap_features': False}
# 	Score: 0.865261811766
# 	Best score: 0.880878272999
#
# Interation no.:  135
# Training with params :
# {'warm_start': True, 'max_samples': 0.9299738598222947, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5628907184993395, 'bootstrap_features': True}
# 	Score: 0.871797993705
# 	Best score: 0.880878272999
#
# Interation no.:  136
# Training with params :
# {'warm_start': True, 'max_samples': 0.8907966539758118, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.5538962580842319, 'bootstrap_features': False}
# 	Score: 0.875761712258
# 	Best score: 0.880878272999
#
# Interation no.:  137
# Training with params :
# {'warm_start': True, 'max_samples': 0.8830035318694724, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.49864598619406764, 'bootstrap_features': False}
# 	Score: 0.877760991038
# 	Best score: 0.880878272999
#
# Interation no.:  138
# Training with params :
# {'warm_start': True, 'max_samples': 0.8668971537502249, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5445904981284162, 'bootstrap_features': True}
# 	Score: 0.874875666898
# 	Best score: 0.880878272999
#
# Interation no.:  139
# ...
# Training with params :
# {'warm_start': True, 'max_samples': 0.9093173789810154, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5270359435833942, 'bootstrap_features': False}
# 	Score: 0.872700707547
# 	Best score: 0.882369878763
#
# Interation no.:  957
# Training with params :
# {'warm_start': True, 'max_samples': 0.9019180712928859, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5328594362824238, 'bootstrap_features': False}
# 	Score: 0.876962808989
# 	Best score: 0.882369878763
#
# Interation no.:  958
# Training with params :
# {'warm_start': True, 'max_samples': 0.9007022487484936, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5460416202157993, 'bootstrap_features': False}
# 	Score: 0.877792485401
# 	Best score: 0.882369878763
#
# Interation no.:  959
# Training with params :
# {'warm_start': True, 'max_samples': 0.8926683595536328, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.5395228821467642, 'bootstrap_features': False}
# 	Score: 0.871884508307
# 	Best score: 0.882369878763
#
# Interation no.:  960
# Training with params :
# {'warm_start': True, 'max_samples': 0.9053410281832317, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5445133718992543, 'bootstrap_features': False}
# 	Score: 0.878313435183
# 	Best score: 0.882369878763
#
# Interation no.:  961
# Training with params :
# {'warm_start': True, 'max_samples': 0.9111746487382225, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.5513726795922641, 'bootstrap_features': False}
# 	Score: 0.877338401708
# 	Best score: 0.882369878763
#
# Interation no.:  962
# Training with params :
# {'warm_start': True, 'max_samples': 0.8959028361388928, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.5376284632521335, 'bootstrap_features': False}
# 	Score: 0.874607919392
# 	Best score: 0.882369878763
#
# Interation no.:  963
# Training with params :
# {'warm_start': True, 'max_samples': 0.9187142484982116, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5299423369586682, 'bootstrap_features': False}
# 	Score: 0.878114541867
# 	Best score: 0.882369878763
#
# Interation no.:  964
# Training with params :
# {'warm_start': True, 'max_samples': 0.9079435243669075, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.5356474276555033, 'bootstrap_features': False}
# 	Score: 0.861932842069
# 	Best score: 0.882369878763
#
# Interation no.:  965
# Training with params :
# {'warm_start': True, 'max_samples': 0.9027660000203368, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5480516271546672, 'bootstrap_features': False}
# 	Score: 0.87831925495
# 	Best score: 0.882369878763
#
# Interation no.:  966
# Training with params :
# {'warm_start': True, 'max_samples': 0.8983799941631807, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.5409038005916844, 'bootstrap_features': False}
# 	Score: 0.872314298067
# 	Best score: 0.882369878763
#
# Interation no.:  967
# Training with params :
# {'warm_start': True, 'max_samples': 0.900495474972014, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5454332622527032, 'bootstrap_features': False}
# 	Score: 0.875050284602
# 	Best score: 0.882369878763
#
# Interation no.:  968
# Training with params :
# {'warm_start': True, 'max_samples': 0.9137581209132172, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5499346242566951, 'bootstrap_features': False}
# 	Score: 0.878162175383
# 	Best score: 0.882369878763
#
# Interation no.:  969
# Training with params :
# {'warm_start': True, 'max_samples': 0.9351245191600769, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5572929080434622, 'bootstrap_features': False}
# 	Score: 0.878304396207
# 	Best score: 0.882369878763
#
# Interation no.:  970
# Training with params :
# {'warm_start': True, 'max_samples': 0.9096179541900785, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5535387909272497, 'bootstrap_features': False}
# 	Score: 0.879736176292
# 	Best score: 0.882369878763
#
# Interation no.:  971
# Training with params :
# {'warm_start': True, 'max_samples': 0.9067846106929868, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5307966501554567, 'bootstrap_features': False}
# 	Score: 0.877641747396
# 	Best score: 0.882369878763
#
# Interation no.:  972
# Training with params :
# {'warm_start': True, 'max_samples': 0.894455448202079, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5431999490361379, 'bootstrap_features': False}
# 	Score: 0.878054217183
# 	Best score: 0.882369878763
#
# Interation no.:  973
# Training with params :
# {'warm_start': True, 'max_samples': 0.9167814346362225, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.4948856130155104, 'bootstrap_features': False}
# 	Score: 0.878410329266
# 	Best score: 0.882369878763
#
# Interation no.:  974
# Training with params :
# {'warm_start': True, 'max_samples': 0.9039898669568726, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.547057594265284, 'bootstrap_features': False}
# 	Score: 0.878536754526
# 	Best score: 0.882369878763
#
# Interation no.:  975
# Training with params :
# {'warm_start': True, 'max_samples': 0.9265753961763835, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5052599194440911, 'bootstrap_features': False}
# 	Score: 0.87383284
# 	Best score: 0.882369878763
#
# Interation no.:  976
# Training with params :
# {'warm_start': True, 'max_samples': 0.8973767065972752, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.5636876963045062, 'bootstrap_features': False}
# 	Score: 0.873619631003
# 	Best score: 0.882369878763
#
# Interation no.:  977
# Training with params :
# {'warm_start': True, 'max_samples': 0.8915159596442893, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.538448565269523, 'bootstrap_features': False}
# 	Score: 0.877070761757
# 	Best score: 0.882369878763
#
# Interation no.:  978
# Training with params :
# {'warm_start': True, 'max_samples': 0.9059017716395844, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5333091534727079, 'bootstrap_features': False}
# 	Score: 0.880243856239
# 	Best score: 0.882369878763
#
# Interation no.:  979
# Training with params :
# {'warm_start': True, 'max_samples': 0.8997742463334796, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5404823897356755, 'bootstrap_features': False}
# 	Score: 0.876867384149
# 	Best score: 0.882369878763
#
# Interation no.:  980
# Training with params :
# {'warm_start': True, 'max_samples': 0.9125954930022424, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 20, 'random_state': 10, 'max_features': 0.5489675002108985, 'bootstrap_features': False}
# 	Score: 0.869587555325
# 	Best score: 0.882369878763
#
# Interation no.:  981
# Training with params :
# {'warm_start': True, 'max_samples': 0.9025495664303208, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5556812519340639, 'bootstrap_features': False}
# 	Score: 0.878280928816
# 	Best score: 0.882369878763
#
# Interation no.:  982
# Training with params :
# {'warm_start': True, 'max_samples': 0.9151158680581063, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 60, 'random_state': 10, 'max_features': 0.5523124598194326, 'bootstrap_features': False}
# 	Score: 0.873844737816
# 	Best score: 0.882369878763
#
# Interation no.:  983
# Training with params :
# {'warm_start': True, 'max_samples': 0.9078465417811231, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5351984542151673, 'bootstrap_features': False}
# 	Score: 0.879435909755
# 	Best score: 0.882369878763
#
# Interation no.:  984
# Training with params :
# {'warm_start': True, 'max_samples': 0.895706909804495, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 30, 'random_state': 10, 'max_features': 0.5425641293946638, 'bootstrap_features': False}
# 	Score: 0.870434539711
# 	Best score: 0.882369878763
#
# Interation no.:  985
# Training with params :
# {'warm_start': True, 'max_samples': 0.8928810694650215, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 10, 'random_state': 10, 'max_features': 0.5573883812886303, 'bootstrap_features': False}
# 	Score: 0.867080221724
# 	Best score: 0.882369878763
#
# Interation no.:  986
# Training with params :
# {'warm_start': True, 'max_samples': 0.9043840879174039, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5453207616257869, 'bootstrap_features': False}
# 	Score: 0.872978752601
# 	Best score: 0.882369878763
#
# Interation no.:  987
# Training with params :
# {'warm_start': True, 'max_samples': 0.9091010877413096, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 50, 'random_state': 10, 'max_features': 0.5511294662745808, 'bootstrap_features': False}
# 	Score: 0.871714642796
# 	Best score: 0.882369878763
#
# Interation no.:  988
# Training with params :
# {'warm_start': True, 'max_samples': 0.9106357026065377, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5543650414326969, 'bootstrap_features': False}
# 	Score: 0.876817347506
# 	Best score: 0.882369878763
#
# Interation no.:  989
# Training with params :
# {'warm_start': True, 'max_samples': 0.9001489592182839, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5468491024964296, 'bootstrap_features': False}
# 	Score: 0.878189185075
# 	Best score: 0.882369878763
#
# Interation no.:  990
# Training with params :
# {'warm_start': True, 'max_samples': 0.9182610866424858, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5418395135120442, 'bootstrap_features': False}
# 	Score: 0.879849305002
# 	Best score: 0.882369878763
#
# Interation no.:  991
# Training with params :
# {'warm_start': True, 'max_samples': 0.8975529446659034, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5437626472614314, 'bootstrap_features': False}
# 	Score: 0.881001335597
# 	Best score: 0.882369878763
#
# Interation no.:  992
# Training with params :
# {'warm_start': True, 'max_samples': 0.8926336754825049, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 70, 'random_state': 10, 'max_features': 0.5280170398148076, 'bootstrap_features': False}
# 	Score: 0.877569733429
# 	Best score: 0.882369878763
#
# Interation no.:  993
# Training with params :
# {'warm_start': True, 'max_samples': 0.890800651047505, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 100, 'random_state': 10, 'max_features': 0.5321026117341779, 'bootstrap_features': False}
# 	Score: 0.878361938057
# 	Best score: 0.882369878763
#
# Interation no.:  994
# Training with params :
# {'warm_start': True, 'max_samples': 0.8939019085207631, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.53427191449017, 'bootstrap_features': False}
# 	Score: 0.878555045597
# 	Best score: 0.882369878763
#
# Interation no.:  995
# Training with params :
# {'warm_start': True, 'max_samples': 0.8961714492001633, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 90, 'random_state': 10, 'max_features': 0.5372554067328392, 'bootstrap_features': False}
# 	Score: 0.878409917289
# 	Best score: 0.882369878763
#
# Interation no.:  996
# Training with params :
# {'warm_start': True, 'max_samples': 0.8977394340841699, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': True, 'oob_score': False, 'n_estimators': 80, 'random_state': 10, 'max_features': 0.5401848224126256, 'bootstrap_features': False}
# 	Score: 0.870490804808
# 	Best score: 0.882369878763
#
# Interation no.:  997
# Training with params :
# {'warm_start': True, 'max_samples': 0.8921732482524666, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 120, 'random_state': 10, 'max_features': 0.5248559190894558, 'bootstrap_features': False}
# 	Score: 0.878739671315
# 	Best score: 0.882369878763
#
# Interation no.:  998
# Training with params :
# {'warm_start': True, 'max_samples': 0.8947254883050486, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5438885471185614, 'bootstrap_features': False}
# 	Score: 0.877892988253
# 	Best score: 0.882369878763
#
# Interation no.:  999
# Training with params :
# {'warm_start': True, 'max_samples': 0.8905167254307655, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 140, 'random_state': 10, 'max_features': 0.5363669533912714, 'bootstrap_features': False}
# 	Score: 0.875826525452
# 	Best score: 0.882369878763
#
# Interation no.:  1000
# Training with params :
# {'warm_start': True, 'max_samples': 0.89812997922701, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 40, 'random_state': 10, 'max_features': 0.5386575844362637, 'bootstrap_features': False}
# 	Score: 0.874100593436
# 	Best score: 0.882369878763
#
# Best parameters:
# {'warm_start': True, 'max_samples': 0.9030810827110213, 'base_estimator': None, 'n_jobs': 1, 'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10, 'max_features': 0.5351477142010489, 'bootstrap_features': False}
# 	Score 0.882369878763

# %%
params = {'warm_start': True, 'max_samples': 0.9030810827110213, 'base_estimator': None, 'n_jobs': 1,
          'verbose': 0, 'bootstrap': False, 'oob_score': False, 'n_estimators': 110, 'random_state': 10,
          'max_features': 0.5351477142010489, 'bootstrap_features': False}
reg1 = BaggingRegressor(
                        n_estimators = params['n_estimators'],
                        max_samples = params['max_samples'],
                        max_features = params['max_features'],
                        bootstrap = params['bootstrap'],
                        bootstrap_features = params['bootstrap_features'],
                        oob_score = params['oob_score'],
                        base_estimator = params['base_estimator'],
                        warm_start = params['warm_start'],
                        verbose = params['verbose'],
                        n_jobs = params['n_jobs'],
                        random_state = params['random_state']  
                        )
modelfit(reg1, X_train, y_train)
# Out:
# Model Report
# Train_coef_of_det: 0.998682
# CV_coef_of_det: Mean-0.882370 | Std-0.036003 | Min-0.783940 | Max-0.911897

# %% [markdown]
# ### Grid search + Genetic programming ( 'sklearn-deap' package )

# %%
params = {
          'n_estimators': range(10,150,10),
          'max_samples': [i/100.0 for i in range(85,94)],
          'max_features': [i/100.0 for i in range(49,58)],
          'bootstrap': [True,False],
          'bootstrap_features': [True,False],
          'oob_score': [False],
          'base_estimator': [None],
          'warm_start': [True],
          'verbose': [0],
          'n_jobs': [1],
          'random_state': [10]
         }
evol = EvolutionaryAlgorithmSearchCV(estimator=BaggingRegressor(), params=params, cv=10,
        scoring='r2', population_size=50, gene_mutation_prob=0.1, gene_crossover_prob=0.5, tournament_size=3,
        generations_number=10, verbose=True, n_jobs=-1)
evol.fit(X_train, y_train)

# %%
params = {}
reg1 = BaggingRegressor(
                        n_estimators = params['n_estimators'],
                        max_samples = params['max_samples'],
                        max_features = params['max_features'],
                        bootstrap = params['bootstrap'],
                        bootstrap_features = params['bootstrap_features'],
                        oob_score = params['oob_score'],
                        base_estimator = params['base_estimator'],
                        warm_start = params['warm_start'],
                        verbose = params['verbose'],
                        n_jobs = params['n_jobs'],
                        random_state = params['random_state']  
                        )
modelfit(reg1, X_train, y_train)

# %% [markdown]
# ### Make predictions and save results

# %%
test_pred = reg1.predict(X_test)
dictn = {'Id': range(1461,2920), 'SalePrice': test_pred}
res = pd.DataFrame(dictn)
res.to_csv('submission.csv', index=0)
