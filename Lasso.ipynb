# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from evolutionary_search import EvolutionaryAlgorithmSearchCV
from hyperopt import fmin, tpe, hp, STATUS_OK
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from sklearn.linear_model import Lasso

# %% [markdown]
# ## Step I. Load data

# %%
train = pd.read_csv('train.csv')
X_test = pd.read_csv('X_test.csv')

X_train = train.iloc[:, :-1]
y_train = train.iloc[:, -1]

# %% [markdown]
# ## Step II. Buid the model and perform parameter tuning

# %%
def modelfit(reg, train, target, performCV=True, cv=10):
    reg.fit(train, target)
    pred = reg.predict(train)
    train_r2_score = r2_score(target, pred)
    
    print('\nModel Report')
    print('Train_coef_of_det: %0.6f' %(train_r2_score))
    
    if performCV:
        cv_r2_score = cross_val_score(reg, train, target, cv=cv, scoring='r2', n_jobs=-1)
        print('CV_coef_of_det: Mean-%0.6f | Std-%0.6f | Min-%0.6f | Max-%0.6f' %(np.mean(cv_r2_score),
            np.std(cv_r2_score), np.min(cv_r2_score), np.max(cv_r2_score)))

# %% [markdown]
# ### Baseline model

# %%
params = {}
grid = GridSearchCV(estimator=Lasso(), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.670725327931
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
params = {}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, fit_intercept=True, normalize=False, precompute=False,
        copy_X=True, max_iter=1000, tol=0.0001, warm_start=False, positive=False, random_state=10,
        selection='cyclic'), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.670725327931

# %% [markdown]
# ### Grid search

# %%
params = {}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=1000, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.670725327931

# %%
params = {'alpha': [i/10.0 for i in range(0,11)]}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=1000, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'alpha': 1.0}
# 0.670725327931
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)

# %%
params = {'alpha': [i/100.0 for i in range(94,101)]}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=1000, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'alpha': 1.0}
# 0.670725327931

# %%
params = {'alpha': [i/1000.0 for i in range(994,1001)]}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=1000, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'alpha': 1.0}
# 0.670725327931

# %%
params = {'max_iter': range(100,1500,100)}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=1000, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_iter': 100}
# 0.732982750274

# %%
params = {'max_iter': range(10,110,10)}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=1000, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_iter': 20}
# 0.787268529354

# %%
params = {'max_iter': range(1,35)}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=1000, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_iter': 23}
# 0.788266176706

# %%
params = {'tol': [10**(-i) for i in range(0,10)]}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=23, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'tol': 0.01}
# 0.788266176706

# %%
params = {'tol': [i*10**(-3) for i in range(1,101,10)]}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=23, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'tol': 0.001}
# 0.788266176706

# %%
params = {'normalize': [True,False]}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=23, tol=0.0001, normalize=False, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'normalize': True}
# 0.795430637438

# %%
params = {'precompute': [True,False]}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=23, tol=0.0001, normalize=True, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'precompute': False}
# 0.795430637438

# %%
params = {'positive': [True,False]}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=23, tol=0.0001, normalize=True, precompute=False,
        positive=False, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'positive': True}
# 0.799567305028

# %%
params = {'selection': ['cyclic','random']}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=23, tol=0.0001, normalize=True, precompute=False,
        positive=True, selection='cyclic', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'selection': 'random'}
# 0.811286740112

# %% [markdown]
# ### Final model

# %%
params = {}
grid = GridSearchCV(estimator=Lasso(alpha=1.0, max_iter=23, tol=0.0001, normalize=True, precompute=False,
        positive=True, selection='random', fit_intercept=True, copy_X=True, warm_start=False, random_state=10),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.811286740112

# %%
reg1 = Lasso(alpha=1.0, max_iter=23, tol=0.0001, normalize=True, precompute=False,
        positive=True, selection='random', fit_intercept=True, copy_X=True, warm_start=False, random_state=10)
modelfit(reg1, X_train, y_train)
# Out:
# Model Report
# Train_coef_of_det: 0.889393
# CV_coef_of_det: Mean-0.811287 | Std-0.128790 | Min-0.439899 | Max-0.897706

# %% [markdown]
# ### Grid search + Random search

# %%
params = {
        'alpha': [i/1000.0 for i in range(970,1001)],
        'max_iter': range(1,50),
        'tol': [i*10**(-3) for i in range(1,101,10)],
        'normalize': [True,False],
        'precompute': [True,False],
        'positive': [True,False],
        'selection': ['cyclic','random'],
        'fit_intercept': [True],
        'copy_X': [True],
        'warm_start': [False],
        'random_state': [10]    
         }
rand = RandomizedSearchCV(estimator=Lasso(), param_distributions=params, cv=10, scoring='r2',
         n_iter=1000, random_state=10, n_jobs=-1)
rand.fit(X_train, y_train)
print 'Best parameters: \n', rand.best_params_
print '\tBest score: ', rand.best_score_

# %%
params = {}
reg1 = Lasso(
            alpha = params['alpha'],
            max_iter = params['max_iter'],
            tol = params['tol'],
            normalize = params['normalize'],
            precompute = params['precompute'],
            positive = params['positive'],
            selection = params['selection'],
            fit_intercept = params['fit_intercept'],
            copy_X = params['copy_X'],
            warm_start = params['warm_start'],
            random_state = params['random_state']
            )
modelfit(reg1, X_train, y_train)

# %% [markdown]
# ### Grid search + Bayesian optimization ( 'hyperopt' package)

# %%
min_score = float('inf')
best_params = ''
c = 0

def score(params):
    global c, min_score, best_params
    c += 1
    print "Interation no.: ", c
    print "Training with params : "
    print params
    reg = Lasso(
                alpha = params['alpha'],
                max_iter = params['max_iter'],
                tol = params['tol'],
                normalize = params['normalize'],
                precompute = params['precompute'],
                positive = params['positive'],
                selection = params['selection'],
                fit_intercept = params['fit_intercept'],
                copy_X = params['copy_X'],
                warm_start = params['warm_start'],
                random_state = params['random_state']     
                )
    cv_r2_score = cross_val_score(reg, X_train, y_train, cv=10, scoring='r2', n_jobs=-1)
    score = 1 - np.mean(cv_r2_score) 
    if score < min_score:
        min_score = score
        best_params = params     
    print "\tScore: {0}".format(1-score)
    print "\tBest score: {0}\n".format(1-min_score)
    return {'loss': score, 'status': STATUS_OK}

def optimize():
    space = {
            'alpha': hp.uniform('alpha', 0.97, 1.0),
            'max_iter': hp.choice('max_iter', range(1,50)),
            'tol': hp.uniform('tol', 1e-3, 1e-1),
            'normalize': hp.choice('normalize', [True,False]),
            'precompute': hp.choice('precompute', [True,False]),
            'positive': hp.choice('positive', [True,False]),
            'selection': hp.choice('selection', ['cyclic','random']),
            'fit_intercept': hp.choice('fit_intercept', [True]),
            'copy_X': hp.choice('copy_X', [True]),
            'warm_start': hp.choice('warm_start', [False]),
            'random_state': hp.choice('random_state', [10])   
             }
    best = fmin(score, space, algo=tpe.suggest, max_evals=1000)    
  
optimize()
print 'Best parameters:'
print best_params
print "\tScore {0}".format(1-min_score)
# Out:
# Interation no.:  1
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 13, 'precompute': False, 'random_state': 10, 'tol': 0.04100205665259572, 'copy_X': True, 'alpha': 0.9894250222328214}
# 	Score: 0.798818310311
# 	Best score: 0.798818310311
#
# Interation no.:  2
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 32, 'precompute': False, 'random_state': 10, 'tol': 0.07335443863395796, 'copy_X': True, 'alpha': 0.978965728352693}
# 	Score: 0.806432664625
# 	Best score: 0.806432664625
#
# Interation no.:  3
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 29, 'precompute': False, 'random_state': 10, 'tol': 0.02425245433084651, 'copy_X': True, 'alpha': 0.9702652929642331}
# 	Score: 0.794380117182
# 	Best score: 0.806432664625
#
# Interation no.:  4
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 29, 'precompute': False, 'random_state': 10, 'tol': 0.05811190889422529, 'copy_X': True, 'alpha': 0.9888442721994594}
# 	Score: 0.808946448994
# 	Best score: 0.808946448994
#
# Interation no.:  5
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 24, 'precompute': False, 'random_state': 10, 'tol': 0.038399282399977794, 'copy_X': True, 'alpha': 0.9899881731126292}
# 	Score: 0.80774197906
# 	Best score: 0.808946448994
#
# Interation no.:  6
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 10, 'precompute': False, 'random_state': 10, 'tol': 0.08189127189050541, 'copy_X': True, 'alpha': 0.991525090714678}
# 	Score: 0.798725872438
# 	Best score: 0.808946448994
#
# Interation no.:  7
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 39, 'precompute': False, 'random_state': 10, 'tol': 0.06657836401458958, 'copy_X': True, 'alpha': 0.9961968367273049}
# 	Score: 0.801875368913
# 	Best score: 0.808946448994
#
# Interation no.:  8
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 32, 'precompute': True, 'random_state': 10, 'tol': 0.06032594958028824, 'copy_X': True, 'alpha': 0.9779003816358981}
# 	Score: 0.807454258043
# 	Best score: 0.808946448994
#
# Interation no.:  9
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 41, 'precompute': True, 'random_state': 10, 'tol': 0.03215973348652882, 'copy_X': True, 'alpha': 0.9751043981842147}
# 	Score: 0.77660674893
# 	Best score: 0.808946448994
#
# Interation no.:  10
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 16, 'precompute': True, 'random_state': 10, 'tol': 0.06305328067845105, 'copy_X': True, 'alpha': 0.979409443454404}
# 	Score: 0.801859522711
# 	Best score: 0.808946448994
#
# Interation no.:  11
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 47, 'precompute': True, 'random_state': 10, 'tol': 0.045718779189499716, 'copy_X': True, 'alpha': 0.9779291062250396}
# 	Score: 0.78205375334
# 	Best score: 0.808946448994
#
# Interation no.:  12
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 23, 'precompute': True, 'random_state': 10, 'tol': 0.04066652898119648, 'copy_X': True, 'alpha': 0.9822406118360202}
# 	Score: 0.786794204219
# 	Best score: 0.808946448994
#
# Interation no.:  13
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 33, 'precompute': False, 'random_state': 10, 'tol': 0.045674957982053004, 'copy_X': True, 'alpha': 0.994937022843505}
# 	Score: 0.804024928337
# 	Best score: 0.808946448994
#
# Interation no.:  14
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 3, 'precompute': True, 'random_state': 10, 'tol': 0.026378101094020133, 'copy_X': True, 'alpha': 0.9907346218327128}
# 	Score: 0.774565515851
# 	Best score: 0.808946448994
#
# Interation no.:  15
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 15, 'precompute': True, 'random_state': 10, 'tol': 0.07188371384790482, 'copy_X': True, 'alpha': 0.9746661905761791}
# 	Score: 0.808864708139
# 	Best score: 0.808946448994
#
# Interation no.:  16
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 30, 'precompute': False, 'random_state': 10, 'tol': 0.07668692246031208, 'copy_X': True, 'alpha': 0.9722883360162954}
# 	Score: 0.809243443191
# 	Best score: 0.809243443191
#
# Interation no.:  17
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 12, 'precompute': True, 'random_state': 10, 'tol': 0.0929898108994921, 'copy_X': True, 'alpha': 0.9833766348911179}
# 	Score: 0.799061377418
# 	Best score: 0.809243443191
#
# Interation no.:  18
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 30, 'precompute': False, 'random_state': 10, 'tol': 0.06387136939943867, 'copy_X': True, 'alpha': 0.9864468773512896}
# 	Score: 0.799822277244
# 	Best score: 0.809243443191
#
# Interation no.:  19
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 26, 'precompute': False, 'random_state': 10, 'tol': 0.07665159125866627, 'copy_X': True, 'alpha': 0.9988025983771429}
# 	Score: 0.809272741756
# 	Best score: 0.809272741756
#
# Interation no.:  20
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 4, 'precompute': False, 'random_state': 10, 'tol': 0.028634580261096516, 'copy_X': True, 'alpha': 0.9790465551886597}
# 	Score: 0.77303534894
# 	Best score: 0.809272741756
#
# Interation no.:  21
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 14, 'precompute': False, 'random_state': 10, 'tol': 0.09907471090007725, 'copy_X': True, 'alpha': 0.9990009131596272}
# 	Score: 0.810004945379
# 	Best score: 0.810004945379
#
# Interation no.:  22
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 26, 'precompute': False, 'random_state': 10, 'tol': 0.0985145757711966, 'copy_X': True, 'alpha': 0.9990991176065709}
# 	Score: 0.810005069669
# 	Best score: 0.810005069669
#
# Interation no.:  23
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 22, 'precompute': False, 'random_state': 10, 'tol': 0.0048660746678939465, 'copy_X': True, 'alpha': 0.9993910347440914}
# 	Score: 0.8116436327
# 	Best score: 0.8116436327
#
# Interation no.:  24
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 9, 'precompute': False, 'random_state': 10, 'tol': 0.010392757921847386, 'copy_X': True, 'alpha': 0.994771132862776}
# 	Score: 0.810725725125
# 	Best score: 0.8116436327
#
# Interation no.:  25
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 9, 'precompute': False, 'random_state': 10, 'tol': 0.0013682325383039332, 'copy_X': True, 'alpha': 0.9948403934654617}
# 	Score: 0.81072580874
# 	Best score: 0.8116436327
#
# Interation no.:  26
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 22, 'precompute': False, 'random_state': 10, 'tol': 0.005122604474105684, 'copy_X': True, 'alpha': 0.9927166810817566}
# 	Score: 0.81162614331
# 	Best score: 0.8116436327
#
# Interation no.:  27
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 22, 'precompute': False, 'random_state': 10, 'tol': 0.013722220730554527, 'copy_X': True, 'alpha': 0.997109643863195}
# 	Score: 0.811637657786
# 	Best score: 0.8116436327
#
# Interation no.:  28
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 22, 'precompute': False, 'random_state': 10, 'tol': 0.013940274912082246, 'copy_X': True, 'alpha': 0.9972115895227978}
# 	Score: 0.811637924729
# 	Best score: 0.8116436327
#
# Interation no.:  29
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 36, 'precompute': False, 'random_state': 10, 'tol': 0.020245826534650666, 'copy_X': True, 'alpha': 0.9876719171516762}
# 	Score: 0.805636770317
# 	Best score: 0.8116436327
#
# Interation no.:  30
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 40, 'precompute': False, 'random_state': 10, 'tol': 0.014716287772626829, 'copy_X': True, 'alpha': 0.9927262108193946}
# 	Score: 0.801099155582
# 	Best score: 0.8116436327
#
# Interation no.:  31
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 2, 'precompute': False, 'random_state': 10, 'tol': 0.0037162526088414223, 'copy_X': True, 'alpha': 0.9977345783677856}
# 	Score: 0.751205712029
# 	Best score: 0.8116436327
#
# Interation no.:  32
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 34, 'precompute': False, 'random_state': 10, 'tol': 0.018988776468828614, 'copy_X': True, 'alpha': 0.985817102827844}
# 	Score: 0.806777901867
# 	Best score: 0.8116436327
#
# Interation no.:  33
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 25, 'precompute': False, 'random_state': 10, 'tol': 0.052761305442110024, 'copy_X': True, 'alpha': 0.999887518490064}
# 	Score: 0.80456187183
# 	Best score: 0.8116436327
#
# Interation no.:  34
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 22, 'precompute': False, 'random_state': 10, 'tol': 0.032333544700689165, 'copy_X': True, 'alpha': 0.993377348816816}
# 	Score: 0.803834212658
# 	Best score: 0.8116436327
#
# Interation no.:  35
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 46, 'precompute': False, 'random_state': 10, 'tol': 0.009562793088418465, 'copy_X': True, 'alpha': 0.9962208937468914}
# 	Score: 0.799698462367
# 	Best score: 0.8116436327
#
# Interation no.:  36
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 19, 'precompute': False, 'random_state': 10, 'tol': 0.021788871669705806, 'copy_X': True, 'alpha': 0.9896439678138945}
# 	Score: 0.811791498972
# 	Best score: 0.811791498972
#
# Interation no.:  37
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 19, 'precompute': False, 'random_state': 10, 'tol': 0.03647143386223767, 'copy_X': True, 'alpha': 0.9888714948064943}
# 	Score: 0.798149371847
# 	Best score: 0.811791498972
#
# Interation no.:  38
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 31, 'precompute': False, 'random_state': 10, 'tol': 0.021639104686408558, 'copy_X': True, 'alpha': 0.9821028448341567}
# 	Score: 0.807653694176
# 	Best score: 0.811791498972
#
# Interation no.:  39
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 42, 'precompute': False, 'random_state': 10, 'tol': 0.05626754087337683, 'copy_X': True, 'alpha': 0.9841448306091691}
# 	Score: 0.799829728918
# 	Best score: 0.811791498972
#
# Interation no.:  40
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 8, 'precompute': True, 'random_state': 10, 'tol': 0.006659574495085209, 'copy_X': True, 'alpha': 0.9879249541111041}
# 	Score: 0.793455267389
# 	Best score: 0.811791498972
#
# Interation no.:  41
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 21, 'precompute': False, 'random_state': 10, 'tol': 0.033432674886901534, 'copy_X': True, 'alpha': 0.9910547970651844}
# 	Score: 0.804175556335
# 	Best score: 0.811791498972
#
# Interation no.:  42
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 43, 'precompute': True, 'random_state': 10, 'tol': 0.0010770858684826848, 'copy_X': True, 'alpha': 0.9805330467773143}
# 	Score: 0.778896442978
# 	Best score: 0.811791498972
#
# Interation no.:  43
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 45, 'precompute': False, 'random_state': 10, 'tol': 0.0461360332721006, 'copy_X': True, 'alpha': 0.9900213473327264}
# 	Score: 0.796144547101
# 	Best score: 0.811791498972
#
# Interation no.:  44
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 7, 'precompute': False, 'random_state': 10, 'tol': 0.026123294664134943, 'copy_X': True, 'alpha': 0.9750112932938398}
# 	Score: 0.798954943454
# 	Best score: 0.811791498972
#
# Interation no.:  45
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 1, 'precompute': True, 'random_state': 10, 'tol': 0.0178250868029005, 'copy_X': True, 'alpha': 0.9708653645040954}
# 	Score: 0.644145006833
# 	Best score: 0.811791498972
#
# Interation no.:  46
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 18, 'precompute': False, 'random_state': 10, 'tol': 0.0413741225619723, 'copy_X': True, 'alpha': 0.9870573201919206}
# 	Score: 0.810100556667
# 	Best score: 0.811791498972
#
# Interation no.:  47
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 19, 'precompute': True, 'random_state': 10, 'tol': 0.08767210027397623, 'copy_X': True, 'alpha': 0.9764157494469785}
# 	Score: 0.810072404842
# 	Best score: 0.811791498972
#
# Interation no.:  48
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 44, 'precompute': False, 'random_state': 10, 'tol': 0.03002855049780096, 'copy_X': True, 'alpha': 0.9849066056812822}
# 	Score: 0.784790216517
# 	Best score: 0.811791498972
#
# Interation no.:  49
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 28, 'precompute': False, 'random_state': 10, 'tol': 0.009050371513832915, 'copy_X': True, 'alpha': 0.9938822259953973}
# 	Score: 0.808403303952
# 	Best score: 0.811791498972
#
# Interation no.:  50
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 11, 'precompute': True, 'random_state': 10, 'tol': 0.04894431716178637, 'copy_X': True, 'alpha': 0.9919680224914063}
# 	Score: 0.810452817357
# 	Best score: 0.811791498972
#
# Interation no.:  51
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 48, 'precompute': False, 'random_state': 10, 'tol': 0.023398307327064636, 'copy_X': True, 'alpha': 0.9896342729933642}
# 	Score: 0.781963875998
# 	Best score: 0.811791498972
#
# Interation no.:  52
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 20, 'precompute': False, 'random_state': 10, 'tol': 0.03650493825492786, 'copy_X': True, 'alpha': 0.9808081685350589}
# 	Score: 0.811317087419
# 	Best score: 0.811791498972
#
# Interation no.:  53
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 38, 'precompute': True, 'random_state': 10, 'tol': 0.04156179809183928, 'copy_X': True, 'alpha': 0.996112443797014}
# 	Score: 0.803951367843
# 	Best score: 0.811791498972
#
# Interation no.:  54
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 5, 'precompute': False, 'random_state': 10, 'tol': 0.06867508475828449, 'copy_X': True, 'alpha': 0.9727364364204748}
# 	Score: 0.804989014396
# 	Best score: 0.811791498972
#
# Interation no.:  55
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 49, 'precompute': False, 'random_state': 10, 'tol': 0.015915720278293508, 'copy_X': True, 'alpha': 0.9773187266990274}
# 	Score: 0.773169986109
# 	Best score: 0.811791498972
#
# Interation no.:  56
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 17, 'precompute': False, 'random_state': 10, 'tol': 0.0018074465070815346, 'copy_X': True, 'alpha': 0.9999250903261228}
# 	Score: 0.80533815567
# 	Best score: 0.811791498972
#
# Interation no.:  57
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 6, 'precompute': True, 'random_state': 10, 'tol': 0.01144418387663445, 'copy_X': True, 'alpha': 0.9828494138631454}
# 	Score: 0.804153483371
# 	Best score: 0.811791498972
#
# Interation no.:  58
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 35, 'precompute': False, 'random_state': 10, 'tol': 0.026595107194056465, 'copy_X': True, 'alpha': 0.9857492791320436}
# 	Score: 0.80575492734
# 	Best score: 0.811791498972
#
# Interation no.:  59
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 27, 'precompute': False, 'random_state': 10, 'tol': 0.054297205642600516, 'copy_X': True, 'alpha': 0.9980970516951391}
# 	Score: 0.801565117802
# 	Best score: 0.811791498972
#
# Interation no.:  60
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 24, 'precompute': False, 'random_state': 10, 'tol': 0.06153956576836428, 'copy_X': True, 'alpha': 0.9941169546572477}
# 	Score: 0.799822892665
# 	Best score: 0.811791498972
#
# Interation no.:  61
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 37, 'precompute': True, 'random_state': 10, 'tol': 0.005475437099684212, 'copy_X': True, 'alpha': 0.99568112439937}
# 	Score: 0.804446604286
# 	Best score: 0.811791498972
#
# Interation no.:  62
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 10, 'precompute': False, 'random_state': 10, 'tol': 0.0226377349961484, 'copy_X': True, 'alpha': 0.9883473568178656}
# 	Score: 0.810740801931
# 	Best score: 0.811791498972
#
# Interation no.:  63
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 39, 'precompute': False, 'random_state': 10, 'tol': 0.05896915403395725, 'copy_X': True, 'alpha': 0.9904063034085174}
# 	Score: 0.808913414794
# 	Best score: 0.811791498972
#
# Interation no.:  64
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 13, 'precompute': False, 'random_state': 10, 'tol': 0.04983539870321983, 'copy_X': True, 'alpha': 0.9918293004678983}
# 	Score: 0.798818546154
# 	Best score: 0.811791498972
#
# Interation no.:  65
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 47, 'precompute': False, 'random_state': 10, 'tol': 0.02924867655593842, 'copy_X': True, 'alpha': 0.9809244320205164}
# 	Score: 0.797527793096
# 	Best score: 0.811791498972
#
# Interation no.:  66
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 22, 'precompute': False, 'random_state': 10, 'tol': 0.015775479474418798, 'copy_X': True, 'alpha': 0.9971731723720579}
# 	Score: 0.811637824135
# 	Best score: 0.811791498972
#
# Interation no.:  67
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 41, 'precompute': False, 'random_state': 10, 'tol': 0.013362692420806638, 'copy_X': True, 'alpha': 0.9982681906616034}
# 	Score: 0.803778743412
# 	Best score: 0.811791498972
#
# Interation no.:  68
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 32, 'precompute': False, 'random_state': 10, 'tol': 0.00806316923202588, 'copy_X': True, 'alpha': 0.9993484162883455}
# 	Score: 0.806362896383
# 	Best score: 0.811791498972
#
# Interation no.:  69
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.0035102542112555937, 'copy_X': True, 'alpha': 0.9967510366910036}
# 	Score: 0.813600670832
# 	Best score: 0.813600670832
#
# Interation no.:  70
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 33, 'precompute': False, 'random_state': 10, 'tol': 0.003255539446204391, 'copy_X': True, 'alpha': 0.9928237169570505}
# 	Score: 0.806778344392
# 	Best score: 0.813600670832
#
# Interation no.:  71
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 29, 'precompute': False, 'random_state': 10, 'tol': 0.018749575256840123, 'copy_X': True, 'alpha': 0.9951588342545592}
# 	Score: 0.80879131614
# 	Best score: 0.813600670832
#
# Interation no.:  72
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 3, 'precompute': False, 'random_state': 10, 'tol': 0.011594739396076224, 'copy_X': True, 'alpha': 0.9969103566066668}
# 	Score: 0.774571513308
# 	Best score: 0.813600670832
#
# Interation no.:  73
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.006629552711391259, 'copy_X': True, 'alpha': 0.9911732121701197}
# 	Score: 0.813590500116
# 	Best score: 0.813600670832
#
# Interation no.:  74
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.03439729784987772, 'copy_X': True, 'alpha': 0.989014057487824}
# 	Score: 0.813586434761
# 	Best score: 0.813600670832
#
# Interation no.:  75
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.0772004463287594, 'copy_X': True, 'alpha': 0.9867284584359111}
# 	Score: 0.809259437976
# 	Best score: 0.813600670832
#
# Interation no.:  76
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 15, 'precompute': False, 'random_state': 10, 'tol': 0.038435609643715146, 'copy_X': True, 'alpha': 0.9910153472317733}
# 	Score: 0.813350897573
# 	Best score: 0.813600670832
#
# Interation no.:  77
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 14, 'precompute': False, 'random_state': 10, 'tol': 0.044068786716628595, 'copy_X': True, 'alpha': 0.9889559647217977}
# 	Score: 0.8126378214
# 	Best score: 0.813600670832
#
# Interation no.:  78
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.06604726663733587, 'copy_X': True, 'alpha': 0.9841305384686359}
# 	Score: 0.808480357817
# 	Best score: 0.813600670832
#
# Interation no.:  79
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 4, 'precompute': True, 'random_state': 10, 'tol': 0.08468915103823882, 'copy_X': True, 'alpha': 0.9940924290125069}
# 	Score: 0.794151868663
# 	Best score: 0.813600670832
#
# Interation no.:  80
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 23, 'precompute': False, 'random_state': 10, 'tol': 0.0322949947278341, 'copy_X': True, 'alpha': 0.9922218961643533}
# 	Score: 0.808916047781
# 	Best score: 0.813600670832
#
# Interation no.:  81
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.03534385878904689, 'copy_X': True, 'alpha': 0.9875741499830558}
# 	Score: 0.802663192177
# 	Best score: 0.813600670832
#
# Interation no.:  82
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.025691182294598013, 'copy_X': True, 'alpha': 0.9932468776061638}
# 	Score: 0.806579030767
# 	Best score: 0.813600670832
#
# Interation no.:  83
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': True, 'random_state': 10, 'tol': 0.00803631173432615, 'copy_X': True, 'alpha': 0.9858646502841873}
# 	Score: 0.813580495983
# 	Best score: 0.813600670832
#
# Interation no.:  84
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.0466517439876178, 'copy_X': True, 'alpha': 0.9946937004955895}
# 	Score: 0.813187623586
# 	Best score: 0.813600670832
#
# Interation no.:  85
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 40, 'precompute': False, 'random_state': 10, 'tol': 0.09458549929808627, 'copy_X': True, 'alpha': 0.9914448005382374}
# 	Score: 0.80878681656
# 	Best score: 0.813600670832
#
# Interation no.:  86
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 12, 'precompute': False, 'random_state': 10, 'tol': 0.0390594763946168, 'copy_X': True, 'alpha': 0.990279281224243}
# 	Score: 0.779864063543
# 	Best score: 0.813600670832
#
# Interation no.:  87
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 36, 'precompute': False, 'random_state': 10, 'tol': 0.017239764587692424, 'copy_X': True, 'alpha': 0.984844900346662}
# 	Score: 0.805629049676
# 	Best score: 0.813600670832
#
# Interation no.:  88
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 46, 'precompute': True, 'random_state': 10, 'tol': 0.05219877495800401, 'copy_X': True, 'alpha': 0.9883942693391228}
# 	Score: 0.80611905269
# 	Best score: 0.813600670832
#
# Interation no.:  89
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 2, 'precompute': False, 'random_state': 10, 'tol': 0.030630340872027182, 'copy_X': True, 'alpha': 0.9820363876747944}
# 	Score: 0.751205127316
# 	Best score: 0.813600670832
#
# Interation no.:  90
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 25, 'precompute': False, 'random_state': 10, 'tol': 0.056856564244948324, 'copy_X': True, 'alpha': 0.9966119708544365}
# 	Score: 0.802890244967
# 	Best score: 0.813600670832
#
# Interation no.:  91
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 42, 'precompute': False, 'random_state': 10, 'tol': 0.020589010329934616, 'copy_X': True, 'alpha': 0.9955759108758112}
# 	Score: 0.800279156723
# 	Best score: 0.813600670832
#
# Interation no.:  92
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 34, 'precompute': True, 'random_state': 10, 'tol': 0.0012072991880379721, 'copy_X': True, 'alpha': 0.9837151144297517}
# 	Score: 0.806771850431
# 	Best score: 0.813600670832
#
# Interation no.:  93
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 45, 'precompute': False, 'random_state': 10, 'tol': 0.043657141063754915, 'copy_X': True, 'alpha': 0.9890633114039479}
# 	Score: 0.79988107002
# 	Best score: 0.813600670832
#
# Interation no.:  94
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 31, 'precompute': False, 'random_state': 10, 'tol': 0.027439611012976612, 'copy_X': True, 'alpha': 0.9935687109689386}
# 	Score: 0.804992606494
# 	Best score: 0.813600670832
#
# Interation no.:  95
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 8, 'precompute': False, 'random_state': 10, 'tol': 0.012922135751746824, 'copy_X': True, 'alpha': 0.9925184411086774}
# 	Score: 0.765265798428
# 	Best score: 0.813600670832
#
# Interation no.:  96
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 30, 'precompute': False, 'random_state': 10, 'tol': 0.07388697224070055, 'copy_X': True, 'alpha': 0.9872112372505372}
# 	Score: 0.80888296884
# 	Best score: 0.813600670832
#
# Interation no.:  97
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 26, 'precompute': True, 'random_state': 10, 'tol': 0.03452999462254472, 'copy_X': True, 'alpha': 0.9863252151043478}
# 	Score: 0.809428660029
# 	Best score: 0.813600670832
#
# Interation no.:  98
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 21, 'precompute': False, 'random_state': 10, 'tol': 0.0035187481778875067, 'copy_X': True, 'alpha': 0.998502443465295}
# 	Score: 0.811767783149
# 	Best score: 0.813600670832
#
# Interation no.:  99
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 18, 'precompute': False, 'random_state': 10, 'tol': 0.010448854772849254, 'copy_X': True, 'alpha': 0.9799988488924066}
# 	Score: 0.81010013551
# 	Best score: 0.813600670832
#
# Interation no.:  100
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 43, 'precompute': False, 'random_state': 10, 'tol': 0.006115963653201351, 'copy_X': True, 'alpha': 0.9911999433591316}
# 	Score: 0.784922552796
# 	Best score: 0.813600670832
#
# Interation no.:  101
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 1, 'precompute': False, 'random_state': 10, 'tol': 0.023013916308616766, 'copy_X': True, 'alpha': 0.9896433130039844}
# 	Score: 0.665118809605
# 	Best score: 0.813600670832
#
# Interation no.:  102
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 7, 'precompute': True, 'random_state': 10, 'tol': 0.047619201888974574, 'copy_X': True, 'alpha': 0.9944158926917388}
# 	Score: 0.808680724623
# 	Best score: 0.813600670832
#
# Interation no.:  103
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 9, 'precompute': False, 'random_state': 10, 'tol': 0.024466288420705643, 'copy_X': True, 'alpha': 0.9978837747881826}
# 	Score: 0.810729464055
# 	Best score: 0.813600670832
#
# Interation no.:  104
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 28, 'precompute': False, 'random_state': 10, 'tol': 0.01635236665761348, 'copy_X': True, 'alpha': 0.9975048522993084}
# 	Score: 0.805912121111
# 	Best score: 0.813600670832
#
# Interation no.:  105
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 5, 'precompute': False, 'random_state': 10, 'tol': 0.019361040820769806, 'copy_X': True, 'alpha': 0.9905956697405692}
# 	Score: 0.74772534884
# 	Best score: 0.813600670832
#
# Interation no.:  106
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 44, 'precompute': False, 'random_state': 10, 'tol': 0.06507792391916213, 'copy_X': True, 'alpha': 0.9828588469646691}
# 	Score: 0.808478348262
# 	Best score: 0.813600670832
#
# Interation no.:  107
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 11, 'precompute': True, 'random_state': 10, 'tol': 0.007418306083485987, 'copy_X': True, 'alpha': 0.9883583315737398}
# 	Score: 0.812642649478
# 	Best score: 0.813600670832
#
# Interation no.:  108
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 38, 'precompute': False, 'random_state': 10, 'tol': 0.0681809321894882, 'copy_X': True, 'alpha': 0.99548550764239}
# 	Score: 0.808498193432
# 	Best score: 0.813600670832
#
# Interation no.:  109
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 17, 'precompute': False, 'random_state': 10, 'tol': 0.08120518080020808, 'copy_X': True, 'alpha': 0.999990331345613}
# 	Score: 0.80884682711
# 	Best score: 0.813600670832
#
# Interation no.:  110
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 49, 'precompute': False, 'random_state': 10, 'tol': 0.04318389739489628, 'copy_X': True, 'alpha': 0.9964684266170336}
# 	Score: 0.78355689464
# 	Best score: 0.813600670832
#
# Interation no.:  111
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 48, 'precompute': False, 'random_state': 10, 'tol': 0.05407432740824032, 'copy_X': True, 'alpha': 0.9784515845359808}
# 	Score: 0.808306115808
# 	Best score: 0.813600670832
#
# Interation no.:  112
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 20, 'precompute': True, 'random_state': 10, 'tol': 0.060906860083234704, 'copy_X': True, 'alpha': 0.9931522079275952}
# 	Score: 0.808792181772
# 	Best score: 0.813600670832
#
# Interation no.:  113
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.030716527908517824, 'copy_X': True, 'alpha': 0.9855219477080613}
# 	Score: 0.81357984951
# 	Best score: 0.813600670832
#
# Interation no.:  114
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 6, 'precompute': False, 'random_state': 10, 'tol': 0.03674976025197112, 'copy_X': True, 'alpha': 0.9735189160321699}
# 	Score: 0.803058003081
# 	Best score: 0.813600670832
#
# Interation no.:  115
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 27, 'precompute': False, 'random_state': 10, 'tol': 0.028162044183947063, 'copy_X': True, 'alpha': 0.9816850146013945}
# 	Score: 0.795238209686
# 	Best score: 0.813600670832
#
# Interation no.:  116
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 35, 'precompute': False, 'random_state': 10, 'tol': 0.012372315954700407, 'copy_X': True, 'alpha': 0.9918056873171849}
# 	Score: 0.805770987076
# 	Best score: 0.813600670832
#
# Interation no.:  117
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 37, 'precompute': False, 'random_state': 10, 'tol': 0.003155742418236643, 'copy_X': True, 'alpha': 0.9764668198867208}
# 	Score: 0.804392777073
# 	Best score: 0.813600670832
#
# Interation no.:  118
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 24, 'precompute': True, 'random_state': 10, 'tol': 0.040242734993543555, 'copy_X': True, 'alpha': 0.998881873222948}
# 	Score: 0.810532165428
# 	Best score: 0.813600670832
#
# Interation no.:  119
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 10, 'precompute': False, 'random_state': 10, 'tol': 0.014665498774015302, 'copy_X': True, 'alpha': 0.9877735095445126}
# 	Score: 0.809445807092
# 	Best score: 0.813600670832
#
# Interation no.:  120
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.021167813082387757, 'copy_X': True, 'alpha': 0.9846068565201365}
# 	Score: 0.788777271067
# 	Best score: 0.813600670832
#
# Interation no.:  121
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 39, 'precompute': False, 'random_state': 10, 'tol': 0.009209410877741993, 'copy_X': True, 'alpha': 0.9960670623374699}
# 	Score: 0.804280799412
# 	Best score: 0.813600670832
#
# Interation no.:  122
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 13, 'precompute': False, 'random_state': 10, 'tol': 0.024965499297135315, 'copy_X': True, 'alpha': 0.989274702119756}
# 	Score: 0.812661404495
# 	Best score: 0.813600670832
#
# Interation no.:  123
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 41, 'precompute': True, 'random_state': 10, 'tol': 0.05196064156635818, 'copy_X': True, 'alpha': 0.986549586525161}
# 	Score: 0.805005210306
# 	Best score: 0.813600670832
#
# Interation no.:  124
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 47, 'precompute': False, 'random_state': 10, 'tol': 0.0050758888697336165, 'copy_X': True, 'alpha': 0.9899496408044643}
# 	Score: 0.795803386882
# 	Best score: 0.813600670832
#
# Interation no.:  125
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.07255323999381358, 'copy_X': True, 'alpha': 0.9926586457026472}
# 	Score: 0.77588043732
# 	Best score: 0.813600670832
#
# Interation no.:  126
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 29, 'precompute': False, 'random_state': 10, 'tol': 0.08870741298520346, 'copy_X': True, 'alpha': 0.9950274084113777}
# 	Score: 0.810095847374
# 	Best score: 0.813600670832
#
# Interation no.:  127
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 3, 'precompute': False, 'random_state': 10, 'tol': 0.03258289799250469, 'copy_X': True, 'alpha': 0.9701354024895879}
# 	Score: 0.774545521865
# 	Best score: 0.813600670832
#
# Interation no.:  128
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 32, 'precompute': True, 'random_state': 10, 'tol': 0.0015628681149677157, 'copy_X': True, 'alpha': 0.9936341447289785}
# 	Score: 0.806346329107
# 	Best score: 0.813600670832
#
# Interation no.:  129
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 33, 'precompute': False, 'random_state': 10, 'tol': 0.06284856724723042, 'copy_X': True, 'alpha': 0.9834173260128354}
# 	Score: 0.805265135465
# 	Best score: 0.813600670832
#
# Interation no.:  130
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 15, 'precompute': False, 'random_state': 10, 'tol': 0.01784849036115032, 'copy_X': True, 'alpha': 0.9872370290162433}
# 	Score: 0.802721219304
# 	Best score: 0.813600670832
#
# Interation no.:  131
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 36, 'precompute': False, 'random_state': 10, 'tol': 0.010769880606118231, 'copy_X': True, 'alpha': 0.9710912684875513}
# 	Score: 0.801676972787
# 	Best score: 0.813600670832
#
# Interation no.:  132
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 4, 'precompute': False, 'random_state': 10, 'tol': 0.05750258685318893, 'copy_X': True, 'alpha': 0.9914643793176676}
# 	Score: 0.794149480647
# 	Best score: 0.813600670832
#
# Interation no.:  133
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 2, 'precompute': True, 'random_state': 10, 'tol': 0.0484598532215723, 'copy_X': True, 'alpha': 0.9907610510457369}
# 	Score: 0.752235014379
# 	Best score: 0.813600670832
#
# Interation no.:  134
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 23, 'precompute': False, 'random_state': 10, 'tol': 0.0974923738843773, 'copy_X': True, 'alpha': 0.9852165978214193}
# 	Score: 0.808786545856
# 	Best score: 0.813600670832
#
# Interation no.:  135
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 14, 'precompute': False, 'random_state': 10, 'tol': 0.03746617498472127, 'copy_X': True, 'alpha': 0.9943432186036877}
# 	Score: 0.802507507261
# 	Best score: 0.813600670832
#
# Interation no.:  136
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 40, 'precompute': False, 'random_state': 10, 'tol': 0.01514421168258515, 'copy_X': True, 'alpha': 0.9885531136240974}
# 	Score: 0.801079158598
# 	Best score: 0.813600670832
#
# Interation no.:  137
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.03415442319401195, 'copy_X': True, 'alpha': 0.9995525340209053}
# 	Score: 0.813605708877
# 	Best score: 0.813605708877
#
# Interation no.:  138
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 19, 'precompute': True, 'random_state': 10, 'tol': 0.006408717119794575, 'copy_X': True, 'alpha': 0.999111112072863}
# 	Score: 0.811812811298
# 	Best score: 0.813605708877
#
# Interation no.:  139
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 25, 'precompute': False, 'random_state': 10, 'tol': 0.029258441041103776, 'copy_X': True, 'alpha': 0.9974634372627491}
# 	Score: 0.809646711275
# 	Best score: 0.813605708877
#
# Interation no.:  140
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 34, 'precompute': False, 'random_state': 10, 'tol': 0.02032476131308383, 'copy_X': True, 'alpha': 0.9996756598843765}
# 	Score: 0.804018224525
# 	Best score: 0.813605708877
#
# Interation no.:  141
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 30, 'precompute': False, 'random_state': 10, 'tol': 0.044994298534007854, 'copy_X': True, 'alpha': 0.9982645882135038}
# 	Score: 0.783313489812
# 	Best score: 0.813605708877
#
# Interation no.:  142
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 31, 'precompute': False, 'random_state': 10, 'tol': 0.04208495687114016, 'copy_X': True, 'alpha': 0.9970664339900231}
# 	Score: 0.808283947329
# 	Best score: 0.813605708877
#
# Interation no.:  143
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 42, 'precompute': True, 'random_state': 10, 'tol': 0.05494259756232153, 'copy_X': True, 'alpha': 0.9963816528983802}
# 	Score: 0.807372753882
# 	Best score: 0.813605708877
#
# Interation no.:  144
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 12, 'precompute': False, 'random_state': 10, 'tol': 0.0232405370842419, 'copy_X': True, 'alpha': 0.9956238663804428}
# 	Score: 0.813455356463
# 	Best score: 0.813605708877
#
# Interation no.:  145
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 46, 'precompute': False, 'random_state': 10, 'tol': 0.003587648567730722, 'copy_X': True, 'alpha': 0.9994266277461777}
# ...
# 	Score: 0.8135730128
# 	Best score: 0.813642530255
#
# Interation no.:  954
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 34, 'precompute': False, 'random_state': 10, 'tol': 0.028112470090216946, 'copy_X': True, 'alpha': 0.9933090409462343}
# 	Score: 0.806799456842
# 	Best score: 0.813642530255
#
# Interation no.:  955
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 31, 'precompute': True, 'random_state': 10, 'tol': 0.05717310786507954, 'copy_X': True, 'alpha': 0.9890167645638624}
# 	Score: 0.80653358285
# 	Best score: 0.813642530255
#
# Interation no.:  956
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 17, 'precompute': False, 'random_state': 10, 'tol': 0.01940449766403656, 'copy_X': True, 'alpha': 0.9861494310343611}
# 	Score: 0.813018237701
# 	Best score: 0.813642530255
#
# Interation no.:  957
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 21, 'precompute': False, 'random_state': 10, 'tol': 0.007092138090213043, 'copy_X': True, 'alpha': 0.996277536655096}
# 	Score: 0.811762225021
# 	Best score: 0.813642530255
#
# Interation no.:  958
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': True, 'max_iter': 45, 'precompute': False, 'random_state': 10, 'tol': 0.08467433874095176, 'copy_X': True, 'alpha': 0.9869896689857766}
# 	Score: 0.80065504296
# 	Best score: 0.813642530255
#
# Interation no.:  959
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': False, 'max_iter': 43, 'precompute': False, 'random_state': 10, 'tol': 0.0016393547186900406, 'copy_X': True, 'alpha': 0.9902654636496914}
# 	Score: 0.800125507706
# 	Best score: 0.813642530255
#
# Interation no.:  960
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 26, 'precompute': True, 'random_state': 10, 'tol': 0.05388820472027753, 'copy_X': True, 'alpha': 0.9973550125811346}
# 	Score: 0.807252239126
# 	Best score: 0.813642530255
#
# Interation no.:  961
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 1, 'precompute': False, 'random_state': 10, 'tol': 0.023926460878902687, 'copy_X': True, 'alpha': 0.9938790120662537}
# 	Score: 0.665123509673
# 	Best score: 0.813642530255
#
# Interation no.:  962
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 8, 'precompute': False, 'random_state': 10, 'tol': 0.09696372786654868, 'copy_X': True, 'alpha': 0.9855628830103901}
# 	Score: 0.809987767199
# 	Best score: 0.813642530255
#
# Interation no.:  963
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 42, 'precompute': False, 'random_state': 10, 'tol': 0.013383598515734616, 'copy_X': True, 'alpha': 0.9999652285572832}
# 	Score: 0.802597460421
# 	Best score: 0.813642530255
#
# Interation no.:  964
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 17, 'precompute': False, 'random_state': 10, 'tol': 0.01596978376133494, 'copy_X': True, 'alpha': 0.9918456313900766}
# 	Score: 0.813029121769
# 	Best score: 0.813642530255
#
# Interation no.:  965
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': True, 'random_state': 10, 'tol': 0.05557792056408186, 'copy_X': True, 'alpha': 0.9847975308840379}
# 	Score: 0.807126994424
# 	Best score: 0.813642530255
#
# Interation no.:  966
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 7, 'precompute': False, 'random_state': 10, 'tol': 0.06261147259236757, 'copy_X': True, 'alpha': 0.9883425927102477}
# 	Score: 0.808673250615
# 	Best score: 0.813642530255
#
# Interation no.:  967
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 44, 'precompute': False, 'random_state': 10, 'tol': 0.05827601609131343, 'copy_X': True, 'alpha': 0.9984682721344806}
# 	Score: 0.808963040359
# 	Best score: 0.813642530255
#
# Interation no.:  968
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 28, 'precompute': False, 'random_state': 10, 'tol': 0.01178862377123173, 'copy_X': True, 'alpha': 0.9895438956591951}
# 	Score: 0.80839242383
# 	Best score: 0.813642530255
#
# Interation no.:  969
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 5, 'precompute': False, 'random_state': 10, 'tol': 0.025813200265952494, 'copy_X': True, 'alpha': 0.9865581371967798}
# 	Score: 0.747710421622
# 	Best score: 0.813642530255
#
# Interation no.:  970
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 11, 'precompute': True, 'random_state': 10, 'tol': 0.029923259629427063, 'copy_X': True, 'alpha': 0.9948020727567528}
# 	Score: 0.812650682896
# 	Best score: 0.813642530255
#
# Interation no.:  971
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 18, 'precompute': False, 'random_state': 10, 'tol': 0.06878123160410744, 'copy_X': True, 'alpha': 0.9957382409341631}
# 	Score: 0.809075294484
# 	Best score: 0.813642530255
#
# Interation no.:  972
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 48, 'precompute': False, 'random_state': 10, 'tol': 0.09997229818628284, 'copy_X': True, 'alpha': 0.9841456433068897}
# 	Score: 0.809985951269
# 	Best score: 0.813642530255
#
# Interation no.:  973
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 9, 'precompute': False, 'random_state': 10, 'tol': 0.0519798518861865, 'copy_X': True, 'alpha': 0.9930253608227977}
# 	Score: 0.810723619555
# 	Best score: 0.813642530255
#
# Interation no.:  974
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 20, 'precompute': False, 'random_state': 10, 'tol': 0.06521187323681525, 'copy_X': True, 'alpha': 0.9828973216530376}
# 	Score: 0.808478409069
# 	Best score: 0.813642530255
#
# Interation no.:  975
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 38, 'precompute': True, 'random_state': 10, 'tol': 0.060563590775319906, 'copy_X': True, 'alpha': 0.9891273361192836}
# 	Score: 0.808304248344
# 	Best score: 0.813642530255
#
# Interation no.:  976
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 17, 'precompute': False, 'random_state': 10, 'tol': 0.04926163463373903, 'copy_X': True, 'alpha': 0.9875453119693016}
# 	Score: 0.809404477377
# 	Best score: 0.813642530255
#
# Interation no.:  977
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.009820138242250127, 'copy_X': True, 'alpha': 0.9907250868563567}
# 	Score: 0.813589659495
# 	Best score: 0.813642530255
#
# Interation no.:  978
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 13, 'precompute': False, 'random_state': 10, 'tol': 0.02790787967390567, 'copy_X': True, 'alpha': 0.9980467603577783}
# 	Score: 0.812677221139
# 	Best score: 0.813642530255
#
# Interation no.:  979
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 49, 'precompute': False, 'random_state': 10, 'tol': 0.04502117094561658, 'copy_X': True, 'alpha': 0.9990767098767788}
# 	Score: 0.783317736302
# 	Best score: 0.813642530255
#
# Interation no.:  980
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 27, 'precompute': True, 'random_state': 10, 'tol': 0.01736113632291164, 'copy_X': True, 'alpha': 0.9922457028926676}
# 	Score: 0.809626016957
# 	Best score: 0.813642530255
#
# Interation no.:  981
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 17, 'precompute': False, 'random_state': 10, 'tol': 0.023244832303461336, 'copy_X': True, 'alpha': 0.9966226037737141}
# 	Score: 0.813038010973
# 	Best score: 0.813642530255
#
# Interation no.:  982
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 24, 'precompute': False, 'random_state': 10, 'tol': 0.014725778810171404, 'copy_X': True, 'alpha': 0.9854627421149285}
# 	Score: 0.810084833242
# 	Best score: 0.813642530255
#
# Interation no.:  983
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 35, 'precompute': False, 'random_state': 10, 'tol': 0.05590063062662727, 'copy_X': True, 'alpha': 0.9900444784858317}
# 	Score: 0.807986602436
# 	Best score: 0.813642530255
#
# Interation no.:  984
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 37, 'precompute': False, 'random_state': 10, 'tol': 0.03118010802152738, 'copy_X': True, 'alpha': 0.991471173012371}
# 	Score: 0.80428770915
# 	Best score: 0.813642530255
#
# Interation no.:  985
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 33, 'precompute': True, 'random_state': 10, 'tol': 0.05021614429445282, 'copy_X': True, 'alpha': 0.9870007555300779}
# 	Score: 0.80140292333
# 	Best score: 0.813642530255
#
# Interation no.:  986
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 32, 'precompute': False, 'random_state': 10, 'tol': 0.021106138435137072, 'copy_X': True, 'alpha': 0.9878986840169335}
# 	Score: 0.806329746636
# 	Best score: 0.813642530255
#
# Interation no.:  987
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 10, 'precompute': False, 'random_state': 10, 'tol': 0.04700705168542724, 'copy_X': True, 'alpha': 0.986229645863981}
# 	Score: 0.810738108944
# 	Best score: 0.813642530255
#
# Interation no.:  988
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 39, 'precompute': False, 'random_state': 10, 'tol': 0.052410821258541, 'copy_X': True, 'alpha': 0.9885101232810748}
# 	Score: 0.806736990029
# 	Best score: 0.813642530255
#
# Interation no.:  989
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 29, 'precompute': False, 'random_state': 10, 'tol': 0.04330499945871725, 'copy_X': True, 'alpha': 0.9928090789641635}
# 	Score: 0.78353762909
# 	Best score: 0.813642530255
#
# Interation no.:  990
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 47, 'precompute': True, 'random_state': 10, 'tol': 0.027115503383656203, 'copy_X': True, 'alpha': 0.9836473508869548}
# 	Score: 0.798951631019
# 	Best score: 0.813642530255
#
# Interation no.:  991
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 41, 'precompute': False, 'random_state': 10, 'tol': 0.005388751898915599, 'copy_X': True, 'alpha': 0.9908254356168669}
# 	Score: 0.803757375041
# 	Best score: 0.813642530255
#
# Interation no.:  992
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 22, 'precompute': False, 'random_state': 10, 'tol': 0.03772923691235328, 'copy_X': True, 'alpha': 0.9849952037301998}
# 	Score: 0.811605703711
# 	Best score: 0.813642530255
#
# Interation no.:  993
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 3, 'precompute': False, 'random_state': 10, 'tol': 0.05443977087904641, 'copy_X': True, 'alpha': 0.9796663057128983}
# 	Score: 0.774554773579
# 	Best score: 0.813642530255
#
# Interation no.:  994
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 6, 'precompute': False, 'random_state': 10, 'tol': 0.045266720999274326, 'copy_X': True, 'alpha': 0.9976619559449043}
# 	Score: 0.804171137179
# 	Best score: 0.813642530255
#
# Interation no.:  995
# Training with params :
# {'normalize': False, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 17, 'precompute': True, 'random_state': 10, 'tol': 0.040863418501975654, 'copy_X': True, 'alpha': 0.999442004667773}
# 	Score: 0.811300086722
# 	Best score: 0.813642530255
#
# Interation no.:  996
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 16, 'precompute': False, 'random_state': 10, 'tol': 0.01945701694740358, 'copy_X': True, 'alpha': 0.9942097145737747}
# 	Score: 0.813596042898
# 	Best score: 0.813642530255
#
# Interation no.:  997
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 4, 'precompute': False, 'random_state': 10, 'tol': 0.05813256521027045, 'copy_X': True, 'alpha': 0.9807221328375526}
# 	Score: 0.794139712772
# 	Best score: 0.813642530255
#
# Interation no.:  998
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 15, 'precompute': False, 'random_state': 10, 'tol': 0.02433194194617209, 'copy_X': True, 'alpha': 0.9892102023933352}
# 	Score: 0.813347601133
# 	Best score: 0.813642530255
#
# Interation no.:  999
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'cyclic', 'fit_intercept': True, 'positive': False, 'max_iter': 14, 'precompute': False, 'random_state': 10, 'tol': 0.03525261688222227, 'copy_X': True, 'alpha': 0.9876437617011812}
# 	Score: 0.784998677519
# 	Best score: 0.813642530255
#
# Interation no.:  1000
# Training with params :
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 17, 'precompute': True, 'random_state': 10, 'tol': 0.04803025665901573, 'copy_X': True, 'alpha': 0.9861162860894075}
# 	Score: 0.809401894612
# 	Best score: 0.813642530255
#
# Best parameters:
# {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True, 'max_iter': 17, 'precompute': False, 'random_state': 10, 'tol': 0.046776741099351975, 'copy_X': True, 'alpha': 0.9933646228467098}
# 	Score 0.813642530255

# %%
params = {'normalize': True, 'warm_start': False, 'selection': 'random', 'fit_intercept': True, 'positive': True,
          'max_iter': 17, 'precompute': False, 'random_state': 10, 'tol': 0.046776741099351975, 'copy_X': True,
          'alpha': 0.9933646228467098}
reg1 = Lasso(
            alpha = params['alpha'],
            max_iter = params['max_iter'],
            tol = params['tol'],
            normalize = params['normalize'],
            precompute = params['precompute'],
            positive = params['positive'],
            selection = params['selection'],
            fit_intercept = params['fit_intercept'],
            copy_X = params['copy_X'],
            warm_start = params['warm_start'],
            random_state = params['random_state']
            )
modelfit(reg1, X_train, y_train)
# Out:
# Model Report
# Train_coef_of_det: 0.886735
# CV_coef_of_det: Mean-0.813643 | Std-0.124397 | Min-0.455041 | Max-0.894080

# %% [markdown]
# ### Grid search + Genetic programming ( 'sklearn-deap' package)

# %%
params = {
        'alpha': [i/1000.0 for i in range(970,1001)],
        'max_iter': range(1,50),
        'tol': [i*10**(-3) for i in range(1,101,10)],
        'normalize': [True,False],
        'precompute': [True,False],
        'positive': [True,False],
        'selection': ['cyclic','random'],
        'fit_intercept': [True],
        'copy_X': [True],
        'warm_start': [False],
        'random_state': [10]
         }
evol = EvolutionaryAlgorithmSearchCV(estimator=Lasso(), params=params, cv=10,
        scoring='r2', population_size=100, gene_mutation_prob=0.5, gene_crossover_prob=0.5, tournament_size=7,
        generations_number=25, verbose=True, n_jobs=-1)
evol.fit(X_train, y_train)

# %%
params = {}
reg1 = Lasso(
            alpha = params['alpha'],
            max_iter = params['max_iter'],
            tol = params['tol'],
            normalize = params['normalize'],
            precompute = params['precompute'],
            positive = params['positive'],
            selection = params['selection'],
            fit_intercept = params['fit_intercept'],
            copy_X = params['copy_X'],
            warm_start = params['warm_start'],
            random_state = params['random_state']
            )
modelfit(reg1, X_train, y_train)

# %% [markdown]
# ### Make predictions and save results

# %%
test_pred = reg1.predict(X_test)
dictn = {'Id': range(1461,2920), 'SalePrice': test_pred}
res = pd.DataFrame(dictn)
res.to_csv('submission.csv', index=0)
