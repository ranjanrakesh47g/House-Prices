# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from evolutionary_search import EvolutionaryAlgorithmSearchCV
from hyperopt import fmin, tpe, hp, STATUS_OK
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from sklearn.linear_model import Ridge

# %% [markdown]
# ## Step I. Load data

# %%
train = pd.read_csv('train.csv')
X_test = pd.read_csv('X_test.csv')

X_train = train.iloc[:, :-1]
y_train = train.iloc[:, -1]

# %% [markdown]
# ## Step II. Buid the model and perform parameter tuning

# %%
def modelfit(reg, train, target, performCV=True, cv=10):
    reg.fit(train, target)
    pred = reg.predict(train)
    train_r2_score = r2_score(target, pred)
    
    print('\nModel Report')
    print('Train_coef_of_det: %0.6f' %(train_r2_score))
    
    if performCV:
        cv_r2_score = cross_val_score(reg, train, target, cv=cv, scoring='r2', n_jobs=-1)
        print('CV_coef_of_det: Mean-%0.6f | Std-%0.6f | Min-%0.6f | Max-%0.6f' %(np.mean(cv_r2_score),
            np.std(cv_r2_score), np.min(cv_r2_score), np.max(cv_r2_score)))

# %% [markdown]
# ### Baseline model

# %%
params = {}
grid = GridSearchCV(estimator=Ridge(), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.712855361446

# %%
params = {}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, fit_intercept=True, normalize=False, copy_X=True, max_iter=None,
        tol=0.001, solver='auto', random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.712855361446

# %% [markdown]
# ### Grid search

# %%
params = {}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='auto', max_iter=None, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.712855361446

# %%
params = {'alpha': [i/10.0] for i in range(0,11)}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='auto', max_iter=None, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'alpha': 1.0}
# 0.712855361446

# %%
params = {'alpha': [i/100.0] for i in range(94,101)}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='auto', max_iter=None, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'alpha': 1.0}
# 0.712855361446

# %%
params = {'alpha': [i/1000.0] for i in range(994,1001)}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='auto', max_iter=None, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'alpha': 1.0}
# 0.712855361446

# %%
params = {'tol': [10**(-i) for i in range(0,11)]}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='auto', max_iter=None, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'tol': 1}
# 0.712855361446

# %%
params = {'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag']}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='auto', max_iter=None, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'solver': 'sag'}
# 0.761741533695

# %%
params = {'max_iter': range(100,2000,100)}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='sag', max_iter=None, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_iter': 100}
# 0.797468689233
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/rakesh/anaconda/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
params = {'max_iter': range(10,200,10)}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='sag', max_iter=None, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_iter': 10}
# 0.823158926953

# %%
params = {'max_iter': range(1,20)}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='sag', max_iter=None, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'max_iter': 4}
# 0.83550085261

# %%
params = {'normalize': [True,False]}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='sag', max_iter=4, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'normalize': False}
# 0.83550085261

# %% [markdown]
# ### Final model

# %%
params = {}
grid = GridSearchCV(estimator=Ridge(alpha=1.0, tol=0.001, solver='sag', max_iter=4, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.83550085261

# %%
reg1 = Ridge(alpha=1.0, tol=0.001, solver='sag', max_iter=4, normalize=False, 
        fit_intercept=True, copy_X=True, random_state=10)
modelfit(reg1, X_train, y_train)
# Out:
# Model Report
# Train_coef_of_det: 0.885598
# CV_coef_of_det: Mean-0.835501 | Std-0.088422 | Min-0.591388 | Max-0.910869

# %% [markdown]
# ### Grid search + Random search

# %%
params = {
        'alpha': [i/10.0 for i in range(0,11)],
        'tol': [10**(-i) for i in range(0,11)],
        'solver': ['sag'],
        'max_iter': range(1,50),
        'normalize': [True,False],
        'fit_intercept': [True],
        'copy_X': [True],
        'random_state': [10]    
         }
rand = RandomizedSearchCV(estimator=Ridge(), param_distributions=params, cv=10, scoring='r2',
         n_iter=1000, random_state=10, n_jobs=-1)
rand.fit(X_train, y_train)
print 'Best parameters: \n', rand.best_params_
print '\tBest score: ', rand.best_score_

# %%
params = {}
reg1 = Ridge(
            alpha = params['alpha'],
            tol = params['tol'],
            solver = params['solver'],
            max_iter = params['max_iter'],
            normalize = params['normalize'], 
            fit_intercept = params['fit_intercept'],
            copy_X = params['copy_X'],
            random_state = params['random_state']         
            )
modelfit(reg1, X_train, y_train)

# %% [markdown]
# ### Grid search + Bayesian optimization ( 'hyperopt' package)

# %%
min_score = float('inf')
best_params = ''
c = 0

def score(params):
    global c, min_score, best_params
    c += 1
    print "Interation no.: ", c
    print "Training with params : "
    print params
    reg = Ridge(
                alpha = params['alpha'],
                tol = params['tol'],
                solver = params['solver'],
                max_iter = params['max_iter'],
                normalize = params['normalize'], 
                fit_intercept = params['fit_intercept'],
                copy_X = params['copy_X'],
                random_state = params['random_state']     
                )
    cv_r2_score = cross_val_score(reg, X_train, y_train, cv=10, scoring='r2', n_jobs=-1)
    score = 1 - np.mean(cv_r2_score) 
    if score < min_score:
        min_score = score
        best_params = params     
    print "\tScore: {0}".format(1-score)
    print "\tBest score: {0}\n".format(1-min_score)
    return {'loss': score, 'status': STATUS_OK}

def optimize():
    space = {
            'alpha': hp.uniform('alpha', 0.0, 1.0),
            'tol': hp.uniform('tol', 1e-11, 1),
            'solver': hp.choice('solver', ['sag']),
            'max_iter': hp.choice('max_iter', range(1,50)),
            'normalize': hp.choice('normalize', [True,False]),
            'fit_intercept': hp.choice('fit_intercept', [True]),
            'copy_X': hp.choice('copy_X', [True]),
            'random_state': hp.choice('random_state', [10])  
             }
    best = fmin(score, space, algo=tpe.suggest, max_evals=1000)    
  
optimize()
print 'Best parameters:'
print best_params
print "\tScore {0}".format(1-min_score)
# Out:
# Interation no.:  1
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 12, 'random_state': 10, 'tol': 0.9073143074845537, 'copy_X': True, 'alpha': 0.06485085420584946, 'solver': 'sag'}
# 	Score: 0.813881900101
# 	Best score: 0.813881900101
#
# Interation no.:  2
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 47, 'random_state': 10, 'tol': 0.148503844263857, 'copy_X': True, 'alpha': 0.4114903537729554, 'solver': 'sag'}
# 	Score: 0.836185786336
# 	Best score: 0.836185786336
#
# Interation no.:  3
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 34, 'random_state': 10, 'tol': 0.285657254291303, 'copy_X': True, 'alpha': 0.7073172126005616, 'solver': 'sag'}
# 	Score: 0.831400385143
# 	Best score: 0.836185786336
#
# Interation no.:  4
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 24, 'random_state': 10, 'tol': 0.8013314806017133, 'copy_X': True, 'alpha': 0.3157390227065936, 'solver': 'sag'}
# 	Score: 0.815019353142
# 	Best score: 0.836185786336
#
# Interation no.:  5
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 10, 'random_state': 10, 'tol': 0.677361975297936, 'copy_X': True, 'alpha': 0.24318656766223912, 'solver': 'sag'}
# 	Score: 0.815018125999
# 	Best score: 0.836185786336
#
# Interation no.:  6
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 32, 'random_state': 10, 'tol': 0.5856147423454402, 'copy_X': True, 'alpha': 0.7116754802683122, 'solver': 'sag'}
# 	Score: 0.817429596349
# 	Best score: 0.836185786336
#
# Interation no.:  7
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 15, 'random_state': 10, 'tol': 0.07165441919917892, 'copy_X': True, 'alpha': 0.7487305410616496, 'solver': 'sag'}
# 	Score: 0.828620548347
# 	Best score: 0.836185786336
#
# Interation no.:  8
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.4008526770793683, 'copy_X': True, 'alpha': 0.773663701735282, 'solver': 'sag'}
# 	Score: 0.818551170393
# 	Best score: 0.836185786336
#
# Interation no.:  9
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 7, 'random_state': 10, 'tol': 0.752517630749918, 'copy_X': True, 'alpha': 0.23946408052421841, 'solver': 'sag'}
# 	Score: 0.816848117836
# 	Best score: 0.836185786336
#
# Interation no.:  10
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 38, 'random_state': 10, 'tol': 0.432036154971475, 'copy_X': True, 'alpha': 0.7287906336567249, 'solver': 'sag'}
# 	Score: 0.817305453549
# 	Best score: 0.836185786336
#
# Interation no.:  11
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 45, 'random_state': 10, 'tol': 0.4407106745700708, 'copy_X': True, 'alpha': 0.20435995451796884, 'solver': 'sag'}
# 	Score: 0.817646802861
# 	Best score: 0.836185786336
#
# Interation no.:  12
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 20, 'random_state': 10, 'tol': 0.5530849384543096, 'copy_X': True, 'alpha': 0.8150881071459989, 'solver': 'sag'}
# 	Score: 0.815027793301
# 	Best score: 0.836185786336
#
# Interation no.:  13
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 22, 'random_state': 10, 'tol': 0.5718828766100127, 'copy_X': True, 'alpha': 0.7817545075664489, 'solver': 'sag'}
# 	Score: 0.816873213908
# 	Best score: 0.836185786336
#
# Interation no.:  14
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 1, 'random_state': 10, 'tol': 0.38230470330402955, 'copy_X': True, 'alpha': 0.6721619907333234, 'solver': 'sag'}
# 	Score: 0.806867689176
# 	Best score: 0.836185786336
#
# Interation no.:  15
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 6, 'random_state': 10, 'tol': 0.9635275294082043, 'copy_X': True, 'alpha': 0.16304026990495768, 'solver': 'sag'}
# 	Score: 0.815016770168
# 	Best score: 0.836185786336
#
# Interation no.:  16
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 16, 'random_state': 10, 'tol': 0.031298676821683954, 'copy_X': True, 'alpha': 0.9630388395939355, 'solver': 'sag'}
# 	Score: 0.828908164489
# 	Best score: 0.836185786336
#
# Interation no.:  17
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 47, 'random_state': 10, 'tol': 0.10839834734685831, 'copy_X': True, 'alpha': 0.31361654413319595, 'solver': 'sag'}
# 	Score: 0.836776724613
# 	Best score: 0.836776724613
#
# Interation no.:  18
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 48, 'random_state': 10, 'tol': 0.4966264062658817, 'copy_X': True, 'alpha': 0.3431338317770457, 'solver': 'sag'}
# 	Score: 0.815019816438
# 	Best score: 0.836776724613
#
# Interation no.:  19
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.8600745335139949, 'copy_X': True, 'alpha': 0.6785641940909334, 'solver': 'sag'}
# 	Score: 0.81502548673
# 	Best score: 0.836776724613
#
# Interation no.:  20
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 4, 'random_state': 10, 'tol': 0.7848252740380705, 'copy_X': True, 'alpha': 0.8655530921242437, 'solver': 'sag'}
# 	Score: 0.815028645717
# 	Best score: 0.836776724613
#
# Interation no.:  21
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 47, 'random_state': 10, 'tol': 0.20309061679368154, 'copy_X': True, 'alpha': 0.5150947893652278, 'solver': 'sag'}
# 	Score: 0.835855314729
# 	Best score: 0.836776724613
#
# Interation no.:  22
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 47, 'random_state': 10, 'tol': 0.13632374148920134, 'copy_X': True, 'alpha': 0.4778369168188491, 'solver': 'sag'}
# 	Score: 0.837431385832
# 	Best score: 0.837431385832
#
# Interation no.:  23
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 41, 'random_state': 10, 'tol': 0.2613117355117641, 'copy_X': True, 'alpha': 0.510902733715722, 'solver': 'sag'}
# 	Score: 0.83273521965
# 	Best score: 0.837431385832
#
# Interation no.:  24
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 25, 'random_state': 10, 'tol': 0.10119847891485292, 'copy_X': True, 'alpha': 0.5984976826534651, 'solver': 'sag'}
# 	Score: 0.835699214732
# 	Best score: 0.837431385832
#
# Interation no.:  25
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 47, 'random_state': 10, 'tol': 6.877157248943999e-05, 'copy_X': True, 'alpha': 0.42768926877227836, 'solver': 'sag'}
# 	Score: 0.834794766272
# 	Best score: 0.837431385832
#
# Interation no.:  26
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 2, 'random_state': 10, 'tol': 0.29126363387017595, 'copy_X': True, 'alpha': 0.01583995058359533, 'solver': 'sag'}
# 	Score: 0.812678262302
# 	Best score: 0.837431385832
#
# Interation no.:  27
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 31, 'random_state': 10, 'tol': 0.17329945207905745, 'copy_X': True, 'alpha': 0.13601960471247085, 'solver': 'sag'}
# 	Score: 0.833043294186
# 	Best score: 0.837431385832
#
# Interation no.:  28
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 29, 'random_state': 10, 'tol': 0.0025068955182009633, 'copy_X': True, 'alpha': 0.6078786859885227, 'solver': 'sag'}
# 	Score: 0.834047898478
# 	Best score: 0.837431385832
#
# Interation no.:  29
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 49, 'random_state': 10, 'tol': 0.222353199709046, 'copy_X': True, 'alpha': 0.4160615756561534, 'solver': 'sag'}
# 	Score: 0.832738452877
# 	Best score: 0.837431385832
#
# Interation no.:  30
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 35, 'random_state': 10, 'tol': 0.11418850981331817, 'copy_X': True, 'alpha': 0.04245467370501427, 'solver': 'sag'}
# 	Score: 0.829522752373
# 	Best score: 0.837431385832
#
# Interation no.:  31
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 28, 'random_state': 10, 'tol': 0.34418297026123085, 'copy_X': True, 'alpha': 0.3273550151493869, 'solver': 'sag'}
# 	Score: 0.825405443536
# 	Best score: 0.837431385832
#
# Interation no.:  32
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 9, 'random_state': 10, 'tol': 0.059811798080280476, 'copy_X': True, 'alpha': 0.1058910433747614, 'solver': 'sag'}
# 	Score: 0.829201952736
# 	Best score: 0.837431385832
#
# Interation no.:  33
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 5, 'random_state': 10, 'tol': 0.13238425024271624, 'copy_X': True, 'alpha': 0.4621574673306075, 'solver': 'sag'}
# 	Score: 0.837193130088
# 	Best score: 0.837431385832
#
# Interation no.:  34
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 5, 'random_state': 10, 'tol': 0.3081424284730101, 'copy_X': True, 'alpha': 0.5921562264872029, 'solver': 'sag'}
# 	Score: 0.829993009871
# 	Best score: 0.837431385832
#
# Interation no.:  35
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 43, 'random_state': 10, 'tol': 0.6366029815240892, 'copy_X': True, 'alpha': 0.47117036101585147, 'solver': 'sag'}
# 	Score: 0.818229506429
# 	Best score: 0.837431385832
#
# Interation no.:  36
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 26, 'random_state': 10, 'tol': 0.15864508747038514, 'copy_X': True, 'alpha': 0.9012956796374447, 'solver': 'sag'}
# 	Score: 0.832083986367
# 	Best score: 0.837431385832
#
# Interation no.:  37
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 40, 'random_state': 10, 'tol': 0.23361426894672516, 'copy_X': True, 'alpha': 0.375672782562422, 'solver': 'sag'}
# 	Score: 0.832589643447
# 	Best score: 0.837431385832
#
# Interation no.:  38
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 36, 'random_state': 10, 'tol': 0.47510354493241214, 'copy_X': True, 'alpha': 0.5434218406942861, 'solver': 'sag'}
# 	Score: 0.818192663393
# 	Best score: 0.837431385832
#
# Interation no.:  39
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 11, 'random_state': 10, 'tol': 0.34045994114834, 'copy_X': True, 'alpha': 0.27534992712991335, 'solver': 'sag'}
# 	Score: 0.824799356313
# 	Best score: 0.837431385832
#
# Interation no.:  40
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 18, 'random_state': 10, 'tol': 0.688053422296702, 'copy_X': True, 'alpha': 0.6501702365463197, 'solver': 'sag'}
# 	Score: 0.817808698021
# 	Best score: 0.837431385832
#
# Interation no.:  41
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 23, 'random_state': 10, 'tol': 0.05171054052898244, 'copy_X': True, 'alpha': 0.45709609999960277, 'solver': 'sag'}
# 	Score: 0.836110966553
# 	Best score: 0.837431385832
#
# Interation no.:  42
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 5, 'random_state': 10, 'tol': 0.15110460376862425, 'copy_X': True, 'alpha': 0.37851348082145003, 'solver': 'sag'}
# 	Score: 0.836184772725
# 	Best score: 0.837431385832
#
# Interation no.:  43
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 37, 'random_state': 10, 'tol': 0.3813787252999074, 'copy_X': True, 'alpha': 0.5492780247729118, 'solver': 'sag'}
# 	Score: 0.823836516284
# 	Best score: 0.837431385832
#
# Interation no.:  44
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 14, 'random_state': 10, 'tol': 0.19539018103844402, 'copy_X': True, 'alpha': 0.21039406200417954, 'solver': 'sag'}
# 	Score: 0.835212484296
# 	Best score: 0.837431385832
#
# Interation no.:  45
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 21, 'random_state': 10, 'tol': 0.528116040355985, 'copy_X': True, 'alpha': 0.2676354563137236, 'solver': 'sag'}
# 	Score: 0.817156022829
# 	Best score: 0.837431385832
#
# Interation no.:  46
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 42, 'random_state': 10, 'tol': 0.25159784846464484, 'copy_X': True, 'alpha': 0.4832031319333307, 'solver': 'sag'}
# 	Score: 0.83278339455
# 	Best score: 0.837431385832
#
# Interation no.:  47
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 8, 'random_state': 10, 'tol': 0.9948726615970169, 'copy_X': True, 'alpha': 0.8201370163443271, 'solver': 'sag'}
# 	Score: 0.815027878588
# 	Best score: 0.837431385832
#
# Interation no.:  48
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 3, 'random_state': 10, 'tol': 0.6090142737307791, 'copy_X': True, 'alpha': 0.641047275344861, 'solver': 'sag'}
# 	Score: 0.817855588582
# 	Best score: 0.837431385832
#
# Interation no.:  49
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 13, 'random_state': 10, 'tol': 0.4351346864753738, 'copy_X': True, 'alpha': 0.728736627368361, 'solver': 'sag'}
# 	Score: 0.817656270573
# 	Best score: 0.837431385832
#
# Interation no.:  50
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 19, 'random_state': 10, 'tol': 0.02280011334540466, 'copy_X': True, 'alpha': 0.35896854456928573, 'solver': 'sag'}
# 	Score: 0.834438671181
# 	Best score: 0.837431385832
#
# Interation no.:  51
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 17, 'random_state': 10, 'tol': 0.10345359586107993, 'copy_X': True, 'alpha': 0.9553963242149544, 'solver': 'sag'}
# 	Score: 0.831608164645
# 	Best score: 0.837431385832
#
# Interation no.:  52
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 46, 'random_state': 10, 'tol': 0.336843403995592, 'copy_X': True, 'alpha': 0.18712018323595686, 'solver': 'sag'}
# 	Score: 0.823359885689
# 	Best score: 0.837431385832
#
# Interation no.:  53
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 34, 'random_state': 10, 'tol': 0.13268700006052533, 'copy_X': True, 'alpha': 0.2843245535494111, 'solver': 'sag'}
# 	Score: 0.838227944525
# 	Best score: 0.838227944525
#
# Interation no.:  54
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 34, 'random_state': 10, 'tol': 0.723428490406289, 'copy_X': True, 'alpha': 0.10129300204208358, 'solver': 'sag'}
# 	Score: 0.815015725416
# 	Best score: 0.838227944525
#
# Interation no.:  55
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 30, 'random_state': 10, 'tol': 0.4676944297553458, 'copy_X': True, 'alpha': 0.29212825653823343, 'solver': 'sag'}
# 	Score: 0.817389385055
# 	Best score: 0.838227944525
#
# Interation no.:  56
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 33, 'random_state': 10, 'tol': 0.8168900822361868, 'copy_X': True, 'alpha': 0.24512486510228204, 'solver': 'sag'}
# 	Score: 0.816913460876
# 	Best score: 0.838227944525
#
# Interation no.:  57
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 38, 'random_state': 10, 'tol': 0.4024184060433067, 'copy_X': True, 'alpha': 0.40698399196764956, 'solver': 'sag'}
# 	Score: 0.823009531357
# 	Best score: 0.838227944525
#
# Interation no.:  58
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 15, 'random_state': 10, 'tol': 0.9307777889191371, 'copy_X': True, 'alpha': 0.1479194820117218, 'solver': 'sag'}
# 	Score: 0.815016514341
# 	Best score: 0.838227944525
#
# Interation no.:  59
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 27, 'random_state': 10, 'tol': 0.08167039123499274, 'copy_X': True, 'alpha': 0.0977267226737934, 'solver': 'sag'}
# 	Score: 0.831500560063
# 	Best score: 0.838227944525
#
# Interation no.:  60
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 24, 'random_state': 10, 'tol': 0.2636201065336336, 'copy_X': True, 'alpha': 0.5347252439162082, 'solver': 'sag'}
# 	Score: 0.832975578592
# 	Best score: 0.838227944525
#
# Interation no.:  61
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 7, 'random_state': 10, 'tol': 0.5329710899456723, 'copy_X': True, 'alpha': 0.02578025214698859, 'solver': 'sag'}
# 	Score: 0.815014447545
# 	Best score: 0.838227944525
#
# Interation no.:  62
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 12, 'random_state': 10, 'tol': 0.1997766876857388, 'copy_X': True, 'alpha': 0.30979338344041846, 'solver': 'sag'}
# 	Score: 0.83598766615
# 	Best score: 0.838227944525
#
# Interation no.:  63
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 34, 'random_state': 10, 'tol': 0.2873430008446436, 'copy_X': True, 'alpha': 0.06341134886079502, 'solver': 'sag'}
# 	Score: 0.818125898887
# 	Best score: 0.838227944525
#
# Interation no.:  64
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 48, 'random_state': 10, 'tol': 0.006850405268255061, 'copy_X': True, 'alpha': 0.6860678250053328, 'solver': 'sag'}
# 	Score: 0.833238925475
# 	Best score: 0.838227944525
#
# Interation no.:  65
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 20, 'random_state': 10, 'tol': 0.37197925866461645, 'copy_X': True, 'alpha': 0.5806201259472293, 'solver': 'sag'}
# 	Score: 0.823852831454
# 	Best score: 0.838227944525
#
# Interation no.:  66
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 10, 'random_state': 10, 'tol': 0.13180923514561593, 'copy_X': True, 'alpha': 0.4454765738543963, 'solver': 'sag'}
# 	Score: 0.837194087314
# 	Best score: 0.838227944525
#
# Interation no.:  67
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 10, 'random_state': 10, 'tol': 0.03553450295391472, 'copy_X': True, 'alpha': 0.44429680816717765, 'solver': 'sag'}
# 	Score: 0.834100795969
# 	Best score: 0.838227944525
#
# Interation no.:  68
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.08076755000726513, 'copy_X': True, 'alpha': 0.39476274285104046, 'solver': 'sag'}
# 	Score: 0.837942823752
# 	Best score: 0.838227944525
#
# Interation no.:  69
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 32, 'random_state': 10, 'tol': 0.1803907734443546, 'copy_X': True, 'alpha': 0.21496561737548803, 'solver': 'sag'}
# 	Score: 0.83412849758
# 	Best score: 0.838227944525
#
# Interation no.:  70
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 47, 'random_state': 10, 'tol': 0.06856476213165869, 'copy_X': True, 'alpha': 0.3946676721103581, 'solver': 'sag'}
# 	Score: 0.835999336055
# 	Best score: 0.838227944525
#
# Interation no.:  71
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.22801059118937486, 'copy_X': True, 'alpha': 0.3551644001940427, 'solver': 'sag'}
# 	Score: 0.832475647156
# 	Best score: 0.838227944525
#
# Interation no.:  72
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 22, 'random_state': 10, 'tol': 0.1384897455440703, 'copy_X': True, 'alpha': 0.18085265152338492, 'solver': 'sag'}
# 	Score: 0.834483920174
# 	Best score: 0.838227944525
#
# Interation no.:  73
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.08957222635638579, 'copy_X': True, 'alpha': 0.4920053441410331, 'solver': 'sag'}
# 	Score: 0.837480047716
# 	Best score: 0.838227944525
#
# Interation no.:  74
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.08011962561376092, 'copy_X': True, 'alpha': 0.5104249731987494, 'solver': 'sag'}
# 	Score: 0.837651668492
# 	Best score: 0.838227944525
#
# Interation no.:  75
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.3177522468628348, 'copy_X': True, 'alpha': 0.7722349830149657, 'solver': 'sag'}
# 	Score: 0.827530626324
# 	Best score: 0.838227944525
#
# Interation no.:  76
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 41, 'random_state': 10, 'tol': 0.044140686811227, 'copy_X': True, 'alpha': 0.24219087420342156, 'solver': 'sag'}
# 	Score: 0.831596264856
# 	Best score: 0.838227944525
#
# Interation no.:  77
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 6, 'random_state': 10, 'tol': 0.1670021361944675, 'copy_X': True, 'alpha': 0.6337147491597089, 'solver': 'sag'}
# 	Score: 0.835487475125
# 	Best score: 0.838227944525
#
# Interation no.:  78
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 1, 'random_state': 10, 'tol': 0.00950101157259628, 'copy_X': True, 'alpha': 0.3350212067377926, 'solver': 'sag'}
# 	Score: 0.808756269877
# 	Best score: 0.838227944525
#
# Interation no.:  79
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.261084576425923, 'copy_X': True, 'alpha': 0.5566293676494456, 'solver': 'sag'}
# 	Score: 0.829372846908
# 	Best score: 0.838227944525
#
# Interation no.:  80
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.11662427578262052, 'copy_X': True, 'alpha': 0.28983272194805754, 'solver': 'sag'}
# 	Score: 0.836205858238
# 	Best score: 0.838227944525
#
# Interation no.:  81
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 45, 'random_state': 10, 'tol': 0.4065525891962242, 'copy_X': True, 'alpha': 0.38141953644870363, 'solver': 'sag'}
# 	Score: 0.822862297493
# 	Best score: 0.838227944525
#
# Interation no.:  82
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 16, 'random_state': 10, 'tol': 0.22401919317491106, 'copy_X': True, 'alpha': 0.515302213681138, 'solver': 'sag'}
# 	Score: 0.832724234619
# 	Best score: 0.838227944525
#
# Interation no.:  83
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 2, 'random_state': 10, 'tol': 0.05617958134232138, 'copy_X': True, 'alpha': 0.4291675523988936, 'solver': 'sag'}
# 	Score: 0.818158441749
# 	Best score: 0.838227944525
#
# Interation no.:  84
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 31, 'random_state': 10, 'tol': 0.30314511527732846, 'copy_X': True, 'alpha': 0.5806163806240976, 'solver': 'sag'}
# 	Score: 0.81991716099
# 	Best score: 0.838227944525
#
# Interation no.:  85
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 34, 'random_state': 10, 'tol': 0.18851659994967743, 'copy_X': True, 'alpha': 0.6956028477614273, 'solver': 'sag'}
# 	Score: 0.834870065621
# 	Best score: 0.838227944525
#
# Interation no.:  86
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 4, 'random_state': 10, 'tol': 0.024381095395218655, 'copy_X': True, 'alpha': 0.6219130323599484, 'solver': 'sag'}
# 	Score: 0.835590802722
# 	Best score: 0.838227944525
#
# Interation no.:  87
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 25, 'random_state': 10, 'tol': 0.3567429879418992, 'copy_X': True, 'alpha': 0.26143284929580957, 'solver': 'sag'}
# 	Score: 0.821471952834
# 	Best score: 0.838227944525
#
# Interation no.:  88
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 49, 'random_state': 10, 'tol': 0.07789583183842838, 'copy_X': True, 'alpha': 0.30645854134463546, 'solver': 'sag'}
# 	Score: 0.830315132366
# 	Best score: 0.838227944525
#
# Interation no.:  89
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 29, 'random_state': 10, 'tol': 0.865929559628583, 'copy_X': True, 'alpha': 0.6595003789534528, 'solver': 'sag'}
# 	Score: 0.817758179763
# 	Best score: 0.838227944525
#
# Interation no.:  90
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 35, 'random_state': 10, 'tol': 0.2421786843029602, 'copy_X': True, 'alpha': 0.13012579535352956, 'solver': 'sag'}
# 	Score: 0.829618777286
# 	Best score: 0.838227944525
#
# Interation no.:  91
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 28, 'random_state': 10, 'tol': 0.2712396671768212, 'copy_X': True, 'alpha': 0.5111968368694066, 'solver': 'sag'}
# 	Score: 0.832326961553
# 	Best score: 0.838227944525
#
# Interation no.:  92
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 9, 'random_state': 10, 'tol': 0.4525112868910418, 'copy_X': True, 'alpha': 0.41595102773274634, 'solver': 'sag'}
# 	Score: 0.818121088974
# 	Best score: 0.838227944525
#
# Interation no.:  93
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 14, 'random_state': 10, 'tol': 0.568374587014527, 'copy_X': True, 'alpha': 0.8359750871111812, 'solver': 'sag'}
# 	Score: 0.815028146121
# 	Best score: 0.838227944525
#
# Interation no.:  94
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 43, 'random_state': 10, 'tol': 0.15669597028672333, 'copy_X': True, 'alpha': 0.7236276015739964, 'solver': 'sag'}
# 	Score: 0.834552028062
# 	Best score: 0.838227944525
#
# Interation no.:  95
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 11, 'random_state': 10, 'tol': 0.2121184866055934, 'copy_X': True, 'alpha': 0.5689154945093, 'solver': 'sag'}
# 	Score: 0.83416984051
# 	Best score: 0.838227944525
#
# Interation no.:  96
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 40, 'random_state': 10, 'tol': 0.48684260691709885, 'copy_X': True, 'alpha': 0.22232692448295494, 'solver': 'sag'}
# 	Score: 0.816639412783
# 	Best score: 0.838227944525
#
# Interation no.:  97
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 18, 'random_state': 10, 'tol': 0.11631985708422758, 'copy_X': True, 'alpha': 0.16752353397676426, 'solver': 'sag'}
# 	Score: 0.832285344287
# 	Best score: 0.838227944525
#
# Interation no.:  98
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 8, 'random_state': 10, 'tol': 0.6095051906458516, 'copy_X': True, 'alpha': 0.333165377786009, 'solver': 'sag'}
# 	Score: 0.817712060225
# 	Best score: 0.838227944525
#
# Interation no.:  99
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 26, 'random_state': 10, 'tol': 0.417526390273427, 'copy_X': True, 'alpha': 0.7622890927752863, 'solver': 'sag'}
# 	Score: 0.817040298431
# 	Best score: 0.838227944525
#
# Interation no.:  100
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 23, 'random_state': 10, 'tol': 0.5251348560243486, 'copy_X': True, 'alpha': 0.4704685574943126, 'solver': 'sag'}
# 	Score: 0.818228898291
# 	Best score: 0.838227944525
#
# Interation no.:  101
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 21, 'random_state': 10, 'tol': 0.32245487693680724, 'copy_X': True, 'alpha': 0.9204831303282022, 'solver': 'sag'}
# 	Score: 0.825759679402
# 	Best score: 0.838227944525
#
# Interation no.:  102
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.6622860720489191, 'copy_X': True, 'alpha': 0.3556642159418734, 'solver': 'sag'}
# 	Score: 0.81502002834
# 	Best score: 0.838227944525
#
# Interation no.:  103
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 19, 'random_state': 10, 'tol': 0.7590155531478717, 'copy_X': True, 'alpha': 0.6073644580698695, 'solver': 'sag'}
# 	Score: 0.818006669526
# 	Best score: 0.838227944525
#
# Interation no.:  104
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 42, 'random_state': 10, 'tol': 0.10015612370338849, 'copy_X': True, 'alpha': 0.5285772179869519, 'solver': 'sag'}
# 	Score: 0.837512450521
# 	Best score: 0.838227944525
#
# Interation no.:  105
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 36, 'random_state': 10, 'tol': 0.005287236725798616, 'copy_X': True, 'alpha': 0.7964362857617779, 'solver': 'sag'}
# 	Score: 0.831694758296
# 	Best score: 0.838227944525
#
# Interation no.:  106
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 46, 'random_state': 10, 'tol': 0.1458584055477634, 'copy_X': True, 'alpha': 0.0012386200747047105, 'solver': 'sag'}
# 	Score: 0.827294572304
# 	Best score: 0.838227944525
#
# Interation no.:  107
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 3, 'random_state': 10, 'tol': 0.3626264187666748, 'copy_X': True, 'alpha': 0.060352144031124766, 'solver': 'sag'}
# 	Score: 0.818534003062
# 	Best score: 0.838227944525
#
# Interation no.:  108
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 37, 'random_state': 10, 'tol': 0.27714833322261956, 'copy_X': True, 'alpha': 0.3904296027906995, 'solver': 'sag'}
# 	Score: 0.831836753143
# 	Best score: 0.838227944525
#
# Interation no.:  109
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 33, 'random_state': 10, 'tol': 0.0784106949293183, 'copy_X': True, 'alpha': 0.4344503134013478, 'solver': 'sag'}
# 	Score: 0.837948629487
# 	Best score: 0.838227944525
#
# Interation no.:  110
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 30, 'random_state': 10, 'tol': 0.17666091544965074, 'copy_X': True, 'alpha': 0.1909876529804298, 'solver': 'sag'}
# 	Score: 0.833625198435
# 	Best score: 0.838227944525
#
# Interation no.:  111
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 33, 'random_state': 10, 'tol': 0.053986120228695866, 'copy_X': True, 'alpha': 0.12909172627026602, 'solver': 'sag'}
# 	Score: 0.829093844584
# 	Best score: 0.838227944525
#
# Interation no.:  112
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 13, 'random_state': 10, 'tol': 0.031038515162786245, 'copy_X': True, 'alpha': 0.2831540721177648, 'solver': 'sag'}
# 	Score: 0.833284879383
# 	Best score: 0.838227944525
#
# Interation no.:  113
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 27, 'random_state': 10, 'tol': 0.20602286703026682, 'copy_X': True, 'alpha': 0.43694800898169783, 'solver': 'sag'}
# 	Score: 0.835306198404
# 	Best score: 0.838227944525
#
# Interation no.:  114
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 33, 'random_state': 10, 'tol': 0.3932181553378938, 'copy_X': True, 'alpha': 0.36684334321959344, 'solver': 'sag'}
# 	Score: 0.822857061523
# 	Best score: 0.838227944525
#
# Interation no.:  115
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 34, 'random_state': 10, 'tol': 0.0007586797982177401, 'copy_X': True, 'alpha': 0.3200838991842275, 'solver': 'sag'}
# 	Score: 0.833941910351
# 	Best score: 0.838227944525
#
# Interation no.:  116
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 24, 'random_state': 10, 'tol': 0.11559968607704313, 'copy_X': True, 'alpha': 0.08382036435716211, 'solver': 'sag'}
# 	Score: 0.831966065172
# 	Best score: 0.838227944525
#
# Interation no.:  117
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 33, 'random_state': 10, 'tol': 0.29522191844235385, 'copy_X': True, 'alpha': 0.23302690611750126, 'solver': 'sag'}
# 	Score: 0.822851584909
# 	Best score: 0.838227944525
#
# Interation no.:  118
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 17, 'random_state': 10, 'tol': 0.2427350882576974, 'copy_X': True, 'alpha': 0.4608032757675288, 'solver': 'sag'}
# 	Score: 0.831158264022
# 	Best score: 0.838227944525
#
# Interation no.:  119
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 7, 'random_state': 10, 'tol': 0.5067777957069957, 'copy_X': True, 'alpha': 0.4057575849786083, 'solver': 'sag'}
# 	Score: 0.818087214696
# 	Best score: 0.838227944525
#
# Interation no.:  120
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 12, 'random_state': 10, 'tol': 0.13410834885651682, 'copy_X': True, 'alpha': 0.20327728630914121, 'solver': 'sag'}
# 	Score: 0.834964278042
# 	Best score: 0.838227944525
#
# Interation no.:  121
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 38, 'random_state': 10, 'tol': 0.33831921259918163, 'copy_X': True, 'alpha': 0.2602910689341836, 'solver': 'sag'}
# 	Score: 0.824591693057
# 	Best score: 0.838227944525
#
# Interation no.:  122
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 32, 'random_state': 10, 'tol': 0.06876994538237217, 'copy_X': True, 'alpha': 0.15895317085307342, 'solver': 'sag'}
# 	Score: 0.831894482251
# 	Best score: 0.838227944525
#
# Interation no.:  123
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 15, 'random_state': 10, 'tol': 0.18753649638079717, 'copy_X': True, 'alpha': 0.9967579685133008, 'solver': 'sag'}
# 	Score: 0.836189491074
# 	Best score: 0.838227944525
#
# Interation no.:  124
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 20, 'random_state': 10, 'tol': 0.16612410867828079, 'copy_X': True, 'alpha': 0.4913886864261657, 'solver': 'sag'}
# 	Score: 0.836369214723
# 	Best score: 0.838227944525
#
# Interation no.:  125
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 45, 'random_state': 10, 'tol': 0.08856790182919592, 'copy_X': True, 'alpha': 0.25230997155554136, 'solver': 'sag'}
# 	Score: 0.836683905195
# 	Best score: 0.838227944525
#
# Interation no.:  126
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 22, 'random_state': 10, 'tol': 0.038805854953032674, 'copy_X': True, 'alpha': 0.3518863699151183, 'solver': 'sag'}
# 	Score: 0.833549505472
# 	Best score: 0.838227944525
#
# Interation no.:  127
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 1, 'random_state': 10, 'tol': 0.4597081384208449, 'copy_X': True, 'alpha': 0.30213682243059736, 'solver': 'sag'}
# 	Score: 0.808221181164
# 	Best score: 0.838227944525
#
# Interation no.:  128
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.02002686507543394, 'copy_X': True, 'alpha': 0.5633544715726521, 'solver': 'sag'}
# 	Score: 0.814968586954
# 	Best score: 0.838227944525
#
# Interation no.:  129
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 16, 'random_state': 10, 'tol': 0.21911481034391855, 'copy_X': True, 'alpha': 0.03445786415074986, 'solver': 'sag'}
# 	Score: 0.826771354555
# 	Best score: 0.838227944525
#
# Interation no.:  130
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 41, 'random_state': 10, 'tol': 0.4278118300201703, 'copy_X': True, 'alpha': 0.4230623633138356, 'solver': 'sag'}
# 	Score: 0.818142100748
# 	Best score: 0.838227944525
#
# Interation no.:  131
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 48, 'random_state': 10, 'tol': 0.820816568411624, 'copy_X': True, 'alpha': 0.625134613862524, 'solver': 'sag'}
# 	Score: 0.817931341838
# 	Best score: 0.838227944525
#
# Interation no.:  132
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 34, 'random_state': 10, 'tol': 0.322261511124921, 'copy_X': True, 'alpha': 0.6647995049073985, 'solver': 'sag'}
# 	Score: 0.828558046105
# 	Best score: 0.838227944525
#
# Interation no.:  133
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 6, 'random_state': 10, 'tol': 0.1240036935782059, 'copy_X': True, 'alpha': 0.11817852076162594, 'solver': 'sag'}
# 	Score: 0.833081393419
# 	Best score: 0.838227944525
#
# Interation no.:  134
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 2, 'random_state': 10, 'tol': 0.1456207746856304, 'copy_X': True, 'alpha': 0.5338732806680546, 'solver': 'sag'}
# 	Score: 0.818208471921
# 	Best score: 0.838227944525
#
# Interation no.:  135
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 4, 'random_state': 10, 'tol': 0.695075216068973, 'copy_X': True, 'alpha': 0.33095707381676753, 'solver': 'sag'}
# 	Score: 0.817696806568
# 	Best score: 0.838227944525
#
# Interation no.:  136
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 25, 'random_state': 10, 'tol': 0.9108349234281619, 'copy_X': True, 'alpha': 0.4496335504185134, 'solver': 'sag'}
# 	Score: 0.818201969527
# 	Best score: 0.838227944525
#
# Interation no.:  137
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 49, 'random_state': 10, 'tol': 0.2465525273372446, 'copy_X': True, 'alpha': 0.2756163970751375, 'solver': 'sag'}
# 	Score: 0.831761615093
# 	Best score: 0.838227944525
#
# Interation no.:  138
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 5, 'random_state': 10, 'tol': 0.384815517082742, 'copy_X': True, 'alpha': 0.5901714005090218, 'solver': 'sag'}
# 	Score: 0.818546756801
# 	Best score: 0.838227944525
#
# Interation no.:  139
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 35, 'random_state': 10, 'tol': 0.05701738932680471, 'copy_X': True, 'alpha': 0.7057669509476892, 'solver': 'sag'}
# 	Score: 0.833953839869
# 	Best score: 0.838227944525
#
# Interation no.:  140
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 31, 'random_state': 10, 'tol': 0.989290142074342, 'copy_X': True, 'alpha': 0.4837907415155523, 'solver': 'sag'}
# 	Score: 0.818237174157
# 	Best score: 0.838227944525
#
# Interation no.:  141
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 9, 'random_state': 10, 'tol': 0.6098248552488833, 'copy_X': True, 'alpha': 0.37471934348591673, 'solver': 'sag'}
# 	Score: 0.817956148775
# 	Best score: 0.838227944525
#
# Interation no.:  142
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 29, 'random_state': 10, 'tol': 0.09385282620340324, 'copy_X': True, 'alpha': 0.40199655306814275, 'solver': 'sag'}
# 	Score: 0.837953180143
# 	Best score: 0.838227944525
#
# Interation no.:  143
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 28, 'random_state': 10, 'tol': 0.0977734884778651, 'copy_X': True, 'alpha': 0.7420387409140488, 'solver': 'sag'}
# 	Score: 0.833779243854
# 	Best score: 0.838227944525
#
# Interation no.:  144
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 29, 'random_state': 10, 'tol': 0.27916772391765216, 'copy_X': True, 'alpha': 0.2084968032111936, 'solver': 'sag'}
# 	Score: 0.828067369613
# 	Best score: 0.838227944525
#
# Interation no.:  145
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 29, 'random_state': 10, 'tol': 0.5550794214509144, 'copy_X': True, 'alpha': 0.0850330659771073, 'solver': 'sag'}
# 	Score: 0.814326624607
# 	Best score: 0.838227944525
#
# Interation no.:  146
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 29, 'random_state': 10, 'tol': 0.0008211964535266847, 'copy_X': True, 'alpha': 0.3427092712557707, 'solver': 'sag'}
# 	Score: 0.834227770232
# 	Best score: 0.838227944525
#
# Interation no.:  147
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 43, 'random_state': 10, 'tol': 0.18880492411726374, 'copy_X': True, 'alpha': 0.4019345591051039, 'solver': 'sag'}
# 	Score: 0.836434547526
# 	Best score: 0.838227944525
#
# Interation no.:  148
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 11, 'random_state': 10, 'tol': 0.07857485489391408, 'copy_X': True, 'alpha': 0.31062684588809375, 'solver': 'sag'}
# 	Score: 0.837469431405
# 	Best score: 0.838227944525
#
# Interation no.:  149
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 33, 'random_state': 10, 'tol': 0.045442474226106894, 'copy_X': True, 'alpha': 0.5046461764606998, 'solver': 'sag'}
# 	Score: 0.834659199046
# 	Best score: 0.838227944525
#
# Interation no.:  150
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 40, 'random_state': 10, 'tol': 0.16653860086355854, 'copy_X': True, 'alpha': 0.38243963185247487, 'solver': 'sag'}
# 	Score: 0.836205366647
# 	Best score: 0.838227944525
#
# Interation no.:  151
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 26, 'random_state': 10, 'tol': 0.019096583530699623, 'copy_X': True, 'alpha': 0.46851060998754107, 'solver': 'sag'}
# 	Score: 0.834999229316
# 	Best score: 0.838227944525
#
# Interation no.:  152
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 36, 'random_state': 10, 'tol': 0.10471897171175794, 'copy_X': True, 'alpha': 0.2270044291357086, 'solver': 'sag'}
# 	Score: 0.835769545949
# 	Best score: 0.838227944525
#
# Interation no.:  153
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 14, 'random_state': 10, 'tol': 0.23054491481604822, 'copy_X': True, 'alpha': 0.4281545766657281, 'solver': 'sag'}
# 	Score: 0.832764497665
# 	Best score: 0.838227944525
#
# Interation no.:  154
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 18, 'random_state': 10, 'tol': 0.211613543900851, 'copy_X': True, 'alpha': 0.5518102447996327, 'solver': 'sag'}
# 	Score: 0.834272743336
# 	Best score: 0.838227944525
#
# Interation no.:  155
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 23, 'random_state': 10, 'tol': 0.1458417424041087, 'copy_X': True, 'alpha': 0.17583422510185892, 'solver': 'sag'}
# 	Score: 0.837116841215
# 	Best score: 0.838227944525
#
# Interation no.:  156
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 10, 'random_state': 10, 'tol': 0.06888285529136128, 'copy_X': True, 'alpha': 0.4042575174213836, 'solver': 'sag'}
# 	Score: 0.836335130603
# 	Best score: 0.838227944525
#
# Interation no.:  157
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 21, 'random_state': 10, 'tol': 0.0014471972274900935, 'copy_X': True, 'alpha': 0.28967301684767366, 'solver': 'sag'}
# 	Score: 0.833389873471
# 	Best score: 0.838227944525
#
# Interation no.:  158
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 47, 'random_state': 10, 'tol': 0.2623210361204743, 'copy_X': True, 'alpha': 0.1484247643036702, 'solver': 'sag'}
# 	Score: 0.829553190142
# 	Best score: 0.838227944525
#
# Interation no.:  159
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 42, 'random_state': 10, 'tol': 0.3062664302508663, 'copy_X': True, 'alpha': 0.5241530108966496, 'solver': 'sag'}
# 	Score: 0.827372109396
# 	Best score: 0.838227944525
#
# Interation no.:  160
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 34, 'random_state': 10, 'tol': 0.13057662726742175, 'copy_X': True, 'alpha': 0.3657171844546921, 'solver': 'sag'}
# 	Score: 0.837389473728
# 	Best score: 0.838227944525
#
# Interation no.:  161
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 37, 'random_state': 10, 'tol': 0.35287763772520253, 'copy_X': True, 'alpha': 0.4478084447383838, 'solver': 'sag'}
# 	Score: 0.826213769545
# 	Best score: 0.838227944525
#
# Interation no.:  162
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 3, 'random_state': 10, 'tol': 0.03956417309708968, 'copy_X': True, 'alpha': 0.2498137057975946, 'solver': 'sag'}
# 	Score: 0.829354092514
# 	Best score: 0.838227944525
#
# Interation no.:  163
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 8, 'random_state': 10, 'tol': 0.2020874390503567, 'copy_X': True, 'alpha': 0.2727427492361884, 'solver': 'sag'}
# 	Score: 0.835631854749
# 	Best score: 0.838227944525
#
# Interation no.:  164
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 19, 'random_state': 10, 'tol': 0.15831196908434542, 'copy_X': True, 'alpha': 0.604807152850245, 'solver': 'sag'}
# 	Score: 0.835731755584
# 	Best score: 0.838227944525
#
# Interation no.:  165
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 46, 'random_state': 10, 'tol': 0.10038628449064403, 'copy_X': True, 'alpha': 0.32745979273814196, 'solver': 'sag'}
# 	Score: 0.829801312703
# 	Best score: 0.838227944525
#
# Interation no.:  166
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 13, 'random_state': 10, 'tol': 0.08028610357061608, 'copy_X': True, 'alpha': 0.49240085829882063, 'solver': 'sag'}
# 	Score: 0.837754814702
# 	Best score: 0.838227944525
#
# Interation no.:  167
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.11808775530106784, 'copy_X': True, 'alpha': 0.1927107519659081, 'solver': 'sag'}
# 	Score: 0.834348937631
# 	Best score: 0.838227944525
#
# Interation no.:  168
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 17, 'random_state': 10, 'tol': 0.18353251282997768, 'copy_X': True, 'alpha': 0.30486757705276235, 'solver': 'sag'}
# 	Score: 0.83594666317
# 	Best score: 0.838227944525
#
# Interation no.:  169
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 24, 'random_state': 10, 'tol': 0.0574867902987881, 'copy_X': True, 'alpha': 0.3484207860628604, 'solver': 'sag'}
# 	Score: 0.835745932221
# 	Best score: 0.838227944525
#
# Interation no.:  170
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 45, 'random_state': 10, 'tol': 0.001153233621069144, 'copy_X': True, 'alpha': 0.3912261613850422, 'solver': 'sag'}
# 	Score: 0.834611009088
# 	Best score: 0.838227944525
#
# Interation no.:  171
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 30, 'random_state': 10, 'tol': 0.28770416091233175, 'copy_X': True, 'alpha': 0.4190864660868027, 'solver': 'sag'}
# 	Score: 0.826587042733
# 	Best score: 0.838227944525
#
# Interation no.:  172
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 38, 'random_state': 10, 'tol': 0.02923795397366727, 'copy_X': True, 'alpha': 0.5653638666326948, 'solver': 'sag'}
# 	Score: 0.833859672252
# 	Best score: 0.838227944525
#
# Interation no.:  173
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 15, 'random_state': 10, 'tol': 0.23511730344829343, 'copy_X': True, 'alpha': 0.47188134194168996, 'solver': 'sag'}
# 	Score: 0.832792321688
# 	Best score: 0.838227944525
#
# Interation no.:  174
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 32, 'random_state': 10, 'tol': 0.09081066452416225, 'copy_X': True, 'alpha': 0.4377300195312975, 'solver': 'sag'}
# 	Score: 0.837943753822
# 	Best score: 0.838227944525
#
# Interation no.:  175
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 32, 'random_state': 10, 'tol': 0.16445735720372825, 'copy_X': True, 'alpha': 0.5441119150165508, 'solver': 'sag'}
# 	Score: 0.836141268067
# 	Best score: 0.838227944525
#
# Interation no.:  176
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 27, 'random_state': 10, 'tol': 0.3228782160969638, 'copy_X': True, 'alpha': 0.6365193296654803, 'solver': 'sag'}
# 	Score: 0.828726654744
# 	Best score: 0.838227944525
#
# Interation no.:  177
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 32, 'random_state': 10, 'tol': 0.2594588494196483, 'copy_X': True, 'alpha': 0.8555254453155194, 'solver': 'sag'}
# 	Score: 0.829379982608
# 	Best score: 0.838227944525
#
# Interation no.:  178
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 32, 'random_state': 10, 'tol': 0.19855646750871697, 'copy_X': True, 'alpha': 0.6819555044295607, 'solver': 'sag'}
# 	Score: 0.833537874816
# 	Best score: 0.838227944525
#
# Interation no.:  179
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 7, 'random_state': 10, 'tol': 0.13353536561881418, 'copy_X': True, 'alpha': 0.23942096234330937, 'solver': 'sag'}
# 	Score: 0.835593158913
# 	Best score: 0.838227944525
#
# Interation no.:  180
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 33, 'random_state': 10, 'tol': 0.016172455935805366, 'copy_X': True, 'alpha': 0.4434424830673281, 'solver': 'sag'}
# 	Score: 0.835092523573
# 	Best score: 0.838227944525
#
# Interation no.:  181
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 29, 'random_state': 10, 'tol': 0.10102104838963934, 'copy_X': True, 'alpha': 0.4915512626605614, 'solver': 'sag'}
# 	Score: 0.837781649305
# ...
# 	Score: 0.834793311309
# 	Best score: 0.838688534234
#
# Interation no.:  942
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 15, 'random_state': 10, 'tol': 0.09470363808857118, 'copy_X': True, 'alpha': 0.38039486569144537, 'solver': 'sag'}
# 	Score: 0.837909165391
# 	Best score: 0.838688534234
#
# Interation no.:  943
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 45, 'random_state': 10, 'tol': 2.563735920238508e-05, 'copy_X': True, 'alpha': 0.4245988419831237, 'solver': 'sag'}
# 	Score: 0.834788983162
# 	Best score: 0.838688534234
#
# Interation no.:  944
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 24, 'random_state': 10, 'tol': 0.5475841455909827, 'copy_X': True, 'alpha': 0.32203130364906285, 'solver': 'sag'}
# 	Score: 0.817632743378
# 	Best score: 0.838688534234
#
# Interation no.:  945
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 27, 'random_state': 10, 'tol': 0.33327854618346164, 'copy_X': True, 'alpha': 0.363903023333167, 'solver': 'sag'}
# 	Score: 0.821253777278
# 	Best score: 0.838688534234
#
# Interation no.:  946
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 12, 'random_state': 10, 'tol': 0.12360604204122186, 'copy_X': True, 'alpha': 0.23674222764125813, 'solver': 'sag'}
# 	Score: 0.835552316721
# 	Best score: 0.838688534234
#
# Interation no.:  947
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 7, 'random_state': 10, 'tol': 0.1725520628915005, 'copy_X': True, 'alpha': 0.48335510494355527, 'solver': 'sag'}
# 	Score: 0.836392437296
# 	Best score: 0.838688534234
#
# Interation no.:  948
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 38, 'random_state': 10, 'tol': 0.04401075400557772, 'copy_X': True, 'alpha': 0.33796494396949006, 'solver': 'sag'}
# 	Score: 0.833152939061
# 	Best score: 0.838688534234
#
# Interation no.:  949
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 20, 'random_state': 10, 'tol': 0.15291468211104647, 'copy_X': True, 'alpha': 0.296465456211571, 'solver': 'sag'}
# 	Score: 0.836251958882
# 	Best score: 0.838688534234
#
# Interation no.:  950
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 26, 'random_state': 10, 'tol': 0.21848438270093998, 'copy_X': True, 'alpha': 0.438243768095888, 'solver': 'sag'}
# 	Score: 0.833341237103
# 	Best score: 0.838688534234
#
# Interation no.:  951
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 1, 'random_state': 10, 'tol': 0.10959734049648079, 'copy_X': True, 'alpha': 0.40608558762837244, 'solver': 'sag'}
# 	Score: 0.809789165088
# 	Best score: 0.838688534234
#
# Interation no.:  952
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 11, 'random_state': 10, 'tol': 0.2678412650848332, 'copy_X': True, 'alpha': 0.26448388602661443, 'solver': 'sag'}
# 	Score: 0.831624257005
# 	Best score: 0.838688534234
#
# Interation no.:  953
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 48, 'random_state': 10, 'tol': 0.06718456655107305, 'copy_X': True, 'alpha': 0.3603197148466314, 'solver': 'sag'}
# 	Score: 0.835830928306
# 	Best score: 0.838688534234
#
# Interation no.:  954
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 22, 'random_state': 10, 'tol': 0.19857992535958957, 'copy_X': True, 'alpha': 0.328045344069072, 'solver': 'sag'}
# 	Score: 0.8361235162
# 	Best score: 0.838688534234
#
# Interation no.:  955
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 35, 'random_state': 10, 'tol': 0.09137108318675027, 'copy_X': True, 'alpha': 0.5058518733441865, 'solver': 'sag'}
# 	Score: 0.830302327064
# 	Best score: 0.838688534234
#
# Interation no.:  956
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 16, 'random_state': 10, 'tol': 0.4900988090801813, 'copy_X': True, 'alpha': 0.3825776899118698, 'solver': 'sag'}
# 	Score: 0.817993373671
# 	Best score: 0.838688534234
#
# Interation no.:  957
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.13201162619710619, 'copy_X': True, 'alpha': 0.2815809154477012, 'solver': 'sag'}
# 	Score: 0.83871647579
# 	Best score: 0.83871647579
#
# Interation no.:  958
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.1757454209845443, 'copy_X': True, 'alpha': 0.2152053582013618, 'solver': 'sag'}
# 	Score: 0.834133203663
# 	Best score: 0.83871647579
#
# Interation no.:  959
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.2540808016961587, 'copy_X': True, 'alpha': 0.14143750013418568, 'solver': 'sag'}
# 	Score: 0.829387355122
# 	Best score: 0.83871647579
#
# Interation no.:  960
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 45, 'random_state': 10, 'tol': 0.03010181806587968, 'copy_X': True, 'alpha': 0.18959086232816794, 'solver': 'sag'}
# 	Score: 0.83098525063
# 	Best score: 0.83871647579
#
# Interation no.:  961
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 4, 'random_state': 10, 'tol': 0.22970763993839444, 'copy_X': True, 'alpha': 0.17020465991646755, 'solver': 'sag'}
# 	Score: 0.831053420536
# 	Best score: 0.83871647579
#
# Interation no.:  962
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.14340002141331584, 'copy_X': True, 'alpha': 0.1607935164465958, 'solver': 'sag'}
# 	Score: 0.833990128944
# 	Best score: 0.83871647579
#
# Interation no.:  963
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.998829321733554, 'copy_X': True, 'alpha': 0.22892457191935162, 'solver': 'sag'}
# 	Score: 0.816721716038
# 	Best score: 0.83871647579
#
# Interation no.:  964
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.0545054690122312, 'copy_X': True, 'alpha': 0.2798061405324129, 'solver': 'sag'}
# 	Score: 0.835047443614
# 	Best score: 0.83871647579
#
# Interation no.:  965
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 32, 'random_state': 10, 'tol': 0.11377105724645671, 'copy_X': True, 'alpha': 0.2041683059325524, 'solver': 'sag'}
# 	Score: 0.835574869772
# 	Best score: 0.83871647579
#
# Interation no.:  966
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.16282110663258087, 'copy_X': True, 'alpha': 0.2563206696396561, 'solver': 'sag'}
# 	Score: 0.833079312252
# 	Best score: 0.83871647579
#
# Interation no.:  967
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.2894916119725215, 'copy_X': True, 'alpha': 0.23832645644056935, 'solver': 'sag'}
# 	Score: 0.824458495311
# 	Best score: 0.83871647579
#
# Interation no.:  968
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.20192072154570936, 'copy_X': True, 'alpha': 0.30851397999292746, 'solver': 'sag'}
# 	Score: 0.835403506356
# 	Best score: 0.83871647579
#
# Interation no.:  969
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 2, 'random_state': 10, 'tol': 0.07857004491446873, 'copy_X': True, 'alpha': 0.27006903713765495, 'solver': 'sag'}
# 	Score: 0.817180616719
# 	Best score: 0.83871647579
#
# Interation no.:  970
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 6, 'random_state': 10, 'tol': 0.13162638180052647, 'copy_X': True, 'alpha': 0.3042427974310617, 'solver': 'sag'}
# 	Score: 0.83768926088
# 	Best score: 0.83871647579
#
# Interation no.:  971
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 25, 'random_state': 10, 'tol': 0.10143278808400441, 'copy_X': True, 'alpha': 0.285509184502588, 'solver': 'sag'}
# 	Score: 0.836506683954
# 	Best score: 0.83871647579
#
# Interation no.:  972
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.17701542784614663, 'copy_X': True, 'alpha': 0.1182564042851208, 'solver': 'sag'}
# 	Score: 0.831458707321
# 	Best score: 0.83871647579
#
# Interation no.:  973
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.4639123131115691, 'copy_X': True, 'alpha': 0.3467576142462743, 'solver': 'sag'}
# 	Score: 0.817800804888
# 	Best score: 0.83871647579
#
# Interation no.:  974
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 31, 'random_state': 10, 'tol': 0.05030634479775892, 'copy_X': True, 'alpha': 0.21325670255643056, 'solver': 'sag'}
# 	Score: 0.832234515354
# 	Best score: 0.83871647579
#
# Interation no.:  975
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 5, 'random_state': 10, 'tol': 0.0003891857704678148, 'copy_X': True, 'alpha': 0.1980778370522294, 'solver': 'sag'}
# 	Score: 0.834000373007
# 	Best score: 0.83871647579
#
# Interation no.:  976
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 28, 'random_state': 10, 'tol': 0.24202943870863344, 'copy_X': True, 'alpha': 0.24936371509533223, 'solver': 'sag'}
# 	Score: 0.831152691268
# 	Best score: 0.83871647579
#
# Interation no.:  977
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 41, 'random_state': 10, 'tol': 0.08436189859495101, 'copy_X': True, 'alpha': 0.18118763114202957, 'solver': 'sag'}
# 	Score: 0.835068366924
# 	Best score: 0.83871647579
#
# Interation no.:  978
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 49, 'random_state': 10, 'tol': 0.15153937531654083, 'copy_X': True, 'alpha': 0.34576868259264404, 'solver': 'sag'}
# 	Score: 0.836781715739
# 	Best score: 0.83871647579
#
# Interation no.:  979
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 39, 'random_state': 10, 'tol': 0.03297915583767534, 'copy_X': True, 'alpha': 0.23280030512181948, 'solver': 'sag'}
# 	Score: 0.832055942588
# 	Best score: 0.83871647579
#
# Interation no.:  980
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 9, 'random_state': 10, 'tol': 0.3058567186004267, 'copy_X': True, 'alpha': 0.29356026002133606, 'solver': 'sag'}
# 	Score: 0.824150274722
# 	Best score: 0.83871647579
#
# Interation no.:  981
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 10, 'random_state': 10, 'tol': 0.4366962578213965, 'copy_X': True, 'alpha': 0.14678133441731478, 'solver': 'sag'}
# 	Score: 0.815514355297
# 	Best score: 0.83871647579
#
# Interation no.:  982
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 36, 'random_state': 10, 'tol': 0.2173907125818217, 'copy_X': True, 'alpha': 0.3933844458517046, 'solver': 'sag'}
# 	Score: 0.833234044749
# 	Best score: 0.83871647579
#
# Interation no.:  983
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 40, 'random_state': 10, 'tol': 0.27481477486981387, 'copy_X': True, 'alpha': 0.45906992155294063, 'solver': 'sag'}
# 	Score: 0.832375260064
# 	Best score: 0.83871647579
#
# Interation no.:  984
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 45, 'random_state': 10, 'tol': 0.1236438825127267, 'copy_X': True, 'alpha': 0.31938378062465905, 'solver': 'sag'}
# 	Score: 0.836439646827
# 	Best score: 0.83871647579
#
# Interation no.:  985
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 47, 'random_state': 10, 'tol': 0.18597915770919685, 'copy_X': True, 'alpha': 0.36676296523507657, 'solver': 'sag'}
# 	Score: 0.836332043652
# 	Best score: 0.83871647579
#
# Interation no.:  986
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 18, 'random_state': 10, 'tol': 0.10476040857640852, 'copy_X': True, 'alpha': 0.41671793159788073, 'solver': 'sag'}
# 	Score: 0.831582865897
# 	Best score: 0.83871647579
#
# Interation no.:  987
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 42, 'random_state': 10, 'tol': 0.06758595899367333, 'copy_X': True, 'alpha': 0.08690148517843477, 'solver': 'sag'}
# 	Score: 0.828798597699
# 	Best score: 0.83871647579
#
# Interation no.:  988
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 43, 'random_state': 10, 'tol': 0.15264681231511068, 'copy_X': True, 'alpha': 0.25341999400813087, 'solver': 'sag'}
# 	Score: 0.835594667749
# 	Best score: 0.83871647579
#
# Interation no.:  989
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 11, 'random_state': 10, 'tol': 0.2095686361694563, 'copy_X': True, 'alpha': 0.2698753211810613, 'solver': 'sag'}
# 	Score: 0.834998144717
# 	Best score: 0.83871647579
#
# Interation no.:  990
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 14, 'random_state': 10, 'tol': 0.13752280303933265, 'copy_X': True, 'alpha': 0.44300054722817317, 'solver': 'sag'}
# 	Score: 0.837192637864
# 	Best score: 0.83871647579
#
# Interation no.:  991
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 23, 'random_state': 10, 'tol': 0.00010558313383829399, 'copy_X': True, 'alpha': 0.33255018156282745, 'solver': 'sag'}
# 	Score: 0.834102604445
# 	Best score: 0.83871647579
#
# Interation no.:  992
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 26, 'random_state': 10, 'tol': 0.34104985926708353, 'copy_X': True, 'alpha': 0.3094756893524222, 'solver': 'sag'}
# 	Score: 0.825215962129
# 	Best score: 0.83871647579
#
# Interation no.:  993
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 8, 'random_state': 10, 'tol': 0.017090140248556263, 'copy_X': True, 'alpha': 0.3667180861045637, 'solver': 'sag'}
# 	Score: 0.833935407486
# 	Best score: 0.83871647579
#
# Interation no.:  994
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 19, 'random_state': 10, 'tol': 0.8057495380318169, 'copy_X': True, 'alpha': 0.5451868581234036, 'solver': 'sag'}
# 	Score: 0.81818938992
# 	Best score: 0.83871647579
#
# Interation no.:  995
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 37, 'random_state': 10, 'tol': 0.08969073684218898, 'copy_X': True, 'alpha': 0.01589515905127903, 'solver': 'sag'}
# 	Score: 0.826619655235
# 	Best score: 0.83871647579
#
# Interation no.:  996
# Training with params :
# {'normalize': False, 'fit_intercept': True, 'max_iter': 33, 'random_state': 10, 'tol': 0.742464631910057, 'copy_X': True, 'alpha': 0.3969381526170089, 'solver': 'sag'}
# 	Score: 0.815020726281
# 	Best score: 0.83871647579
#
# Interation no.:  997
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 46, 'random_state': 10, 'tol': 0.23132123827203913, 'copy_X': True, 'alpha': 0.28646039727036815, 'solver': 'sag'}
# 	Score: 0.832453900849
# 	Best score: 0.83871647579
#
# Interation no.:  998
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 45, 'random_state': 10, 'tol': 0.1831217350046916, 'copy_X': True, 'alpha': 0.4835230848798562, 'solver': 'sag'}
# 	Score: 0.836391984452
# 	Best score: 0.83871647579
#
# Interation no.:  999
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 3, 'random_state': 10, 'tol': 0.1630718819027126, 'copy_X': True, 'alpha': 0.2350715380250125, 'solver': 'sag'}
# 	Score: 0.829143624229
# 	Best score: 0.83871647579
#
# Interation no.:  1000
# Training with params :
# {'normalize': True, 'fit_intercept': True, 'max_iter': 24, 'random_state': 10, 'tol': 0.11982674621911873, 'copy_X': True, 'alpha': 0.42399877308769646, 'solver': 'sag'}
# 	Score: 0.837543912145
# 	Best score: 0.83871647579
#
# Best parameters:
# {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.13201162619710619, 'copy_X': True, 'alpha': 0.2815809154477012, 'solver': 'sag'}
# 	Score 0.83871647579

# %%
params = {'normalize': True, 'fit_intercept': True, 'max_iter': 44, 'random_state': 10, 'tol': 0.13201162619710619,
          'copy_X': True, 'alpha': 0.2815809154477012, 'solver': 'sag'}
reg1 = Ridge(
            alpha = params['alpha'],
            tol = params['tol'],
            solver = params['solver'],
            max_iter = params['max_iter'],
            normalize = params['normalize'], 
            fit_intercept = params['fit_intercept'],
            copy_X = params['copy_X'],
            random_state = params['random_state']         
            )
modelfit(reg1, X_train, y_train)
# Out:
# Model Report
# Train_coef_of_det: 0.889356
# CV_coef_of_det: Mean-0.838716 | Std-0.088595 | Min-0.597462 | Max-0.911908

# %% [markdown]
# ### Grid search + Genetic programming ( 'sklearn-deap' package)

# %%
params = {
        'alpha': [i/10.0 for i in range(0,11)],
        'tol': [10**(-i) for i in range(0,11)],
        'solver': ['sag'],
        'max_iter': range(1,50),
        'normalize': [True,False],
        'fit_intercept': [True],
        'copy_X': [True],
        'random_state': [10] 
         }
evol = EvolutionaryAlgorithmSearchCV(estimator=Ridge(), params=params, cv=10,
        scoring='r2', population_size=100, gene_mutation_prob=0.5, gene_crossover_prob=0.5, tournament_size=7,
        generations_number=25, verbose=True, n_jobs=-1)
evol.fit(X_train, y_train)

# %%
params = {}
reg1 = Ridge(
            alpha = params['alpha'],
            tol = params['tol'],
            solver = params['solver'],
            max_iter = params['max_iter'],
            normalize = params['normalize'], 
            fit_intercept = params['fit_intercept'],
            copy_X = params['copy_X'],
            random_state = params['random_state']         
            )
modelfit(reg1, X_train, y_train)

# %% [markdown]
# ### Make predictions and save results

# %%
test_pred = reg1.predict(X_test)
dictn = {'Id': range(1461,2920), 'SalePrice': test_pred}
res = pd.DataFrame(dictn)
res.to_csv('submission.csv', index=0)
