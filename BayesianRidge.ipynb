# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from evolutionary_search import EvolutionaryAlgorithmSearchCV
from hyperopt import fmin, tpe, hp, STATUS_OK
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from sklearn.linear_model import BayesianRidge

# %% [markdown]
# ## Step I. Load data

# %%
train = pd.read_csv('train.csv')
X_test = pd.read_csv('X_test.csv')

X_train = train.iloc[:, :-1]
y_train = train.iloc[:, -1]

# %% [markdown]
# ## Step II. Buid the model and perform parameter tuning

# %%
def modelfit(reg, train, target, performCV=True, cv=10):
    reg.fit(train, target)
    pred = reg.predict(train)
    train_r2_score = r2_score(target, pred)
    
    print('\nModel Report')
    print('Train_coef_of_det: %0.6f' %(train_r2_score))
    
    if performCV:
        cv_r2_score = cross_val_score(reg, train, target, cv=cv, scoring='r2', n_jobs=-1)
        print('CV_coef_of_det: Mean-%0.6f | Std-%0.6f | Min-%0.6f | Max-%0.6f' %(np.mean(cv_r2_score),
            np.std(cv_r2_score), np.min(cv_r2_score), np.max(cv_r2_score)))

# %% [markdown]
# ### Baseline model

# %%
params = {}
grid = GridSearchCV(estimator=BayesianRidge(), param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.81727887521

# %%
params = {}
grid = GridSearchCV(estimator=BayesianRidge(n_iter=300, tol=0.001, alpha_1=1e-06, alpha_2=1e-06, lambda_1=1e-06,
        lambda_2=1e-06, compute_score=False, fit_intercept=True, normalize=False, copy_X=True, verbose=False),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.81727887521

# %% [markdown]
# ### Grid search

# %%
params = {}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  30  iterations
# {}
# 0.81727887521
# Convergence after  29  iterations
# Convergence after  28  iterations
# Convergence after  30  iterations
# Convergence after  30  iterations
# Convergence after  29  iterations
# Convergence after  34  iterations
# Convergence after  31  iterations
# Convergence after  38  iterations
# Convergence after Convergence after  16  iterations
#  25  iterations

# %%
params = {'alpha_1': [10**(-i) for i in range(0,15)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  30  iterations
# {'alpha_1': 1e-12}
# 0.817278875256
# Convergence after  29  iterations
# Convergence after  28  iterations
# Convergence after  29  iterations
# Convergence after  31  iterations
# Convergence after  30  iterations
# Convergence after  30  iterations
# Convergence after  34  iterations
# Convergence after  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  16  iterations
#  25  iterations
#  29  iterations
#  31  iterations
#  29  iterations
#  34  iterations
#  38  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  16  iterations
#  28  iterations
#  25  iterations
#  29  iterations
#  31  iterations
#  34  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  30  iterations
#  30  iterations
#  38  iterations
#  16  iterations
#  25  iterations
#  29  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  31  iterations
#  38  iterations
#  30  iterations
#  34  iterations
#  28  iterations
#  29  iterations
#  16  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  25  iterations
#  30  iterations
#  31  iterations
#  29  iterations
#  38  iterations
#  29  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  28  iterations
#  30  iterations
#  25  iterations
#  16  iterations
#  28  iterations
#  16  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  25  iterations
#  30  iterations
#  31  iterations
#  38  iterations
#  34  iterations
#  34  iterations
#  38  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  30  iterations
#  29  iterations
#  30  iterations
#  29  iterations
#  31  iterations
#  38  iterations
#  16  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  29  iterations
#  16  iterations
#  30  iterations
#  25  iterations
#  25  iterations
#  30  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  29  iterations
#  30  iterations
#  34  iterations
#  28  iterations
#  16  iterations
#  31  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  28  iterations
#  30  iterations
#  29  iterations
#  38  iterations
#  38  iterations
#  31  iterations
#  25  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  16  iterations
#  30  iterations
#  29  iterations
#  25  iterations
#  34  iterations
#  30  iterations
#  16  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  30  iterations
#  29  iterations
#  28  iterations
#  34  iterations
#  34  iterations
#  30  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  29  iterations
#  16  iterations
#  28  iterations
#  31  iterations
#  31  iterations
#  29  iterations
#  25  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  29  iterations
#  34  iterations
#  30  iterations
#  25  iterations
#  29  iterations
#  25  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  16  iterations
#  31  iterations
#  29  iterations
#  28  iterations
#  16  iterations
#  30  iterations
#  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  38  iterations
#  25  iterations
#  29  iterations
#  28  iterations
#  29  iterations
#  34  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  38  iterations
#  30  iterations
#  16  iterations
#  28  iterations
# Convergence after  25  iterations

# %%
params = {'alpha_1': [i*10**(-13) for i in range(1,101,10)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  30  iterations
# {'alpha_1': 2.1e-12}
# 0.817278875256
# Convergence after  31  iterations
# Convergence after  29  iterations
# Convergence after  28  iterations
# Convergence after  30  iterations
# Convergence after  29  iterations
# Convergence after  34  iterations
# Convergence after  30  iterations
# Convergence after  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  16  iterations
#  25  iterations
#  29  iterations
#  31  iterations
#  29  iterations
#  34  iterations
#  30  iterations
#  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  28  iterations
#  25  iterations
#  16  iterations
#  29  iterations
#  31  iterations
#  29  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  28  iterations
#  30  iterations
#  30  iterations
#  29  iterations
#  31  iterations
#  16  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  38  iterations
#  30  iterations
#  25  iterations
#  25  iterations
#  16  iterations
#  29  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  34  iterations
#  31  iterations
#  28  iterations
#  38  iterations
#  30  iterations
#  29  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  29  iterations
#  25  iterations
#  16  iterations
#  30  iterations
#  30  iterations
#  28  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  31  iterations
#  28  iterations
#  34  iterations
#  30  iterations
#  29  iterations
#  29  iterations
#  25  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  29  iterations
#  38  iterations
#  16  iterations
#  38  iterations
#  16  iterations
#  25  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  16  iterations
#  29  iterations
#  34  iterations
#  30  iterations
#  30  iterations
#  30  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  16  iterations
#  34  iterations
#  25  iterations
#  34  iterations
#  29  iterations
#  29  iterations
#  31  iterations
#  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  34  iterations
#  28  iterations
#  29  iterations
#  28  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after  16  iterations
#  25  iterations
#  30  iterations
#  25  iterations
# Convergence after Convergence after  29  iterations
#  30  iterations

# %%
params = {'alpha_2': [10**(-i) for i in range(0,15)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1e-06, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  30  iterations
# {'alpha_2': 1}
# 0.817278875257
# Convergence after  29  iterations
# Convergence after  29  iterations
# Convergence after  31  iterations
# Convergence after  28  iterations
# Convergence after  34  iterations
# Convergence after  30  iterations
# Convergence after  30  iterations
# Convergence after  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  16  iterations
#  25  iterations
#  29  iterations
#  31  iterations
#  29  iterations
#  34  iterations
#  30  iterations
#  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  31  iterations
#  25  iterations
#  29  iterations
#  28  iterations
#  16  iterations
#  29  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  25  iterations
#  30  iterations
#  16  iterations
#  28  iterations
#  38  iterations
#  31  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  28  iterations
#  30  iterations
#  34  iterations
#  30  iterations
#  38  iterations
#  25  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  16  iterations
#  30  iterations
#  31  iterations
#  34  iterations
#  29  iterations
#  30  iterations
#  28  iterations
#  16  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  31  iterations
#  25  iterations
#  29  iterations
#  34  iterations
#  30  iterations
#  38  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  29  iterations
#  28  iterations
#  25  iterations
#  34  iterations
#  38  iterations
#  30  iterations
#  16  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  16  iterations
#  30  iterations
#  28  iterations
#  29  iterations
#  38  iterations
#  29  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  25  iterations
#  31  iterations
#  30  iterations
#  30  iterations
#  25  iterations
#  30  iterations
#  16  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  29  iterations
#  38  iterations
#  31  iterations
#  16  iterations
#  30  iterations
#  30  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  28  iterations
#  28  iterations
#  25  iterations
#  31  iterations
#  30  iterations
#  29  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  34  iterations
#  38  iterations
#  38  iterations
#  25  iterations
#  31  iterations
#  29  iterations
#  16  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  31  iterations
#  30  iterations
#  16  iterations
#  30  iterations
#  16  iterations
#  28  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  25  iterations
#  34  iterations
#  29  iterations
#  34  iterations
#  28  iterations
#  28  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  25  iterations
#  38  iterations
#  34  iterations
#  29  iterations
#  31  iterations
#  30  iterations
#  38  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  30  iterations
#  30  iterations
#  16  iterations
#  29  iterations
#  29  iterations
#  30  iterations
#  25  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  31  iterations
#  28  iterations
#  29  iterations
#  16  iterations
#  25  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  31  iterations
#  30  iterations
#  25  iterations
#  29  iterations
# Convergence after Convergence after  16  iterations
#  28  iterations

# %%
params = {'alpha_2': [i*10**(-1) for i in range(0,101,10)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1e-06, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  30  iterations
# {'alpha_2': 10.0}
# 0.817278875257
# Convergence after  31  iterations
# Convergence after  29  iterations
# Convergence after  30  iterations
# Convergence after  29  iterations
# Convergence after  34  iterations
# Convergence after  28  iterations
# Convergence after  30  iterations
# Convergence after  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  16  iterations
#  25  iterations
#  29  iterations
#  31  iterations
#  34  iterations
#  29  iterations
#  30  iterations
#  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  30  iterations
#  16  iterations
#  29  iterations
#  29  iterations
#  25  iterations
#  31  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  30  iterations
#  38  iterations
#  29  iterations
#  25  iterations
#  30  iterations
#  16  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  29  iterations
#  30  iterations
#  16  iterations
#  30  iterations
#  34  iterations
#  38  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  25  iterations
#  31  iterations
#  29  iterations
#  29  iterations
#  38  iterations
#  34  iterations
#  30  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  25  iterations
#  29  iterations
#  28  iterations
#  16  iterations
#  38  iterations
#  31  iterations
#  30  iterations
#  25  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  16  iterations
#  30  iterations
#  34  iterations
#  38  iterations
#  29  iterations
#  29  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  30  iterations
#  30  iterations
#  31  iterations
#  30  iterations
#  16  iterations
#  29  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  34  iterations
#  31  iterations
#  25  iterations
#  34  iterations
#  38  iterations
#  16  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  29  iterations
#  25  iterations
#  30  iterations
#  29  iterations
#  28  iterations
#  38  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  16  iterations
#  31  iterations
#  30  iterations
#  31  iterations
#  16  iterations
#  38  iterations
#  30  iterations
#  25  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  29  iterations
#  34  iterations
#  25  iterations
#  30  iterations
#  38  iterations
#  31  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after  29  iterations
#  16  iterations
#  34  iterations
#  28  iterations
# Convergence after Convergence after  25  iterations
#  28  iterations

# %%
params = {'lambda_1': [10**(-i) for i in range(0,15)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  32  iterations
# {'lambda_1': 0.001}
# 0.817279113217
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  3  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  3  iterations
#  2  iterations
#  3  iterations
#  3  iterations
#  3  iterations
#  3  iterations
#  3  iterations
#  3  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  3  iterations
#  3  iterations
#  3  iterations
#  4  iterations
#  3  iterations
#  4  iterations
#  4  iterations
#  4  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  4  iterations
#  4  iterations
#  4  iterations
#  32  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  37  iterations
#  32  iterations
#  27  iterations
#  32  iterations
#  31  iterations
#  40  iterations
#  19  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  38  iterations
#  30  iterations
#  28  iterations
#  35  iterations
#  30  iterations
#  31  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  30  iterations
#  29  iterations
#  30  iterations
#  31  iterations
#  25  iterations
#  17  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  29  iterations
#  25  iterations
#  34  iterations
#  16  iterations
#  28  iterations
#  38  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  25  iterations
#  16  iterations
#  31  iterations
#  30  iterations
#  30  iterations
#  38  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  28  iterations
#  34  iterations
#  31  iterations
#  29  iterations
#  30  iterations
#  38  iterations
#  25  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  29  iterations
#  29  iterations
#  25  iterations
#  16  iterations
#  30  iterations
#  30  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  29  iterations
#  16  iterations
#  28  iterations
#  34  iterations
#  31  iterations
#  30  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  16  iterations
#  29  iterations
#  30  iterations
#  34  iterations
#  25  iterations
#  31  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  29  iterations
#  29  iterations
#  34  iterations
#  30  iterations
#  16  iterations
#  29  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  25  iterations
#  28  iterations
#  34  iterations
#  29  iterations
#  30  iterations
#  25  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  28  iterations
#  38  iterations
#  29  iterations
#  16  iterations
#  29  iterations
#  28  iterations
#  25  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  38  iterations
#  30  iterations
#  25  iterations
#  31  iterations
#  29  iterations
#  38  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  38  iterations
#  34  iterations
#  30  iterations
#  28  iterations
#  16  iterations
#  16  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after  31  iterations
#  29  iterations
#  29  iterations
#  30  iterations
# Convergence after Convergence after Convergence after  25  iterations
#  16  iterations
#  30  iterations

# %%
params = {'lambda_1': [i*10**(-4) for i in range(1,101,10)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  32  iterations
# {'lambda_1': 0.0011}
# 0.817279137021
# Convergence after  30  iterations
# Convergence after  29  iterations
# Convergence after  28  iterations
# Convergence after  30  iterations
# Convergence after  30  iterations
# Convergence after  31  iterations
# Convergence after  35  iterations
# Convergence after  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  17  iterations
#  25  iterations
#  32  iterations
#  34  iterations
#  32  iterations
#  37  iterations
#  32  iterations
#  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  31  iterations
#  6  iterations
#  19  iterations
#  28  iterations
#  6  iterations
#  6  iterations
#  5  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  6  iterations
#  5  iterations
#  6  iterations
#  6  iterations
#  6  iterations
#  6  iterations
#  6  iterations
#  5  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  5  iterations
#  5  iterations
#  5  iterations
#  5  iterations
#  5  iterations
#  5  iterations
#  6  iterations
#  4  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  4  iterations
#  5  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  5  iterations
#  4  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
#  4  iterations
# Convergence after  4  iterations
# Convergence after  4  iterations

# %%
params = {'lambda_1': [i/100000.0 for i in range(104,116)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  32  iterations
# {'lambda_1': 0.00115}
# 0.817279148932
# Convergence after  32  iterations
# Convergence after  32  iterations
# Convergence after  31  iterations
# Convergence after  32  iterations
# Convergence after  32  iterations
# Convergence after  34  iterations
# Convergence after  37  iterations
# Convergence after  40  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  19  iterations
#  28  iterations
#  32  iterations
#  34  iterations
#  32  iterations
#  37  iterations
#  32  iterations
#  40  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  31  iterations
#  37  iterations
#  32  iterations
#  19  iterations
#  34  iterations
#  28  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  32  iterations
#  37  iterations
#  31  iterations
#  40  iterations
#  34  iterations
#  19  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  41  iterations
#  32  iterations
#  37  iterations
#  32  iterations
#  32  iterations
#  28  iterations
#  32  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  32  iterations
#  34  iterations
#  32  iterations
#  34  iterations
#  31  iterations
#  19  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  19  iterations
#  32  iterations
#  32  iterations
#  32  iterations
#  41  iterations
#  41  iterations
#  37  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  32  iterations
#  34  iterations
#  31  iterations
#  19  iterations
#  32  iterations
#  28  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  34  iterations
#  19  iterations
#  31  iterations
#  37  iterations
#  32  iterations
#  41  iterations
#  19  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  37  iterations
#  28  iterations
#  32  iterations
#  32  iterations
#  41  iterations
#  32  iterations
#  33  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  37  iterations
#  28  iterations
#  34  iterations
#  32  iterations
#  41  iterations
#  28  iterations
#  34  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  31  iterations
#  34  iterations
#  19  iterations
#  37  iterations
#  31  iterations
#  32  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  33  iterations
#  31  iterations
#  41  iterations
#  33  iterations
#  33  iterations
#  19  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  33  iterations
#  41  iterations
#  41  iterations
#  28  iterations
#  33  iterations
#  37  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  37  iterations
#  19  iterations
#  33  iterations
#  19  iterations
#  32  iterations
# Convergence after Convergence after  28  iterations
#  34  iterations

# %%
params = {'lambda_1': [i/1000000.0 for i in range(1144,1156)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  32  iterations
# {'lambda_1': 0.001155}
# 0.817279150123
# Convergence after  33  iterations
# Convergence after  32  iterations
# Convergence after  31  iterations
# Convergence after  34  iterations
# Convergence after  33  iterations
# Convergence after  33  iterations
# Convergence after  37  iterations
# Convergence after  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  19  iterations
#  33  iterations
#  28  iterations
#  34  iterations
#  32  iterations
#  37  iterations
#  33  iterations
#  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  33  iterations
#  31  iterations
#  34  iterations
#  28  iterations
#  37  iterations
#  19  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  41  iterations
#  19  iterations
#  33  iterations
#  28  iterations
#  33  iterations
#  34  iterations
#  31  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  32  iterations
#  41  iterations
#  19  iterations
#  33  iterations
#  28  iterations
#  37  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  33  iterations
#  32  iterations
#  33  iterations
#  34  iterations
#  31  iterations
#  37  iterations
#  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  19  iterations
#  28  iterations
#  34  iterations
#  33  iterations
#  41  iterations
#  32  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  37  iterations
#  33  iterations
#  19  iterations
#  28  iterations
#  37  iterations
#  33  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  34  iterations
#  32  iterations
#  41  iterations
#  31  iterations
#  33  iterations
#  32  iterations
#  37  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  19  iterations
#  28  iterations
#  33  iterations
#  41  iterations
#  28  iterations
#  19  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  19  iterations
#  33  iterations
#  31  iterations
#  33  iterations
#  41  iterations
#  31  iterations
#  37  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  32  iterations
#  33  iterations
#  37  iterations
#  33  iterations
#  33  iterations
#  41  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  33  iterations
#  34  iterations
#  34  iterations
#  32  iterations
#  33  iterations
#  33  iterations
#  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  19  iterations
#  33  iterations
#  33  iterations
#  28  iterations
#  33  iterations
#  37  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  37  iterations
#  19  iterations
#  19  iterations
#  31  iterations
#  28  iterations
# Convergence after Convergence after  41  iterations
#  34  iterations

# %%
params = {'lambda_1': [i/10000000.0 for i in range(11544,11556)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  32  iterations
# {'lambda_1': 0.0011555}
# 0.817279150243
# Convergence after  33  iterations
# Convergence after  33  iterations
# Convergence after  33  iterations
# Convergence after  32  iterations
# Convergence after  31  iterations
# Convergence after  37  iterations
# Convergence after  34  iterations
# Convergence after  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  19  iterations
#  28  iterations
#  33  iterations
#  34  iterations
#  37  iterations
#  32  iterations
#  33  iterations
#  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  19  iterations
#  34  iterations
#  32  iterations
#  33  iterations
#  31  iterations
#  28  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  37  iterations
#  41  iterations
#  19  iterations
#  33  iterations
#  28  iterations
#  33  iterations
#  31  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  33  iterations
#  41  iterations
#  19  iterations
#  31  iterations
#  37  iterations
#  33  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  41  iterations
#  33  iterations
#  34  iterations
#  32  iterations
#  33  iterations
#  37  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  32  iterations
#  37  iterations
#  19  iterations
#  28  iterations
#  34  iterations
#  33  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  19  iterations
#  34  iterations
#  41  iterations
#  33  iterations
#  33  iterations
#  33  iterations
#  37  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  41  iterations
#  28  iterations
#  31  iterations
#  32  iterations
#  19  iterations
#  33  iterations
#  37  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  41  iterations
#  33  iterations
#  31  iterations
#  33  iterations
#  34  iterations
#  32  iterations
#  19  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  32  iterations
#  31  iterations
#  37  iterations
#  34  iterations
#  33  iterations
#  41  iterations
#  19  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  33  iterations
#  31  iterations
#  33  iterations
#  34  iterations
#  28  iterations
#  37  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  19  iterations
#  41  iterations
#  41  iterations
#  32  iterations
#  28  iterations
#  33  iterations
#  33  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  37  iterations
#  41  iterations
#  33  iterations
#  31  iterations
#  33  iterations
#  19  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  37  iterations
#  31  iterations
#  19  iterations
#  32  iterations
#  33  iterations
#  33  iterations
# Convergence after  28  iterations

# %%
params = {'lambda_1': [i/100000000.0 for i in range(115544,115556)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=1e-06, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  32  iterations
# {'lambda_1': 0.00115555}
# 0.817279150255
# Convergence after  31  iterations
# Convergence after  34  iterations
# Convergence after  32  iterations
# Convergence after  33  iterations
# Convergence after  33  iterations
# Convergence after  33  iterations
# Convergence after  41  iterations
# Convergence after  37  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  19  iterations
#  28  iterations
#  33  iterations
#  34  iterations
#  32  iterations
#  37  iterations
#  33  iterations
#  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  19  iterations
#  28  iterations
#  31  iterations
#  34  iterations
#  33  iterations
#  37  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  41  iterations
#  33  iterations
#  31  iterations
#  33  iterations
#  33  iterations
#  19  iterations
#  34  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  37  iterations
#  41  iterations
#  33  iterations
#  31  iterations
#  32  iterations
#  28  iterations
#  19  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  37  iterations
#  34  iterations
#  32  iterations
#  41  iterations
#  31  iterations
#  33  iterations
#  33  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  37  iterations
#  33  iterations
#  28  iterations
#  41  iterations
#  33  iterations
#  19  iterations
#  32  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  19  iterations
#  31  iterations
#  33  iterations
#  34  iterations
#  33  iterations
#  28  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  41  iterations
#  33  iterations
#  37  iterations
#  28  iterations
#  37  iterations
#  31  iterations
#  19  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  41  iterations
#  33  iterations
#  34  iterations
#  19  iterations
#  32  iterations
#  33  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  19  iterations
#  33  iterations
#  31  iterations
#  33  iterations
#  37  iterations
#  33  iterations
#  41  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  37  iterations
#  32  iterations
#  33  iterations
#  31  iterations
#  34  iterations
#  28  iterations
#  33  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  28  iterations
#  19  iterations
#  32  iterations
#  33  iterations
#  33  iterations
#  33  iterations
#  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  31  iterations
#  37  iterations
#  28  iterations
#  19  iterations
#  41  iterations
#  37  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  19  iterations
#  31  iterations
#  34  iterations
#  33  iterations
#  41  iterations
#  33  iterations
#  32  iterations
# Convergence after  28  iterations

# %%
params = {'lambda_2': [10**(-i) for i in range(0,15)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  32  iterations
# {'lambda_2': 0.001}
# 0.817279150265
# Convergence after  30  iterations
# Convergence after  27  iterations
# Convergence after  28  iterations
# Convergence after  29  iterations
# Convergence after  29  iterations
# Convergence after  29  iterations
# Convergence after  37  iterations
# Convergence after  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  16  iterations
#  24  iterations
#  29  iterations
#  31  iterations
#  29  iterations
#  34  iterations
#  30  iterations
#  38  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  28  iterations
#  25  iterations
#  32  iterations
#  16  iterations
#  30  iterations
#  30  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  39  iterations
#  17  iterations
#  30  iterations
#  33  iterations
#  35  iterations
#  29  iterations
#  26  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  40  iterations
#  31  iterations
#  32  iterations
#  27  iterations
#  31  iterations
#  36  iterations
#  30  iterations
#  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  32  iterations
#  32  iterations
#  31  iterations
#  18  iterations
#  34  iterations
#  33  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  33  iterations
#  19  iterations
#  33  iterations
#  37  iterations
#  28  iterations
#  37  iterations
#  19  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  37  iterations
#  28  iterations
#  41  iterations
#  33  iterations
#  34  iterations
#  31  iterations
#  32  iterations
#  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  31  iterations
#  33  iterations
#  32  iterations
#  34  iterations
#  33  iterations
#  33  iterations
#  37  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  33  iterations
#  19  iterations
#  34  iterations
#  28  iterations
#  31  iterations
#  19  iterations
#  37  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  33  iterations
#  41  iterations
#  33  iterations
#  33  iterations
#  33  iterations
#  33  iterations
#  34  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  41  iterations
#  19  iterations
#  41  iterations
#  19  iterations
#  32  iterations
#  32  iterations
#  37  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  33  iterations
#  33  iterations
#  32  iterations
#  28  iterations
#  28  iterations
#  34  iterations
#  19  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  41  iterations
#  41  iterations
#  33  iterations
#  32  iterations
#  31  iterations
#  33  iterations
#  33  iterations
#  37  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  34  iterations
#  33  iterations
#  34  iterations
#  32  iterations
#  37  iterations
#  33  iterations
#  37  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  28  iterations
#  41  iterations
#  28  iterations
#  33  iterations
#  28  iterations
#  19  iterations
#  32  iterations
#  19  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  33  iterations
#  33  iterations
#  34  iterations
#  31  iterations
#  33  iterations
#  19  iterations
#  33  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  33  iterations
#  37  iterations
#  34  iterations
#  28  iterations
#  31  iterations
#  37  iterations
#  33  iterations
#  28  iterations
# Convergence after Convergence after Convergence after Convergence after  19  iterations
#  32  iterations
#  33  iterations
#  41  iterations
# Convergence after Convergence after  41  iterations
#  31  iterations

# %%
params = {'lambda_2': [i/10000.0 for i in range(1,101,10)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  31  iterations
# {'lambda_2': 0.0051}
# 0.817279150269
# Convergence after  32  iterations
# Convergence after  32  iterations
# Convergence after  32  iterations
# Convergence after  33  iterations
# Convergence after  34  iterations
# Convergence after  31  iterations
# Convergence after  37  iterations
# Convergence after  41  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  19  iterations
#  28  iterations
#  31  iterations
#  33  iterations
#  31  iterations
#  36  iterations
#  32  iterations
#  40  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  30  iterations
#  33  iterations
#  18  iterations
#  27  iterations
#  31  iterations
#  31  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  36  iterations
#  30  iterations
#  26  iterations
#  39  iterations
#  31  iterations
#  31  iterations
#  18  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  39  iterations
#  31  iterations
#  29  iterations
#  31  iterations
#  36  iterations
#  31  iterations
#  30  iterations
#  18  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  32  iterations
#  36  iterations
#  30  iterations
#  39  iterations
#  18  iterations
#  26  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  39  iterations
#  30  iterations
#  30  iterations
#  26  iterations
#  36  iterations
#  31  iterations
#  29  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  26  iterations
#  30  iterations
#  29  iterations
#  30  iterations
#  31  iterations
#  31  iterations
#  17  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  31  iterations
#  17  iterations
#  39  iterations
#  30  iterations
#  32  iterations
#  32  iterations
#  35  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  26  iterations
#  31  iterations
#  31  iterations
#  39  iterations
#  17  iterations
#  30  iterations
#  26  iterations
#  35  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  30  iterations
#  35  iterations
#  31  iterations
#  31  iterations
#  17  iterations
#  29  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  39  iterations
#  35  iterations
#  32  iterations
#  30  iterations
#  30  iterations
#  31  iterations
#  39  iterations
#  26  iterations
# Convergence after Convergence after Convergence after Convergence after  29  iterations
#  31  iterations
#  17  iterations
#  26  iterations

# %%
params = {'lambda_2': [i/100000.0 for i in range(504,516)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=1e-06,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  31  iterations
# {'lambda_2': 0.00508}
# 0.817279150269
# Convergence after  31  iterations
# Convergence after  30  iterations
# Convergence after  32  iterations
# Convergence after  31  iterations
# Convergence after  29  iterations
# Convergence after  31  iterations
# Convergence after  39  iterations
# Convergence after  36  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  17  iterations
#  26  iterations
#  32  iterations
#  31  iterations
#  30  iterations
#  36  iterations
#  31  iterations
#  39  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  29  iterations
#  31  iterations
#  26  iterations
#  17  iterations
#  30  iterations
#  32  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  36  iterations
#  31  iterations
#  17  iterations
#  29  iterations
#  39  iterations
#  31  iterations
#  26  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  30  iterations
#  31  iterations
#  29  iterations
#  39  iterations
#  17  iterations
#  36  iterations
#  26  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  30  iterations
#  39  iterations
#  31  iterations
#  30  iterations
#  31  iterations
#  36  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  26  iterations
#  17  iterations
#  32  iterations
#  30  iterations
#  30  iterations
#  31  iterations
#  39  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  36  iterations
#  31  iterations
#  26  iterations
#  17  iterations
#  32  iterations
#  30  iterations
#  36  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  39  iterations
#  30  iterations
#  30  iterations
#  29  iterations
#  31  iterations
#  26  iterations
#  17  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  30  iterations
#  30  iterations
#  39  iterations
#  29  iterations
#  31  iterations
#  36  iterations
#  26  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  17  iterations
#  17  iterations
#  31  iterations
#  39  iterations
#  30  iterations
#  31  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  36  iterations
#  39  iterations
#  30  iterations
#  36  iterations
#  30  iterations
#  26  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  26  iterations
#  31  iterations
#  31  iterations
#  30  iterations
#  36  iterations
#  17  iterations
#  29  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  30  iterations
#  32  iterations
#  26  iterations
#  39  iterations
#  39  iterations
#  29  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  36  iterations
#  17  iterations
#  26  iterations
#  31  iterations
#  17  iterations
#  30  iterations
#  29  iterations
# Convergence after  31  iterations

# %%
params = {'n_iter': range(50,850,50)}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=0.0051,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# Convergence after  31  iterations
# {'n_iter': 50}
# 0.817279150269
# Convergence after  30  iterations
# Convergence after  32  iterations
# Convergence after  29  iterations
# Convergence after  30  iterations
# Convergence after  31  iterations
# Convergence after  31  iterations
# Convergence after  36  iterations
# Convergence after  39  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  17  iterations
#  26  iterations
#  30  iterations
#  32  iterations
#  30  iterations
#  36  iterations
#  31  iterations
#  39  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  17  iterations
#  26  iterations
#  30  iterations
#  29  iterations
#  30  iterations
#  32  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  36  iterations
#  39  iterations
#  17  iterations
#  26  iterations
#  31  iterations
#  29  iterations
#  30  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  31  iterations
#  30  iterations
#  17  iterations
#  36  iterations
#  39  iterations
#  29  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  26  iterations
#  31  iterations
#  30  iterations
#  30  iterations
#  31  iterations
#  39  iterations
#  36  iterations
#  26  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  31  iterations
#  17  iterations
#  32  iterations
#  30  iterations
#  36  iterations
#  39  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  26  iterations
#  31  iterations
#  36  iterations
#  17  iterations
#  32  iterations
#  31  iterations
#  39  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  29  iterations
#  30  iterations
#  30  iterations
#  31  iterations
#  32  iterations
#  30  iterations
#  36  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  17  iterations
#  31  iterations
#  26  iterations
#  26  iterations
#  31  iterations
#  29  iterations
#  30  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  39  iterations
#  36  iterations
#  17  iterations
#  29  iterations
#  30  iterations
#  31  iterations
#  17  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  26  iterations
#  39  iterations
#  31  iterations
#  32  iterations
#  30  iterations
#  36  iterations
#  17  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  39  iterations
#  29  iterations
#  31  iterations
#  31  iterations
#  30  iterations
#  26  iterations
#  32  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  36  iterations
#  39  iterations
#  30  iterations
#  36  iterations
#  29  iterations
#  17  iterations
#  26  iterations
#  39  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  31  iterations
#  30  iterations
#  30  iterations
#  31  iterations
#  30  iterations
#  29  iterations
#  39  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  17  iterations
#  36  iterations
#  26  iterations
#  17  iterations
#  32  iterations
#  30  iterations
#  31  iterations
#  39  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  30  iterations
#  29  iterations
#  30  iterations
#  36  iterations
#  26  iterations
#  32  iterations
#  39  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  17  iterations
#  31  iterations
#  26  iterations
#  32  iterations
#  29  iterations
#  30  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  30  iterations
#  36  iterations
#  17  iterations
#  26  iterations
#  31  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  32  iterations
#  30  iterations
#  36  iterations
#  31  iterations
#  39  iterations
#  31  iterations
# Convergence after Convergence after  17  iterations
#  26  iterations

# %%
params = {'n_iter': range(5,100,5)}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=0.0051,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'n_iter': 10}
# 0.818719033257
# Convergence after  17  iterations
# Convergence after  17  iterations
# Convergence after  17  iterations
# Convergence after  29  iterations
# Convergence after  26  iterations
# Convergence after  30  iterations
# Convergence after  32  iterations
# Convergence after  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  30  iterations
#  36  iterations
#  31  iterations
#  29  iterations
#  17  iterations
#  26  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  26  iterations
#  36  iterations
#  30  iterations
#  39  iterations
#  31  iterations
#  17  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  31  iterations
#  30  iterations
#  29  iterations
#  30  iterations
#  31  iterations
#  39  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  26  iterations
#  31  iterations
#  26  iterations
#  17  iterations
#  30  iterations
#  36  iterations
#  31  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  39  iterations
#  36  iterations
#  29  iterations
#  32  iterations
#  17  iterations
#  30  iterations
#  31  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  39  iterations
#  32  iterations
#  39  iterations
#  30  iterations
#  31  iterations
#  30  iterations
#  30  iterations
#  26  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  17  iterations
#  31  iterations
#  17  iterations
#  31  iterations
#  26  iterations
#  30  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  32  iterations
#  30  iterations
#  39  iterations
#  36  iterations
#  39  iterations
#  29  iterations
#  17  iterations
#  31  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  26  iterations
#  30  iterations
#  31  iterations
#  36  iterations
#  31  iterations
#  36  iterations
#  31  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  32  iterations
#  30  iterations
#  30  iterations
#  26  iterations
#  36  iterations
#  30  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  26  iterations
#  26  iterations
#  17  iterations
#  29  iterations
#  32  iterations
#  30  iterations
#  17  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  29  iterations
#  31  iterations
#  29  iterations
#  39  iterations
#  39  iterations
#  30  iterations
#  17  iterations
#  36  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  31  iterations
#  31  iterations
#  31  iterations
#  31  iterations
#  39  iterations
#  17  iterations
#  32  iterations
#  30  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  36  iterations
#  30  iterations
#  36  iterations
#  36  iterations
#  39  iterations
#  31  iterations
#  26  iterations
#  32  iterations
# Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after Convergence after  30  iterations
#  17  iterations
#  26  iterations
#  30  iterations
#  29  iterations
#  31  iterations
#  29  iterations
# Convergence after Convergence after Convergence after Convergence after  39  iterations
#  32  iterations
#  17  iterations
#  30  iterations
# Convergence after Convergence after  31  iterations
#  26  iterations

# %%
params = {'n_iter': range(1,20)}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=0.0051,
        n_iter=300, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'n_iter': 7}
# 0.831444815282
# Convergence after  17  iterations
# Convergence after  17  iterations

# %%
params = {'tol': [10**(-i) for i in range(0,11)]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=0.0051,
        n_iter=7, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'tol': 1}
# 0.831444815282

# %%
params = {'compute_score': [True,False]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=0.0051,
        n_iter=7, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'compute_score': True}
# 0.831444815282

# %%
params = {'normalize': [True,False]}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=0.0051,
        n_iter=7, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {'normalize': False}
# 0.831444815282
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after  2  iterations
# Convergence after Convergence after  2  iterations
#  2  iterations

# %% [markdown]
# ### Final model

# %%
params = {}
grid = GridSearchCV(estimator=BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=0.0051,
        n_iter=7, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True),
        param_grid=params, cv=10, scoring='r2', n_jobs=-1)
grid.fit(X_train, y_train)
print grid.best_params_
print grid.best_score_
# Out:
# {}
# 0.831444815282

# %%
reg1 = BayesianRidge(alpha_1=1e-12, alpha_2=1, lambda_1=0.00115555, lambda_2=0.0051,
        n_iter=7, tol=0.001, compute_score=False, normalize=False, fit_intercept=True, copy_X=True, verbose=True)
modelfit(reg1, X_train, y_train)
# Out:
# Model Report
# Train_coef_of_det: 0.909845
# CV_coef_of_det: Mean-0.831445 | Std-0.106082 | Min-0.533836 | Max-0.907814

# %% [markdown]
# ### Grid search + Random search

# %%
params = {
        'alpha_1': [i*10**(-13) for i in range(1,101,10)],
        'alpha_2': [i*10**(-1) for i in range(0,101,10)],
        'lambda_1': [i/100000000.0 for i in range(115520,115580)],
        'lambda_2': [i/100000.0 for i in range(490,530)],    
        'n_iter': range(1,30),
        'tol': [10**(-i) for i in range(0,11)],
        'compute_score': [True,False],
        'normalize': [True,False],
        'fit_intercept': [True],
        'copy_X': [True],
        'verbose': [True]
         }
rand = RandomizedSearchCV(estimator=BayesianRidge(), param_distributions=params, cv=10, scoring='r2',
         n_iter=1000, random_state=10, n_jobs=-1)
rand.fit(X_train, y_train)
print 'Best parameters: \n', rand.best_params_
print '\tBest score: ', rand.best_score_

# %%
params = {}
reg1 = BayesianRidge(
                    alpha_1 = params['alpha_1'],
                    alpha_2 = params['alpha_2'],
                    lambda_1 = params['lambda_1'],
                    lambda_2 = params['lambda_2'],
                    n_iter = params['n_iter'],
                    tol = params['tol'],
                    compute_score = params['compute_score'],
                    normalize = params['normalize'],
                    fit_intercept = params['fit_intercept'],
                    copy_X = params['copy_X'],
                    verbose = params['verbose']
                    )
modelfit(reg1, X_train, y_train)

# %% [markdown]
# ### Grid search + Bayesian optimization ( 'hyperopt' package)

# %%
min_score = float('inf')
best_params = ''
c = 0

def score(params):
    global c, min_score, best_params
    c += 1
    print "Interation no.: ", c
    print "Training with params : "
    print params
    reg = BayesianRidge(
                    alpha_1 = params['alpha_1'],
                    alpha_2 = params['alpha_2'],
                    lambda_1 = params['lambda_1'],
                    lambda_2 = params['lambda_2'],
                    n_iter = params['n_iter'],
                    tol = params['tol'],
                    compute_score = params['compute_score'],
                    normalize = params['normalize'],
                    fit_intercept = params['fit_intercept'],
                    copy_X = params['copy_X'],
                    verbose = params['verbose']      
                    )
    cv_r2_score = cross_val_score(reg, X_train, y_train, cv=10, scoring='r2', n_jobs=-1)
    score = 1 - np.mean(cv_r2_score) 
    if score < min_score:
        min_score = score
        best_params = params     
    print "\tScore: {0}".format(1-score)
    print "\tBest score: {0}\n".format(1-min_score)
    return {'loss': score, 'status': STATUS_OK}

def optimize():
    space = {
            'alpha_1': hp.uniform('alpha_1', 1e-13, 1e-11),
            'alpha_2': hp.uniform('alpha_2', 0, 10),
            'lambda_1': hp.uniform('lambda_1', 0.0011552, 0.0011558),
            'lambda_2': hp.uniform('lambda_2', 0.0049, 0.0053),    
            'n_iter': hp.choice('n_iter', range(1,30)),
            'tol': hp.uniform('tol', 1e-6, 1),
            'compute_score': hp.choice('compute_score', [True,False]),
            'normalize': hp.choice('normalize', [True,False]),
            'fit_intercept': hp.choice('fit_intercept', [True]),
            'copy_X': hp.choice('copy_X', [True]),
            'verbose': hp.choice('verbose', [True])    
             }
    best = fmin(score, space, algo=tpe.suggest, max_evals=1000)    
  
optimize()
print 'Best parameters:'
print best_params
print "\tScore {0}".format(1-min_score)
# Out:
# Interation no.:  1
# Training with params :
# {'normalize': True, 'n_iter': 6, 'verbose': True, 'lambda_2': 0.005273387768381567, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 4.5223979975801845, 'tol': 0.6371964638948532, 'alpha_1': 3.6772618788874844e-13, 'copy_X': True, 'lambda_1': 0.0011557442489714702}
# 	Score: -0.00759022137463
# 	Best score: -0.00759022137463
#
# Interation no.:  2
# Training with params :
# {'normalize': False, 'n_iter': 4, 'verbose': True, 'lambda_2': 0.004900139430266924, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.380442331461982, 'tol': 0.6754412897177099, 'alpha_1': 4.571837423343486e-12, 'copy_X': True, 'lambda_1': 0.001155548882902618}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: -0.00263193470869
# 	Best score: -0.00263193470869
#
# Interation no.:  3
# Training with params :
# {'normalize': True, 'n_iter': 14, 'verbose': True, 'lambda_2': 0.005202700357287762, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 2.1536697999757526, 'tol': 0.6827377830363184, 'alpha_1': 8.944067774816163e-12, 'copy_X': True, 'lambda_1': 0.0011554690844109519}
# 	Score: -0.00759022159392
# 	Best score: -0.00263193470869
#
# Interation no.:  4
# Training with params :
# {'normalize': False, 'n_iter': 5, 'verbose': True, 'lambda_2': 0.00496378126029014, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 1.4927434889052726, 'tol': 0.7046759394077219, 'alpha_1': 9.437134879565315e-12, 'copy_X': True, 'lambda_1': 0.0011555160062596802}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.20361408434
# 	Best score: 0.20361408434
#
# Interation no.:  5
# Training with params :
# {'normalize': True, 'n_iter': 18, 'verbose': True, 'lambda_2': 0.005216604083110479, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 4.649203780711948, 'tol': 0.36213301379921115, 'alpha_1': 1.9778931010916554e-12, 'copy_X': True, 'lambda_1': 0.0011553451385100083}
# 	Score: -0.00759022154824
# 	Best score: 0.20361408434
#
# Interation no.:  6
# Training with params :
# {'normalize': False, 'n_iter': 10, 'verbose': True, 'lambda_2': 0.005052325466887542, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 4.849300252725347, 'tol': 0.6504661203660534, 'alpha_1': 9.948988229652402e-12, 'copy_X': True, 'lambda_1': 0.0011556558136950569}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.818723632159
# 	Best score: 0.818723632159
#
# Interation no.:  7
# Training with params :
# {'normalize': False, 'n_iter': 21, 'verbose': True, 'lambda_2': 0.005260405403744593, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 3.9122615267229968, 'tol': 0.1454667621212037, 'alpha_1': 2.89085401725356e-12, 'copy_X': True, 'lambda_1': 0.0011552376104212343}
# 	Score: 0.817280501063
# 	Best score: 0.818723632159
#
# Interation no.:  8
# Training with params :
# {'normalize': False, 'n_iter': 19, 'verbose': True, 'lambda_2': 0.005093388899747036, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 7.50687558687181, 'tol': 0.9966105506845533, 'alpha_1': 1.7804782733167223e-12, 'copy_X': True, 'lambda_1': 0.0011553153319842015}
# Convergence after  15  iterations
# 	Score: 0.817283725498
# 	Best score: 0.818723632159
#
# Interation no.:  9
# Training with params :
# {'normalize': True, 'n_iter': 29, 'verbose': True, 'lambda_2': 0.005020343719398625, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 2.9035086276932462, 'tol': 0.6085232762266064, 'alpha_1': 2.7713934162387024e-12, 'copy_X': True, 'lambda_1': 0.0011557499325826855}
# Convergence after  14  iterations
# 	Score: -0.00759022217371
# 	Best score: 0.818723632159
#
# Interation no.:  10
# Training with params :
# {'normalize': False, 'n_iter': 27, 'verbose': True, 'lambda_2': 0.004914611623114538, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.2052015487479129, 'tol': 0.7868519472354278, 'alpha_1': 4.536524741745705e-12, 'copy_X': True, 'lambda_1': 0.0011554667005852376}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.817279216791
# 	Best score: 0.818723632159
#
# Interation no.:  11
# Training with params :
# {'normalize': False, 'n_iter': 18, 'verbose': True, 'lambda_2': 0.005242140608263452, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 7.6784910897751955, 'tol': 0.642884160694894, 'alpha_1': 8.637786134404986e-12, 'copy_X': True, 'lambda_1': 0.001155580159494974}
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  22  iterations
# Convergence after  21  iterations
# Convergence after  22  iterations
# Convergence after  22  iterations
# Convergence after  25  iterations
# Convergence after Convergence after  14  iterations
#  19  iterations
# 	Score: 0.817287518999
# 	Best score: 0.818723632159
#
# Interation no.:  12
# Training with params :
# {'normalize': True, 'n_iter': 25, 'verbose': True, 'lambda_2': 0.005264476549925994, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 9.113597137354358, 'tol': 0.47079495736973387, 'alpha_1': 8.500985159420272e-12, 'copy_X': True, 'lambda_1': 0.001155714568163144}
# Convergence after  14  iterations
# 	Score: -0.00759022140234
# 	Best score: 0.818723632159
#
# Interation no.:  13
# Training with params :
# {'normalize': False, 'n_iter': 2, 'verbose': True, 'lambda_2': 0.004993115268210195, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 1.5909691872813025, 'tol': 0.244907848031055, 'alpha_1': 6.969800139233567e-12, 'copy_X': True, 'lambda_1': 0.0011557268053101917}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: -0.00756388025745
# 	Best score: 0.818723632159
#
# Interation no.:  14
# Training with params :
# {'normalize': False, 'n_iter': 20, 'verbose': True, 'lambda_2': 0.0052623019544823825, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 1.3004960922832487, 'tol': 0.7203453608141167, 'alpha_1': 7.102525353879589e-12, 'copy_X': True, 'lambda_1': 0.001155251715547551}
# 	Score: 0.817281619137
# 	Best score: 0.818723632159
#
# Interation no.:  15
# Training with params :
# {'normalize': True, 'n_iter': 20, 'verbose': True, 'lambda_2': 0.004915851740713453, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 3.259815926526066, 'tol': 0.23857195446833218, 'alpha_1': 5.67464321462114e-12, 'copy_X': True, 'lambda_1': 0.0011553805156970195}
# Convergence after  14  iterations
# Convergence after  19  iterations
# 	Score: -0.00759022249868
# 	Best score: 0.818723632159
#
# Interation no.:  16
# Training with params :
# {'normalize': True, 'n_iter': 3, 'verbose': True, 'lambda_2': 0.00499920403973811, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 1.5088369704106541, 'tol': 0.7993410300183245, 'alpha_1': 8.94673409290321e-12, 'copy_X': True, 'lambda_1': 0.0011553887876380269}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: -0.00759022223552
# 	Best score: 0.818723632159
#
# Interation no.:  17
# Training with params :
# {'normalize': True, 'n_iter': 23, 'verbose': True, 'lambda_2': 0.005035677158814654, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.07135805988097266, 'tol': 0.23531498326435202, 'alpha_1': 1.874253301443427e-12, 'copy_X': True, 'lambda_1': 0.001155343159438136}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: -0.00759022211969
# 	Best score: 0.818723632159
#
# Interation no.:  18
# Training with params :
# {'normalize': True, 'n_iter': 14, 'verbose': True, 'lambda_2': 0.005037308880217833, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 6.571277715024032, 'tol': 0.9692279406551993, 'alpha_1': 6.3814681887507646e-12, 'copy_X': True, 'lambda_1': 0.001155498075545042}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: -0.00759022211667
# 	Best score: 0.818723632159
#
# Interation no.:  19
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004978647163157825, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.471860914729199, 'tol': 0.3950137590003342, 'alpha_1': 2.390228581859945e-12, 'copy_X': True, 'lambda_1': 0.0011552150481082713}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.831591002563
# 	Best score: 0.831591002563
#
# Interation no.:  20
# Training with params :
# {'normalize': True, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004951211201855798, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 6.207012227838834, 'tol': 0.5602579356209255, 'alpha_1': 4.808227384832769e-12, 'copy_X': True, 'lambda_1': 0.001155767401912845}
# 	Score: -0.00759022239223
# 	Best score: 0.831591002563
#
# Interation no.: Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
#  21
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.005105346805258703, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 5.7222426838369, 'tol': 0.42957104990859124, 'alpha_1': 4.5473096786202684e-13, 'copy_X': True, 'lambda_1': 0.001155637117733817}
# 	Score: 0.831439276554
# 	Best score: 0.831591002563
#
# Interation no.:  22
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.005140451145746623, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 8.3469760528449, 'tol': 0.006835494548347976, 'alpha_1': 3.4373824450593585e-13, 'copy_X': True, 'lambda_1': 0.0011556318230475954}
# 	Score: 0.831396646639
# 	Best score: 0.831591002563
#
# Interation no.:  23
# Training with params :
# {'normalize': False, 'n_iter': 9, 'verbose': True, 'lambda_2': 0.005155083747922591, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 5.865950318676082, 'tol': 0.42937002547729813, 'alpha_1': 1.556312038015558e-13, 'copy_X': True, 'lambda_1': 0.0011556684858056695}
# 	Score: 0.820156726932
# 	Best score: 0.831591002563
#
# Interation no.:  24
# Training with params :
# {'normalize': False, 'n_iter': 11, 'verbose': True, 'lambda_2': 0.005088152561283155, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 9.61740893167836, 'tol': 0.32734785741003425, 'alpha_1': 3.1171298307360342e-12, 'copy_X': True, 'lambda_1': 0.0011555784820299316}
# 	Score: 0.818014122546
# 	Best score: 0.831591002563
#
# Interation no.:  25
# Training with params :
# {'normalize': False, 'n_iter': 1, 'verbose': True, 'lambda_2': 0.0051315038708657406, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 7.1311052221817075, 'tol': 0.03801007730531486, 'alpha_1': 1.700783942852219e-13, 'copy_X': True, 'lambda_1': 0.0011556354223315403}
# 	Score: -0.00758546813754
# 	Best score: 0.831591002563
#
# Interation no.:  26
# Training with params :
# {'normalize': False, 'n_iter': 17, 'verbose': True, 'lambda_2': 0.005173940519493876, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 8.354943832922253, 'tol': 0.5329425882361434, 'alpha_1': 1.6385912456620525e-12, 'copy_X': True, 'lambda_1': 0.001155425508176557}
# 	Score: 0.817294737173
# 	Best score: 0.831591002563
#
# Interation no.:  27
# Training with params :
# {'normalize': False, 'n_iter': 28, 'verbose': True, 'lambda_2': 0.005075243585532223, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 5.58292782509613, 'tol': 0.36603352283952406, 'alpha_1': 3.1892547849158202e-12, 'copy_X': True, 'lambda_1': 0.0011552058761245664}
# Convergence after  14  iterations
# 	Score: 0.817279186189
# 	Best score: 0.831591002563
#
# Interation no.:  28
# Training with params :
# {'normalize': False, 'n_iter': 22, 'verbose': True, 'lambda_2': 0.005118094763582749, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 8.724299760758166, 'tol': 0.11414306386899359, 'alpha_1': 1.9425580016821374e-13, 'copy_X': True, 'lambda_1': 0.001155696659363065}
# Convergence after  22  iterations
# Convergence after  24  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  26  iterations
# Convergence after Convergence after  14  iterations
#  20  iterations
# 	Score: 0.81727989923
# 	Best score: 0.831591002563
#
# Interation no.:  29
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.00495514273280578, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 0.010794973653670326, 'tol': 0.49836058765663255, 'alpha_1': 2.598838439190196e-13, 'copy_X': True, 'lambda_1': 0.001155598811112267}
# Convergence after  15  iterations
# Convergence after  21  iterations
# 	Score: 0.831624878235
# 	Best score: 0.831624878235
#
# Interation no.:  30
# Training with params :
# {'normalize': False, 'n_iter': 15, 'verbose': True, 'lambda_2': 0.004944856694218467, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 0.6524205587307296, 'tol': 0.8990239946923047, 'alpha_1': 1.5543070888723318e-12, 'copy_X': True, 'lambda_1': 0.0011557961852381863}
# 	Score: 0.817334577857
# 	Best score: 0.831624878235
#
# Interation no.:  31
# Training with params :
# {'normalize': False, 'n_iter': 16, 'verbose': True, 'lambda_2': 0.004981612309036178, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.959461077948148, 'tol': 0.3033628956291522, 'alpha_1': 4.097548463930034e-12, 'copy_X': True, 'lambda_1': 0.0011555697576487343}
# Convergence after  14  iterations
# 	Score: 0.81730858517
# 	Best score: 0.831624878235
#
# Interation no.:  32
# Training with params :
# {'normalize': False, 'n_iter': 12, 'verbose': True, 'lambda_2': 0.004936962167539767, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 2.6555099088066654, 'tol': 0.4764167982725223, 'alpha_1': 1.4611502493170322e-13, 'copy_X': True, 'lambda_1': 0.0011555378608643016}
# Convergence after  14  iterations
# 	Score: 0.817662422914
# 	Best score: 0.831624878235
#
# Interation no.:  33
# Training with params :
# {'normalize': False, 'n_iter': 24, 'verbose': True, 'lambda_2': 0.004910482446071665, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 3.8248638059293114, 'tol': 0.539312332362212, 'alpha_1': 3.0671975934154888e-12, 'copy_X': True, 'lambda_1': 0.0011552848657754686}
# 	Score: 0.817279387783
# 	Best score: 0.831624878235
#
# Interation no.:  34
# Training with params :
# {'normalize': False, 'n_iter': 26, 'verbose': True, 'lambda_2': 0.0049696442799476576, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 0.394637149931119, 'tol': 0.15122663000507003, 'alpha_1': 4.984645110564991e-12, 'copy_X': True, 'lambda_1': 0.0011554495244163}
# Convergence after  22  iterations
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  20  iterations
# Convergence after  14  iterations
# 	Score: 0.817279222124
# 	Best score: 0.831624878235
#
# Interation no.:  35
# Training with params :
# {'normalize': False, 'n_iter': 13, 'verbose': True, 'lambda_2': 0.005010698659428269, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 5.180250936380569, 'tol': 0.3993349131859022, 'alpha_1': 2.7367876644629957e-13, 'copy_X': True, 'lambda_1': 0.0011556122981374497}
# Convergence after  24  iterations
# Convergence after  24  iterations
# Convergence after  24  iterations
# Convergence after  23  iterations
# Convergence after  24  iterations
# Convergence after  25  iterations
# Convergence after Convergence after  15  iterations
#  21  iterations
# 	Score: 0.817477945148
# 	Best score: 0.831624878235
#
# Interation no.:  36
# Training with params :
# {'normalize': False, 'n_iter': 8, 'verbose': True, 'lambda_2': 0.004900640696429561, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 4.338176332432538, 'tol': 0.7349008879360532, 'alpha_1': 2.2531987946466085e-12, 'copy_X': True, 'lambda_1': 0.0011555034251982967}
# 	Score: 0.823464994742
# 	Best score: 0.831624878235
#
# Interation no.:  37
# Training with params :
# {'normalize': False, 'n_iter': 6, 'verbose': True, 'lambda_2': 0.005059539900820193, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 2.043242737836227, 'tol': 0.5884718016349174, 'alpha_1': 3.82045878273989e-12, 'copy_X': True, 'lambda_1': 0.0011554139737773755}
# 	Score: 0.816978599599
# 	Best score: 0.831624878235
#
# Interation no.:  38
# Training with params :
# {'normalize': False, 'n_iter': 4, 'verbose': True, 'lambda_2': 0.004938034883665276, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 7.072076946546579, 'tol': 0.29633390370430596, 'alpha_1': 6.3940871233047424e-12, 'copy_X': True, 'lambda_1': 0.0011555365201649603}
# 	Score: -0.00255184316547
# 	Best score: 0.831624878235
#
# Interation no.:  39
# Training with params :
# {'normalize': False, 'n_iter': 5, 'verbose': True, 'lambda_2': 0.004970399151970419, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.987626617443265, 'tol': 0.8402962960118543, 'alpha_1': 1.6627586504413377e-12, 'copy_X': True, 'lambda_1': 0.0011556868390487781}
# 	Score: 0.20397574867
# 	Best score: 0.831624878235
#
# Interation no.:  40
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.005292261644313474, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 3.701822877222385, 'tol': 0.49608600924819146, 'alpha_1': 3.201278590474748e-12, 'copy_X': True, 'lambda_1': 0.0011557956678301916}
# 	Score: 0.831218135472
# 	Best score: 0.831624878235
#
# Interation no.:  41
# Training with params :
# {'normalize': True, 'n_iter': 21, 'verbose': True, 'lambda_2': 0.00502321256181834, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 7.902260953251447, 'tol': 0.18817613369654462, 'alpha_1': 2.031242321460254e-13, 'copy_X': True, 'lambda_1': 0.0011556068939135328}
# 	Score: -0.00759022216269
# 	Best score: 0.831624878235
#
# Interation no.:  42
# Training with params :
# {'normalize': False, 'n_iter': 10, 'verbose': True, 'lambda_2': 0.005196971945550757, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 2.452210745571954, 'tol': 0.6683038793629399, 'alpha_1': 6.9379663428772985e-12, 'copy_X': True, 'lambda_1': 0.0011554788582132033}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.818709942336
# 	Best score: 0.831624878235
#
# Interation no.:  43
# Training with params :
# {'normalize': False, 'n_iter': 29, 'verbose': True, 'lambda_2': 0.005054997049086874, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 5.104609195561985, 'tol': 0.057332362190889, 'alpha_1': 2.2775745456002083e-12, 'copy_X': True, 'lambda_1': 0.0011552617658064604}
# 	Score: 0.817279164063
# 	Best score: 0.831624878235
#
# Interation no.:  44
# Training with params :
# {'normalize': True, 'n_iter': 19, 'verbose': True, 'lambda_2': 0.004995843483605409, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 4.445408463444649, 'tol': 0.6114311540388232, 'alpha_1': 4.96242989433716e-12, 'copy_X': True, 'lambda_1': 0.0011552068647388833}
# Convergence after  25  iterations
# Convergence after  25  iterations
# Convergence after  27  iterations
# Convergence after  26  iterations
# Convergence after  24  iterations
# Convergence after  26  iterations
# Convergence after Convergence after  15  iterations
#  22  iterations
# 	Score: -0.00759022224365
# 	Best score: 0.831624878235
#
# Interation no.:  45
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004920951338805167, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 3.1809941002978257, 'tol': 0.36621322079004415, 'alpha_1': 1.7006695086160681e-12, 'copy_X': True, 'lambda_1': 0.0011552875330316157}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.831664593875
# 	Best score: 0.831664593875
#
# Interation no.:  46
# Training with params :
# {'normalize': False, 'n_iter': 27, 'verbose': True, 'lambda_2': 0.004924992491069517, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 0.8711230347794854, 'tol': 0.27122950997011236, 'alpha_1': 2.623277467994695e-13, 'copy_X': True, 'lambda_1': 0.0011553044571222788}
# 	Score: 0.817279196915
# 	Best score: 0.831664593875
#
# Interation no.:  47
# Training with params :
# {'normalize': True, 'n_iter': 25, 'verbose': True, 'lambda_2': 0.005238732300235204, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 1.964114471842601, 'tol': 0.35399264132905395, 'alpha_1': 8.260613455342307e-12, 'copy_X': True, 'lambda_1': 0.001155351881705954}
# Convergence after  23  iterations
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  24  iterations
# Convergence after  25  iterations
# Convergence after  24  iterations
# Convergence after Convergence after  14  iterations
#  20  iterations
# 	Score: -0.00759022147844
# 	Best score: 0.831664593875
#
# Interation no.:  48
# Training with params :
# {'normalize': False, 'n_iter': 2, 'verbose': True, 'lambda_2': 0.004926651752826281, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 3.1759018983110123, 'tol': 0.4490005644278679, 'alpha_1': 9.464503243262652e-12, 'copy_X': True, 'lambda_1': 0.0011554368935619206}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: -0.00756414165275
# 	Best score: 0.831664593875
#
# Interation no.:  49
# Training with params :
# {'normalize': True, 'n_iter': 3, 'verbose': True, 'lambda_2': 0.004951804902253648, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 1.7023110829179537, 'tol': 0.7621136486327551, 'alpha_1': 1.4212745434661382e-12, 'copy_X': True, 'lambda_1': 0.0011553860765134115}
# 	Score: -0.0075902223852
# 	Best score: 0.831664593875
#
# Interation no.:  50
# Training with params :
# {'normalize': False, 'n_iter': 18, 'verbose': True, 'lambda_2': 0.004901227213086444, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 0.2782180344056418, 'tol': 0.21485977347120208, 'alpha_1': 6.6078475626634156e-12, 'copy_X': True, 'lambda_1': 0.0011557412467633646}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.817287691061
# 	Best score: 0.831664593875
#
# Interation no.:  51
# Training with params :
# {'normalize': False, 'n_iter': 23, 'verbose': True, 'lambda_2': 0.005073709069811646, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 3.3445542173007756, 'tol': 0.12154874170791119, 'alpha_1': 2.4194170301744527e-13, 'copy_X': True, 'lambda_1': 0.001155523773231006}
# Convergence after  14  iterations
# 	Score: 0.817279564295
# 	Best score: 0.831664593875
#
# Interation no.:  52
# Training with params :
# {'normalize': True, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.005037387312208267, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 0.7677417840365575, 'tol': 0.8948776592722111, 'alpha_1': 9.432806572721225e-12, 'copy_X': True, 'lambda_1': 0.0011555571410832924}
# Convergence after  15  iterations
# Convergence after  21  iterations
# 	Score: -0.00759022211724
# 	Best score: 0.831664593875
#
# Interation no.:  53
# Training with params :
# {'normalize': False, 'n_iter': 14, 'verbose': True, 'lambda_2': 0.004954272423302884, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 1.176566085849553, 'tol': 0.5065736529222956, 'alpha_1': 4.0908719840066776e-12, 'copy_X': True, 'lambda_1': 0.001155599361216467}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.817383902342
# 	Best score: 0.831664593875
#
# Interation no.:  54
# Training with params :
# {'normalize': False, 'n_iter': 9, 'verbose': True, 'lambda_2': 0.005011566378031582, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 4.185539840524413, 'tol': 0.6934506977931647, 'alpha_1': 2.0269179295703195e-12, 'copy_X': True, 'lambda_1': 0.001155333162781853}
# 	Score: 0.820184652451
# 	Best score: 0.831664593875
#
# Interation no.:  55
# Training with params :
# {'normalize': False, 'n_iter': 11, 'verbose': True, 'lambda_2': 0.004980392311184912, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 0.029869416278533706, 'tol': 0.6305886621100762, 'alpha_1': 2.6788796283210193e-13, 'copy_X': True, 'lambda_1': 0.0011554858382899454}
# 	Score: 0.818019199796
# 	Best score: 0.831664593875
#
# Interation no.:  56
# Training with params :
# {'normalize': True, 'n_iter': 1, 'verbose': True, 'lambda_2': 0.004920736460850635, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 2.4859909244948737, 'tol': 0.396061243149357, 'alpha_1': 4.3553558533648756e-12, 'copy_X': True, 'lambda_1': 0.0011552361009935358}
# 	Score: -0.00759023437997
# 	Best score: 0.831664593875
#
# Interation no.:  57
# Training with params :
# {'normalize': False, 'n_iter': 28, 'verbose': True, 'lambda_2': 0.004902375146780101, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 4.762444213079179, 'tol': 0.5888091396722511, 'alpha_1': 1.3585122087567219e-13, 'copy_X': True, 'lambda_1': 0.001155765477979995}
# 	Score: 0.817279202093
# 	Best score: 0.831664593875
#
# Interation no.:  58
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.00516980330490426, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 2.9284895158717887, 'tol': 0.3395935108099573, 'alpha_1': 2.7145645706437255e-12, 'copy_X': True, 'lambda_1': 0.001155664764112547}
# Convergence after  22  iterations
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  22  iterations
# Convergence after  26  iterations
# Convergence after  23  iterations
# Convergence after Convergence after  14  iterations
#  19  iterations
# 	Score: 0.831361674345
# 	Best score: 0.831664593875
#
# Interation no.:  59
# Training with params :
# {'normalize': True, 'n_iter': 22, 'verbose': True, 'lambda_2': 0.005105872786701116, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 3.5142406594654476, 'tol': 0.25837570306592506, 'alpha_1': 8.305816720512747e-12, 'copy_X': True, 'lambda_1': 0.0011553970379378192}
# 	Score: -0.00759022189872
# 	Best score: 0.831664593875
#
# Interation no.:  60
# Training with params :
# {'normalize': False, 'n_iter': 17, 'verbose': True, 'lambda_2': 0.005029509967383605, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 6.324411029293625, 'tol': 0.19134625008404893, 'alpha_1': 1.9615726946180318e-12, 'copy_X': True, 'lambda_1': 0.0011554498531034833}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.817294870764
# 	Best score: 0.831664593875
#
# Interation no.:  61
# Training with params :
# {'normalize': False, 'n_iter': 20, 'verbose': True, 'lambda_2': 0.004962420912204779, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 5.322559613125555, 'tol': 0.45064913239804444, 'alpha_1': 5.47182321609837e-12, 'copy_X': True, 'lambda_1': 0.0011553582072962598}
# Convergence after  15  iterations
# 	Score: 0.817281662799
# 	Best score: 0.831664593875
#
# Interation no.:  62
# Training with params :
# {'normalize': False, 'n_iter': 16, 'verbose': True, 'lambda_2': 0.005007467854968526, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 4.092250885987987, 'tol': 0.06996497398789003, 'alpha_1': 1.5439935890903878e-13, 'copy_X': True, 'lambda_1': 0.0011557226506457587}
# Convergence after  14  iterations
# 	Score: 0.817308539643
# 	Best score: 0.831664593875
#
# Interation no.:  63
# Training with params :
# {'normalize': False, 'n_iter': 15, 'verbose': True, 'lambda_2': 0.004991176870756587, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 1.1841275145607382, 'tol': 0.5344556543736704, 'alpha_1': 3.311010067762952e-12, 'copy_X': True, 'lambda_1': 0.0011552728315917333}
# Convergence after  15  iterations
# 	Score: 0.817334402775
# 	Best score: 0.831664593875
#
# Interation no.:  64
# Training with params :
# {'normalize': True, 'n_iter': 24, 'verbose': True, 'lambda_2': 0.005072810402800897, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.7276426043915376, 'tol': 0.3775308323449691, 'alpha_1': 9.56474968366801e-12, 'copy_X': True, 'lambda_1': 0.001155309652987634}
# Convergence after  14  iterations
# 	Score: -0.00759022200194
# 	Best score: 0.831664593875
#
# Interation no.:  65
# Training with params :
# {'normalize': False, 'n_iter': 12, 'verbose': True, 'lambda_2': 0.005045189953649737, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 0.429127303413269, 'tol': 0.8182340929579639, 'alpha_1': 6.180185958041037e-12, 'copy_X': True, 'lambda_1': 0.0011555897701590809}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.817659795977
# 	Best score: 0.831664593875
#
# Interation no.:  66
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.00491060486586265, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.051943927735207, 'tol': 0.29829313234774046, 'alpha_1': 2.1745215797399978e-12, 'copy_X': True, 'lambda_1': 0.001155234080629237}
# 	Score: 0.83167713951
# 	Best score: 0.83167713951
#
# Interation no.:  67
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004935668397231156, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 6.886148212781983, 'tol': 0.30566392378279295, 'alpha_1': 1.9001826296468975e-12, 'copy_X': True, 'lambda_1': 0.0011552295386229293}
# 	Score: 0.831645279994
# 	Best score: 0.83167713951
#
# Interation no.:  68
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004933375256590806, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.219537125147943, 'tol': 0.2883918818657111, 'alpha_1': 2.887040549990447e-12, 'copy_X': True, 'lambda_1': 0.001155235281685873}
# 	Score: 0.831648247667
# 	Best score: 0.83167713951
#
# Interation no.:  69
# Training with params :
# {'normalize': False, 'n_iter': 26, 'verbose': True, 'lambda_2': 0.004929499597041297, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.050347335208853, 'tol': 0.4219545405124568, 'alpha_1': 3.8235315202171335e-12, 'copy_X': True, 'lambda_1': 0.0011552873188190465}
# 	Score: 0.817279230806
# 	Best score: 0.83167713951
#
# Interation no.:  70
# Training with params :
# {'normalize': False, 'n_iter': 13, 'verbose': True, 'lambda_2': 0.004915611611677192, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 7.936516622628257, 'tol': 0.16671423276245936, 'alpha_1': 3.5608114783859864e-12, 'copy_X': True, 'lambda_1': 0.0011552512882041731}
# Convergence after  23  iterations
# Convergence after  24  iterations
# Convergence after  22  iterations
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after Convergence after  14  iterations
#  20  iterations
# 	Score: 0.817479104698
# 	Best score: 0.83167713951
#
# Interation no.:  71
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004907539860174347, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.679330426421327, 'tol': 0.21730784563493896, 'alpha_1': 3.0627337988353632e-12, 'copy_X': True, 'lambda_1': 0.0011553299574998503}
# 	Score: 0.831682133267
# 	Best score: 0.831682133267
#
# Interation no.:  72
# Training with params :
# {'normalize': False, 'n_iter': 6, 'verbose': True, 'lambda_2': 0.004900896662086207, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.728107296647647, 'tol': 0.006888527998043542, 'alpha_1': 4.085963558618151e-12, 'copy_X': True, 'lambda_1': 0.0011553388395079383}
# 	Score: 0.8144668697
# 	Best score: 0.831682133267
#
# Interation no.:  73
# Training with params :
# {'normalize': False, 'n_iter': 8, 'verbose': True, 'lambda_2': 0.004907631501016325, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 7.537277362256177, 'tol': 0.10274548241957904, 'alpha_1': 2.4051294970159625e-12, 'copy_X': True, 'lambda_1': 0.0011553737558809534}
# 	Score: 0.823461032769
# 	Best score: 0.831682133267
#
# Interation no.:  74
# Training with params :
# {'normalize': False, 'n_iter': 5, 'verbose': True, 'lambda_2': 0.004945136731805892, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 8.608552634320816, 'tol': 0.23344643409440735, 'alpha_1': 2.7498333814741344e-12, 'copy_X': True, 'lambda_1': 0.0011553217042357539}
# 	Score: 0.202411550639
# 	Best score: 0.831682133267
#
# Interation no.:  75
# Training with params :
# {'normalize': False, 'n_iter': 4, 'verbose': True, 'lambda_2': 0.004965527568121703, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 6.0493731215344635, 'tol': 0.3179110161491998, 'alpha_1': 4.770740730651478e-12, 'copy_X': True, 'lambda_1': 0.0011552949991089217}
# 	Score: -0.00248892675633
# 	Best score: 0.831682133267
#
# Interation no.:  76
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004982622709735164, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 8.890734813475555, 'tol': 0.20873109916988777, 'alpha_1': 2.2379889210416468e-12, 'copy_X': True, 'lambda_1': 0.0011552166813937118}
# 	Score: 0.831586042744
# 	Best score: 0.831682133267
#
# Interation no.:  77
# Training with params :
# {'normalize': False, 'n_iter': 10, 'verbose': True, 'lambda_2': 0.005221711087201345, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 8.324276158534785, 'tol': 0.0867617997379607, 'alpha_1': 3.7616161242357005e-12, 'copy_X': True, 'lambda_1': 0.0011552730303284993}
# 	Score: 0.818707491864
# 	Best score: 0.831682133267
#
# Interation no.:  78
# Training with params :
# {'normalize': False, 'n_iter': 19, 'verbose': True, 'lambda_2': 0.004914781832738627, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 6.5138274281266515, 'tol': 0.17306234229212952, 'alpha_1': 1.8244549816910466e-12, 'copy_X': True, 'lambda_1': 0.0011553709389170105}
# 	Score: 0.817283772963
# 	Best score: 0.831682133267
#
# Interation no.:  79
# Training with params :
# {'normalize': False, 'n_iter': 29, 'verbose': True, 'lambda_2': 0.005131872794522098, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 5.499098423638007, 'tol': 0.13066804424435083, 'alpha_1': 5.0515989262958e-12, 'copy_X': True, 'lambda_1': 0.0011554006973129739}
# Convergence after  15  iterations
# 	Score: 0.817279168474
# 	Best score: 0.831682133267
#
# Interation no.:  80
# Training with params :
# {'normalize': False, 'n_iter': 21, 'verbose': True, 'lambda_2': 0.00501984132736315, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.37425936065278, 'tol': 0.02815854138384949, 'alpha_1': 2.1440309943066773e-12, 'copy_X': True, 'lambda_1': 0.0011553223677233772}
# Convergence after  24  iterations
# Convergence after  24  iterations
# Convergence after  25  iterations
# Convergence after  23  iterations
# Convergence after  28  iterations
# Convergence after  24  iterations
# Convergence after  24  iterations
# Convergence after Convergence after  15  iterations
#  21  iterations
# 	Score: 0.817280519715
# 	Best score: 0.831682133267
#
# Interation no.:  81
# Training with params :
# {'normalize': True, 'n_iter': 25, 'verbose': True, 'lambda_2': 0.004942139536746258, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.761199194612354, 'tol': 0.26820062944536793, 'alpha_1': 4.655360598441999e-12, 'copy_X': True, 'lambda_1': 0.001155217217007439}
# Convergence after  16  iterations
# 	Score: -0.00759022241344
# 	Best score: 0.831682133267
#
# Interation no.:  82
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004972012102803142, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 7.903455356546673, 'tol': 0.3459554397603485, 'alpha_1': 3.469989821466979e-12, 'copy_X': True, 'lambda_1': 0.0011552571611579653}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.831599797887
# 	Best score: 0.831682133267
#
# Interation no.:  83
# Training with params :
# {'normalize': False, 'n_iter': 27, 'verbose': True, 'lambda_2': 0.005292923551465913, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 7.309947638558437, 'tol': 0.14373122870906324, 'alpha_1': 1.706579294044069e-12, 'copy_X': True, 'lambda_1': 0.0011554163092206485}
# 	Score: 0.817279192961
# 	Best score: 0.831682133267
#
# Interation no.:  84
# Training with params :
# {'normalize': False, 'n_iter': 14, 'verbose': True, 'lambda_2': 0.0050892207459566395, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 2.9223396762854845, 'tol': 0.3795814601295622, 'alpha_1': 6.254058193390511e-12, 'copy_X': True, 'lambda_1': 0.0011552028172131161}
# Convergence after  24  iterations
# Convergence after  23  iterations
# Convergence after  25  iterations
# Convergence after  24  iterations
# Convergence after  24  iterations
# Convergence after  24  iterations
# Convergence after  15  iterations
# Convergence after  21  iterations
# 	Score: 0.817383004738
# 	Best score: 0.831682133267
#
# Interation no.:  85
# Training with params :
# {'normalize': False, 'n_iter': 2, 'verbose': True, 'lambda_2': 0.0049919581069333575, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 4.879722706308544, 'tol': 0.41666910323187806, 'alpha_1': 1.4917728312698394e-12, 'copy_X': True, 'lambda_1': 0.001155463359020856}
# 	Score: -0.00756387905399
# 	Best score: 0.831682133267
#
# Interation no.:  86
# Training with params :
# {'normalize': True, 'n_iter': 3, 'verbose': True, 'lambda_2': 0.005007128991289583, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 2.3340080275438293, 'tol': 0.47200252721824193, 'alpha_1': 3.3556379477705455e-12, 'copy_X': True, 'lambda_1': 0.001155357375277317}
# 	Score: -0.00759022221006
# 	Best score: 0.831682133267
#
# Interation no.:  87
# Training with params :
# {'normalize': False, 'n_iter': 11, 'verbose': True, 'lambda_2': 0.004959510647417982, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 6.831589272157471, 'tol': 0.5601239173818491, 'alpha_1': 1.356462921447702e-12, 'copy_X': True, 'lambda_1': 0.001155271265206121}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.818020112232
# 	Best score: 0.831682133267
#
# Interation no.:  88
# Training with params :
# {'normalize': False, 'n_iter': 9, 'verbose': True, 'lambda_2': 0.005064664326555721, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 8.640753419156031, 'tol': 0.2395872187786913, 'alpha_1': 3.716219775256612e-12, 'copy_X': True, 'lambda_1': 0.001155299263339827}
# 	Score: 0.820173929447
# 	Best score: 0.831682133267
#
# Interation no.:  89
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.0049470131158444695, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 3.8686001832011727, 'tol': 0.3219615815779482, 'alpha_1': 1.2281848319705657e-12, 'copy_X': True, 'lambda_1': 0.0011552500996431737}
# 	Score: 0.831631176777
# 	Best score: 0.831682133267
#
# Interation no.:  90
# Training with params :
# {'normalize': True, 'n_iter': 23, 'verbose': True, 'lambda_2': 0.00492217528271563, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.980632914187781, 'tol': 0.2190428114362596, 'alpha_1': 5.319844400054954e-12, 'copy_X': True, 'lambda_1': 0.001155334314155239}
# 	Score: -0.00759022247809
# 	Best score: 0.831682133267
#
# Interation no.:  91
# Training with params :
# {'normalize': False, 'n_iter': 1, 'verbose': True, 'lambda_2': 0.005271901652354576, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 8.138499373378577, 'tol': 0.2877976164145512, 'alpha_1': 1.5665868969842222e-13, 'copy_X': True, 'lambda_1': 0.0011553169482656968}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: -0.00758546813754
# 	Best score: 0.831682133267
#
# Interation no.:  92
# Training with params :
# {'normalize': False, 'n_iter': 18, 'verbose': True, 'lambda_2': 0.005044963147934725, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 9.463210336242396, 'tol': 0.5181938647526914, 'alpha_1': 2.6104614322194476e-12, 'copy_X': True, 'lambda_1': 0.0011554341657787255}
# 	Score: 0.817287615944
# 	Best score: 0.831682133267
#
# Interation no.:  93
# Training with params :
# {'normalize': False, 'n_iter': 17, 'verbose': True, 'lambda_2': 0.005198446761397713, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 4.605021854502237, 'tol': 0.4527649373767877, 'alpha_1': 1.4897827657081906e-12, 'copy_X': True, 'lambda_1': 0.001155283700570656}
# Convergence after  14  iterations
# 	Score: 0.817294713416
# 	Best score: 0.831682133267
#
# Interation no.:  94
# Training with params :
# {'normalize': False, 'n_iter': 28, 'verbose': True, 'lambda_2': 0.005154154413431589, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 5.740188156459693, 'tol': 0.36645360227832896, 'alpha_1': 4.250470898814395e-12, 'copy_X': True, 'lambda_1': 0.001155509031961019}
# Convergence after  14  iterations
# 	Score: 0.81727918608
# 	Best score: 0.831682133267
#
# Interation no.:  95
# Training with params :
# {'normalize': True, 'n_iter': 15, 'verbose': True, 'lambda_2': 0.004906968163122075, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 2.6380475913592685, 'tol': 0.19381663421398176, 'alpha_1': 2.9679835729617406e-12, 'copy_X': True, 'lambda_1': 0.0011553657822755345}
# Convergence after  23  iterations
# Convergence after  24  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  22  iterations
# Convergence after  26  iterations
# Convergence after Convergence after  14  iterations
#  20  iterations
# 	Score: -0.00759022252654
# 	Best score: 0.831682133267
#
# Interation no.:  96
# Training with params :
# {'normalize': False, 'n_iter': 16, 'verbose': True, 'lambda_2': 0.004975928900485284, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 3.206870019132951, 'tol': 0.0465503782518743, 'alpha_1': 5.624247212338893e-13, 'copy_X': True, 'lambda_1': 0.00115520167425032}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.817308587805
# 	Best score: 0.831682133267
#
# Interation no.:  97
# Training with params :
# {'normalize': False, 'n_iter': 22, 'verbose': True, 'lambda_2': 0.005183623302017137, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 7.7247397346859366, 'tol': 0.48477659269120454, 'alpha_1': 6.466245252716213e-12, 'copy_X': True, 'lambda_1': 0.0011552200946944144}
# Convergence after  15  iterations
# 	Score: 0.817279896681
# 	Best score: 0.831682133267
#
# Interation no.:  98
# Training with params :
# {'normalize': False, 'n_iter': 20, 'verbose': True, 'lambda_2': 0.00499961554870071, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 3.64821748974676, 'tol': 0.07851254343597372, 'alpha_1': 1.1891984454821739e-12, 'copy_X': True, 'lambda_1': 0.0011553874974174205}
# Convergence after  14  iterations
# Convergence after  20  iterations
# 	Score: 0.81728165576
# 	Best score: 0.831682133267
#
# Interation no.:  99
# Training with params :
# {'normalize': True, 'n_iter': 12, 'verbose': True, 'lambda_2': 0.005098471760754985, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 1.359167003179457, 'tol': 0.404453354705247, 'alpha_1': 3.893809180999461e-12, 'copy_X': True, 'lambda_1': 0.0011554075555027566}
# Convergence after  15  iterations
# 	Score: -0.00759022192225
# 	Best score: 0.831682133267
#
# Interation no.:  100
# Training with params :
# {'normalize': False, 'n_iter': 24, 'verbose': True, 'lambda_2': 0.0051166477942095594, 'fit_intercept': True, 'compute_score': True, 'alpha_2': 6.007223807420526, 'tol': 0.15930239009099792, 'alpha_1': 3.221546341675519e-13, 'copy_X': True, 'lambda_1': 0.0011552445317451504}
# ...
# 	Score: 0.817280531674
# 	Best score: 0.831696966687
#
# Interation no.:  968
# Training with params :
# {'normalize': False, 'n_iter': 19, 'verbose': True, 'lambda_2': 0.0049272540040842345, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.9591130979949872, 'tol': 0.43865587908024106, 'alpha_1': 6.009347295358333e-12, 'copy_X': True, 'lambda_1': 0.0011557309321569681}
# Convergence after  14  iterations
# Convergence after  20  iterations
# 	Score: 0.817283772045
# 	Best score: 0.831696966687
#
# Interation no.:  969
# Training with params :
# {'normalize': False, 'n_iter': 29, 'verbose': True, 'lambda_2': 0.005028579793423248, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.27978108358905524, 'tol': 0.41520500272704736, 'alpha_1': 5.973162517517295e-12, 'copy_X': True, 'lambda_1': 0.0011556808364486754}
# Convergence after  14  iterations
# 	Score: 0.817279177653
# 	Best score: 0.831696966687
#
# Interation no.:  970
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004945320380104807, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.2253256439299989, 'tol': 0.37929858058849286, 'alpha_1': 5.931349479755134e-12, 'copy_X': True, 'lambda_1': 0.001155782469773876}
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  24  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  28  iterations
# Convergence after  26  iterations
# Convergence after Convergence after  14  iterations
#  20  iterations
# 	Score: 0.831639352006
# 	Best score: 0.831696966687
#
# Interation no.:  971
# Training with params :
# {'normalize': False, 'n_iter': 27, 'verbose': True, 'lambda_2': 0.004969986832943156, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.004056361398637849, 'tol': 0.46154251223845194, 'alpha_1': 5.821164966850897e-12, 'copy_X': True, 'lambda_1': 0.0011557184085522576}
# 	Score: 0.817279202375
# 	Best score: 0.831696966687
#
# Interation no.:  972
# Training with params :
# {'normalize': True, 'n_iter': 10, 'verbose': True, 'lambda_2': 0.004916675253981406, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.5875549360300512, 'tol': 0.5053392514705713, 'alpha_1': 5.9024370678780524e-12, 'copy_X': True, 'lambda_1': 0.0011556506598037304}
# Convergence after  23  iterations
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  24  iterations
# Convergence after  22  iterations
# Convergence after  26  iterations
# Convergence after  23  iterations
# Convergence after Convergence after  14  iterations
#  20  iterations
# 	Score: -0.00759022249971
# 	Best score: 0.831696966687
#
# Interation no.:  973
# Training with params :
# {'normalize': False, 'n_iter': 25, 'verbose': True, 'lambda_2': 0.005138711210171545, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.14388148038911652, 'tol': 0.34265786707583823, 'alpha_1': 5.782797132863595e-12, 'copy_X': True, 'lambda_1': 0.0011557468105591463}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.81727927932
# 	Best score: 0.831696966687
#
# Interation no.:  974
# Training with params :
# {'normalize': False, 'n_iter': 2, 'verbose': True, 'lambda_2': 0.004936129630710509, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.3125039744535734, 'tol': 0.5301490510812601, 'alpha_1': 5.884347613096832e-12, 'copy_X': True, 'lambda_1': 0.0011557682206973293}
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  24  iterations
# Convergence after  22  iterations
# Convergence after Convergence after  14  iterations
#  20  iterations
# 	Score: -0.00756411077046
# 	Best score: 0.831696966687
#
# Interation no.:  975
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004924755558567485, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.005427889696288213, 'tol': 0.31128552227383155, 'alpha_1': 5.83239934665307e-12, 'copy_X': True, 'lambda_1': 0.0011556347910097525}
# 	Score: 0.831663711494
# 	Best score: 0.831696966687
#
# Interation no.:  976
# Training with params :
# {'normalize': False, 'n_iter': 18, 'verbose': True, 'lambda_2': 0.004958749128727488, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.9753197819283765, 'tol': 0.4790429056472288, 'alpha_1': 5.974824333782903e-12, 'copy_X': True, 'lambda_1': 0.0011557894594448888}
# 	Score: 0.817287661566
# 	Best score: 0.831696966687
#
# Interation no.:  977
# Training with params :
# {'normalize': False, 'n_iter': 3, 'verbose': True, 'lambda_2': 0.004912777158951001, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.6161504225586993, 'tol': 0.4204767437608074, 'alpha_1': 5.83809108188344e-12, 'copy_X': True, 'lambda_1': 0.001155698132869536}
# Convergence after  14  iterations
# 	Score: -0.007404205666
# 	Best score: 0.831696966687
#
# Interation no.:  978
# Training with params :
# {'normalize': False, 'n_iter': 23, 'verbose': True, 'lambda_2': 0.004937280967842148, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.7560332265558022, 'tol': 0.44645753042593106, 'alpha_1': 5.846912732415849e-12, 'copy_X': True, 'lambda_1': 0.001155762765572262}
# 	Score: 0.817279568286
# 	Best score: 0.831696966687
#
# Interation no.:  979
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.0049837833831319536, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.4525332679252622, 'tol': 0.36775058718050585, 'alpha_1': 5.8902716317415885e-12, 'copy_X': True, 'lambda_1': 0.001155731147847609}
# Convergence after  22  iterations
# Convergence after  22  iterations
# Convergence after  20  iterations
# Convergence after  14  iterations
# 	Score: 0.831590405716
# 	Best score: 0.831696966687
#
# Interation no.:  980
# Training with params :
# {'normalize': False, 'n_iter': 14, 'verbose': True, 'lambda_2': 0.004965593822036222, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.22023342431556248, 'tol': 0.27958775195626095, 'alpha_1': 5.639081798930917e-12, 'copy_X': True, 'lambda_1': 0.0011557106471491237}
# 	Score: 0.817383834611
# 	Best score: 0.831696966687
#
# Interation no.:  981
# Training with params :
# {'normalize': False, 'n_iter': 9, 'verbose': True, 'lambda_2': 0.004906742877301044, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.6973840655131753, 'tol': 0.49066520923436047, 'alpha_1': 5.877045191221403e-12, 'copy_X': True, 'lambda_1': 0.0011557797220053364}
# 	Score: 0.820206903855
# 	Best score: 0.831696966687
#
# Interation no.:  982
# Training with params :
# {'normalize': False, 'n_iter': 1, 'verbose': True, 'lambda_2': 0.004921973215299547, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.085214031111441, 'tol': 0.5814155600374808, 'alpha_1': 5.782154705130651e-12, 'copy_X': True, 'lambda_1': 0.0011557993666454}
# 	Score: -0.00758546813754
# 	Best score: 0.831696966687
#
# Interation no.:  983
# Training with params :
# {'normalize': True, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.0049473926766036725, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.012242353311165466, 'tol': 0.5444054574655091, 'alpha_1': 5.931570873375366e-12, 'copy_X': True, 'lambda_1': 0.0011557431482324514}
# 	Score: -0.00759022240396
# 	Best score: 0.831696966687
#
# Interation no.:  984
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004929667122304699, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.433307586965471, 'tol': 0.5071880100881885, 'alpha_1': 5.656738825286501e-12, 'copy_X': True, 'lambda_1': 0.0011556933014585343}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.831658146807
# 	Best score: 0.831696966687
#
# Interation no.:  985
# Training with params :
# {'normalize': False, 'n_iter': 11, 'verbose': True, 'lambda_2': 0.005248258138511715, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.42810697782333096, 'tol': 0.4691621389632176, 'alpha_1': 5.749437082694989e-12, 'copy_X': True, 'lambda_1': 0.001155662297044756}
# 	Score: 0.818006763224
# 	Best score: 0.831696966687
#
# Interation no.:  986
# Training with params :
# {'normalize': False, 'n_iter': 15, 'verbose': True, 'lambda_2': 0.004907686504286199, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.20198281569819315, 'tol': 0.392034250046695, 'alpha_1': 5.737876010307057e-12, 'copy_X': True, 'lambda_1': 0.0011557553528381654}
# 	Score: 0.817334705198
# 	Best score: 0.831696966687
#
# Interation no.:  987
# Training with params :
# {'normalize': False, 'n_iter': 17, 'verbose': True, 'lambda_2': 0.0049005810588093526, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.0045321161251382636, 'tol': 0.5309262835210404, 'alpha_1': 5.661673153942774e-12, 'copy_X': True, 'lambda_1': 0.0011557709567079273}
# Convergence after  14  iterations
# 	Score: 0.817294998965
# 	Best score: 0.831696966687
#
# Interation no.:  988
# Training with params :
# {'normalize': False, 'n_iter': 16, 'verbose': True, 'lambda_2': 0.0049536983000791485, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.8677758235318078, 'tol': 0.6129762229672518, 'alpha_1': 5.782955675285644e-12, 'copy_X': True, 'lambda_1': 0.0011557900757092894}
# Convergence after  14  iterations
# 	Score: 0.817308639272
# 	Best score: 0.831696966687
#
# Interation no.:  989
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004918807337579737, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.608133043017276, 'tol': 0.5692875605647103, 'alpha_1': 5.8930092818440614e-12, 'copy_X': True, 'lambda_1': 0.001155720797293925}
# Convergence after  14  iterations
# 	Score: 0.831672243005
# 	Best score: 0.831696966687
#
# Interation no.:  990
# Training with params :
# {'normalize': False, 'n_iter': 28, 'verbose': True, 'lambda_2': 0.00493325503011351, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.2312671641522368, 'tol': 0.32873084529262164, 'alpha_1': 5.816829866336678e-12, 'copy_X': True, 'lambda_1': 0.0011557993198252543}
# 	Score: 0.817279186688
# 	Best score: 0.831696966687
#
# Interation no.:  991
# Training with params :
# {'normalize': False, 'n_iter': 20, 'verbose': True, 'lambda_2': 0.004900704614432267, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.36411430976262593, 'tol': 0.43569823196988744, 'alpha_1': 5.702159945062934e-12, 'copy_X': True, 'lambda_1': 0.0011556789932890713}
# Convergence after  23  iterations
# Convergence after  24  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  26  iterations
# Convergence after Convergence after  14  iterations
#  20  iterations
# 	Score: 0.817281672582
# 	Best score: 0.831696966687
#
# Interation no.:  992
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004941438841622773, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.5545997770941686, 'tol': 0.548650361710009, 'alpha_1': 5.753483805369764e-12, 'copy_X': True, 'lambda_1': 0.0011557390912083061}
# Convergence after  14  iterations
# 	Score: 0.831643764763
# 	Best score: 0.831696966687
#
# Interation no.:  993
# Training with params :
# {'normalize': True, 'n_iter': 22, 'verbose': True, 'lambda_2': 0.004900427470637915, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.925497655973407, 'tol': 0.49557043105695286, 'alpha_1': 5.861423443450512e-12, 'copy_X': True, 'lambda_1': 0.0011557786375568705}
# 	Score: -0.00759022255273
# 	Best score: 0.831696966687
#
# Interation no.:  994
# Training with params :
# {'normalize': False, 'n_iter': 26, 'verbose': True, 'lambda_2': 0.004913032676138731, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.003098893472901265, 'tol': 0.5172418034342698, 'alpha_1': 5.879360018082914e-12, 'copy_X': True, 'lambda_1': 0.00115579908573433}
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after  1  iterations
# Convergence after Convergence after  1  iterations
#  1  iterations
# 	Score: 0.817279236858
# 	Best score: 0.831696966687
#
# Interation no.:  995
# Training with params :
# {'normalize': False, 'n_iter': 13, 'verbose': True, 'lambda_2': 0.004924049735180474, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.4949650584165046, 'tol': 0.45759824739143484, 'alpha_1': 5.5383198376565375e-12, 'copy_X': True, 'lambda_1': 0.0011557557331592434}
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  22  iterations
# Convergence after  22  iterations
# Convergence after  24  iterations
# Convergence after  23  iterations
# Convergence after Convergence after  14  iterations
#  20  iterations
# 	Score: 0.817479054587
# 	Best score: 0.831696966687
#
# Interation no.:  996
# Training with params :
# {'normalize': False, 'n_iter': 24, 'verbose': True, 'lambda_2': 0.004907135585337706, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.22706761191636268, 'tol': 0.5840981871670647, 'alpha_1': 5.778138766380491e-12, 'copy_X': True, 'lambda_1': 0.0011557660552449134}
# 	Score: 0.81727938542
# 	Best score: 0.831696966687
#
# Interation no.:  997
# Training with params :
# {'normalize': False, 'n_iter': 6, 'verbose': True, 'lambda_2': 0.004992120955072231, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.7534116901596538, 'tol': 0.3739551614910012, 'alpha_1': 5.833381642438318e-12, 'copy_X': True, 'lambda_1': 0.0011557143666364178}
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  22  iterations
# Convergence after  22  iterations
# Convergence after  23  iterations
# Convergence after  23  iterations
# Convergence after Convergence after  14  iterations
#  19  iterations
# 	Score: 0.815897966872
# 	Best score: 0.831696966687
#
# Interation no.:  998
# Training with params :
# {'normalize': False, 'n_iter': 12, 'verbose': True, 'lambda_2': 0.0051864114246571395, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.1708301514392185, 'tol': 0.40607313747701446, 'alpha_1': 5.7043612464009736e-12, 'copy_X': True, 'lambda_1': 0.0011557296230909559}
# 	Score: 0.817656471923
# 	Best score: 0.831696966687
#
# Interation no.:  999
# Training with params :
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004900282959809987, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.825680432548034, 'tol': 0.6672093693233289, 'alpha_1': 5.7622193485946756e-12, 'copy_X': True, 'lambda_1': 0.0011557490519296426}
# 	Score: 0.83169615808
# 	Best score: 0.831696966687
#
# Interation no.:  1000
# Training with params :
# {'normalize': False, 'n_iter': 4, 'verbose': True, 'lambda_2': 0.004972810381294602, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 1.9725399331249185, 'tol': 0.7388477842532815, 'alpha_1': 5.993290569886538e-12, 'copy_X': True, 'lambda_1': 0.0011557877981034563}
# 	Score: -0.00248276774548
# 	Best score: 0.831696966687
#
# Best parameters:
# {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004900097067640188, 'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.010070176141440748, 'tol': 0.4475451681770408, 'alpha_1': 5.828472650020041e-12, 'copy_X': True, 'lambda_1': 0.0011557992166094178}
# 	Score 0.831696966687

# %%
params = {'normalize': False, 'n_iter': 7, 'verbose': True, 'lambda_2': 0.004900097067640188,
          'fit_intercept': True, 'compute_score': False, 'alpha_2': 0.010070176141440748, 'tol': 0.4475451681770408,
          'alpha_1': 5.828472650020041e-12, 'copy_X': True, 'lambda_1': 0.0011557992166094178}
reg1 = BayesianRidge(
                    alpha_1 = params['alpha_1'],
                    alpha_2 = params['alpha_2'],
                    lambda_1 = params['lambda_1'],
                    lambda_2 = params['lambda_2'],
                    n_iter = params['n_iter'],
                    tol = params['tol'],
                    compute_score = params['compute_score'],
                    normalize = params['normalize'],
                    fit_intercept = params['fit_intercept'],
                    copy_X = params['copy_X'],
                    verbose = params['verbose']
                    )
modelfit(reg1, X_train, y_train)
# Out:
# Model Report
# Train_coef_of_det: 0.909645
# CV_coef_of_det: Mean-0.831697 | Std-0.105829 | Min-0.534806 | Max-0.908068

# %% [markdown]
# ### Grid search + Genetic programming ( 'sklearn-deap' package)

# %%
params = {
        'alpha_1': [i*10**(-13) for i in range(1,101,10)],
        'alpha_2': [i*10**(-1) for i in range(0,101,10)],
        'lambda_1': [i/100000000.0 for i in range(115520,115580)],
        'lambda_2': [i/100000.0 for i in range(490,530)],    
        'n_iter': range(1,30),
        'tol': [10**(-i) for i in range(0,11)],
        'compute_score': [True,False],
        'normalize': [True,False],
        'fit_intercept': [True],
        'copy_X': [True],
        'verbose': [True]
         }
evol = EvolutionaryAlgorithmSearchCV(estimator=BayesianRidge(), params=params, cv=10,
        scoring='r2', population_size=100, gene_mutation_prob=0.5, gene_crossover_prob=0.5, tournament_size=7,
        generations_number=25, verbose=True, n_jobs=-1)
evol.fit(X_train, y_train)

# %%
params = {}
reg1 = BayesianRidge(
                    alpha_1 = params['alpha_1'],
                    alpha_2 = params['alpha_2'],
                    lambda_1 = params['lambda_1'],
                    lambda_2 = params['lambda_2'],
                    n_iter = params['n_iter'],
                    tol = params['tol'],
                    compute_score = params['compute_score'],
                    normalize = params['normalize'],
                    fit_intercept = params['fit_intercept'],
                    copy_X = params['copy_X'],
                    verbose = params['verbose']
                    )
modelfit(reg1, X_train, y_train)

# %% [markdown]
# ### Make predictions and save results

# %%
test_pred = reg1.predict(X_test)
dictn = {'Id': range(1461,2920), 'SalePrice': test_pred}
res = pd.DataFrame(dictn)
res.to_csv('submission.csv', index=0)
